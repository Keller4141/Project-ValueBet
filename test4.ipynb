# %%
import requests
import pandas as pd
from datetime import datetime, timedelta, timezone

API_TOKEN = "KuQ4Rt1ypOCvXfcm3cZXdPhOUlbuOrpHBgJkFm1MWTvtRR8TLhgEI02hjDxz"
BASE_URL = "https://api.sportmonks.com/v3/football"
BOOKMAKER_URL = "https://api.sportmonks.com/v3/odds/bookmakers"  # bookmaker lookup is under /v3/odds/...

# -------------------------
# Fixtures (next 12 hours)
# -------------------------
def fetch_fixtures_next_12h() -> pd.DataFrame:
    """Return fixtures starting in the next 12 hours (UTC)."""
    now_utc = datetime.now(timezone.utc)
    end_utc = now_utc + timedelta(hours=12)

    start_date = now_utc.date()
    end_date = (now_utc + timedelta(days=1)).date()
    endpoint = f"/fixtures/between/{start_date:%Y-%m-%d}/{end_date:%Y-%m-%d}"

    session = requests.Session()
    fixtures = []
    page = 1

    while True:
        r = session.get(
            f"{BASE_URL}{endpoint}",
            params={"api_token": API_TOKEN, "page": page},
            timeout=30,
        )
        r.raise_for_status()
        payload = r.json()

        fixtures.extend(payload.get("data") or [])

        # Pagination handling: be defensive across endpoints/plans
        pagination = ((payload.get("meta") or {}).get("pagination")) or {}
        has_more = pagination.get("has_more")
        total_pages = pagination.get("total_pages")
        current_page = pagination.get("current_page")

        if has_more is False:
            break
        if total_pages is not None and current_page is not None and int(current_page) >= int(total_pages):
            break
        if has_more is None and (total_pages is None or current_page is None):
            # If the API didn't return pagination metadata, assume single page.
            break

        page += 1

    df = pd.DataFrame(
        {
            "FixtureID": [f.get("id") for f in fixtures],
            "Fixture": [f.get("name") for f in fixtures],
            "StartingAt": [f.get("starting_at") for f in fixtures],
        }
    )

    if df.empty:
        return df

    df["StartingAt"] = pd.to_datetime(df["StartingAt"], utc=True, errors="coerce")
    df = df[df["StartingAt"].between(now_utc, end_utc)].reset_index(drop=True)
    return df


# -------------------------
# Bookmaker ID -> Name lookup (cached)
# -------------------------
def _get_bookmaker_name(bookmaker_id: int | None, session: requests.Session, cache: dict[int, str]) -> str | None:
    """
    Resolve bookmaker_id to bookmaker name via /v3/odds/bookmakers/{ID}.
    Caches results to avoid repeated calls.
    """
    if bookmaker_id is None:
        return None

    try:
        bookmaker_id_int = int(bookmaker_id)
    except (TypeError, ValueError):
        return None

    if bookmaker_id_int in cache:
        return cache[bookmaker_id_int]

    r = session.get(
        f"{BOOKMAKER_URL}/{bookmaker_id_int}",
        params={"api_token": API_TOKEN},
        timeout=30,
    )
    if r.status_code == 404:
        return None
    r.raise_for_status()

    data = (r.json() or {}).get("data") or {}
    name = data.get("name")
    if isinstance(name, str) and name.strip():
        cache[bookmaker_id_int] = name.strip()
        return cache[bookmaker_id_int]

    return None


# -------------------------
# Odds (keep ONLY the fields used in your first version)
# -------------------------
def fetch_odds_prematch_for_fixture(
    fixture_id: int,
    session: requests.Session,
    bookmaker_cache: dict[int, str],
) -> list[dict]:
    """Pull odds for a single fixture and shape the columns we need (first-code schema)."""
    endpoint = f"/odds/pre-match/fixtures/{fixture_id}"

    r = session.get(
        f"{BASE_URL}{endpoint}",
        params={"api_token": API_TOKEN},
        timeout=30,
    )
    if r.status_code == 404:
        return []

    r.raise_for_status()
    odds = r.json().get("data") or []

    rows = []
    for odd in odds:
        bookmaker_id = odd.get("bookmaker_id")
        bookmaker_name = _get_bookmaker_name(bookmaker_id, session, bookmaker_cache)

        rows.append(
            {
                "OddID": odd.get("id"),
                "FixtureID": odd.get("fixture_id"),
                "MarketID": odd.get("market_id"),
                "Bookmaker": bookmaker_name,  # <-- filled reliably via bookmaker_id lookup
                "Market": odd.get("market_description"),
                "Label": odd.get("label"),
                "Name": odd.get("name"),
                "Value": odd.get("value"),
                "DP3": odd.get("dp3"),
                "Total": odd.get("total"),
                "Handicap": odd.get("handicap"),
                "LatestBookmakerUpdate": odd.get("latest_bookmaker_update"),
            }
        )

    return rows


def fetch_odds_next_12h() -> pd.DataFrame:
    fixtures_df = fetch_fixtures_next_12h()
    if fixtures_df.empty:
        return pd.DataFrame()

    session = requests.Session()
    bookmaker_cache: dict[int, str] = {}
    rows: list[dict] = []

    for fid in fixtures_df["FixtureID"].astype(int):
        rows.extend(fetch_odds_prematch_for_fixture(fid, session, bookmaker_cache))

    df = pd.DataFrame(rows)
    if df.empty:
        return df

    df = df.merge(fixtures_df, on="FixtureID", how="left")

    # Normalize types
    df["Odds"] = pd.to_numeric(df["Value"], errors="coerce")
    df["Total"] = pd.to_numeric(df["Total"], errors="coerce")
    df["Handicap"] = pd.to_numeric(df["Handicap"], errors="coerce")

    # Drop unusable odds (same spirit as your original)
    df = df.dropna(subset=["Odds", "MarketID", "Bookmaker", "Label", "StartingAt"]).reset_index(drop=True)

    return df


# -------------------------
# Example usage + valuebet scan
# -------------------------
df = fetch_odds_next_12h()

VALUEBET_THRESHOLD_PCT = 0.30  # 30% premium vs median => valuebet; tweak as needed

columns_to_show = [
    "StartingAt",
    "Fixture",
    "Bookmaker",
    "Market",
    "Label",
    "Odds",
    "Name",
    "Total",
    "Handicap",
    "LatestBookmakerUpdate",
]

if df.empty:
    results = pd.DataFrame()
    value_bets = pd.DataFrame()
else:
    group_keys = ["FixtureID", "MarketID", "Label", "Name", "Total", "Handicap"]

    # Keep one line per bookmaker per selection (latest row wins) so the median
    # isn't skewed by multiple prices from the same bookmaker.
    df = df.sort_values(group_keys + ["Bookmaker", "LatestBookmakerUpdate"])
    df = df.drop_duplicates(subset=group_keys + ["Bookmaker"], keep="last")

    grouped = df.groupby(group_keys, dropna=False)

    stats_median = grouped["Odds"].median().rename("OddsMedian")
    stats_bookmaker_count = grouped["Bookmaker"].nunique().rename("ComparedBookmakerCount")
    stats_bookmaker_list = grouped["Bookmaker"].agg(
        lambda x: sorted({b for b in x if isinstance(b, str) and b.strip()})
    ).rename("ComparedBookmakers")

    df = df.merge(stats_median, on=group_keys, how="left")
    df = df.merge(stats_bookmaker_count, on=group_keys, how="left")
    df = df.merge(stats_bookmaker_list, on=group_keys, how="left")

    df["OtherBookmakersCompared"] = df.apply(
        lambda row: [b for b in (row["ComparedBookmakers"] or []) if b != row["Bookmaker"]],
        axis=1,
    )
    df["OtherBookmakersCount"] = df["OtherBookmakersCompared"].apply(len)

    df["OddsVsMedian"] = df["Odds"] / df["OddsMedian"]
    df["OddsVsMedian"].replace([float("inf"), -float("inf")], pd.NA, inplace=True)
    df["ValueBetThresholdPct"] = VALUEBET_THRESHOLD_PCT
    df["IsValueBet"] = (df["ComparedBookmakerCount"] > 1) & (
        df["OddsVsMedian"] >= (1 + VALUEBET_THRESHOLD_PCT)
    )

    df["ComparedBookmakersStr"] = df["ComparedBookmakers"].apply(
        lambda lst: ", ".join(lst) if isinstance(lst, list) else None
    )
    df["OtherBookmakersComparedStr"] = df["OtherBookmakersCompared"].apply(
        lambda lst: ", ".join(lst) if lst else ""
    )

    display_cols = columns_to_show + [
        "OddsMedian",
        "OddsVsMedian",
        "ValueBetThresholdPct",
        "IsValueBet",
        "ComparedBookmakerCount",
        "OtherBookmakersCount",
        "OtherBookmakersComparedStr",
        "ComparedBookmakersStr",
    ]

    results = df[display_cols].copy()
    value_bets = df[df["IsValueBet"]][display_cols].copy()

# Inspect these in the notebook as needed:
# - results.head()
# - value_bets.head()
# Out:
# First 50 odds rows (with value flags and comparisons):
#                StartingAt       Fixture   Bookmaker                             Market              Label   Odds              Name  Total  Handicap LatestBookmakerUpdate  OddsMedian  OddsVsMedian  ValueBetThresholdPct  IsValueBet  ComparedBookmakerCount  OtherBookmakersCount                                                                                                                                         OtherBookmakersComparedStr                                                                                                                                                        ComparedBookmakersStr
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                         Team Shots                  1   1.83              None    NaN       NaN   2026-01-04 19:40:37       1.830      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                         Team Shots                  1   1.83              None    NaN       NaN   2026-01-04 19:40:37       1.830      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                 1st Half Goal Line              Under   1.72               1.0    1.0       NaN   2026-01-06 15:32:54       1.720      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365     Alternative 1st Half Goal Line              Under   1.67               1.0    1.0       NaN   2026-01-06 13:40:44       1.670      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                       Player Shots                4.5  11.00 Santiago Pierotti    NaN       NaN   2026-01-06 15:32:54      11.000      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                       Player Shots                4.5  21.00      Tete Morente    NaN       NaN   2026-01-06 15:32:54      21.000      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                        Goalscorers            Anytime   8.50      Muhammed Bah    NaN       NaN   2026-01-06 15:32:54       8.500      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                        Goalscorers              First  34.00      Corrie Ndaba    NaN       NaN   2026-01-06 15:32:54      34.000      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                        Goalscorers              First  41.00      Matias Perez    NaN       NaN   2026-01-06 15:32:54      41.000      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                        Goalscorers               Last  29.00     Jose Angelino    NaN       NaN   2026-01-06 15:32:54      29.000      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                      Multi Scorers          3 or More 501.00         Alex Sala    NaN       NaN   2026-01-06 15:32:54     501.000      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365      Player Headed Shots on Target                0.5  29.00         Alex Sala    NaN       NaN   2026-01-06 15:32:54      29.000      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365 Player Shots on Target Outside Box                0.5  26.00       Olaf Gorter    NaN       NaN   2026-01-06 15:32:54      26.000      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                   Last Goal Scorer               Last  15.00       Olaf Gorter    NaN       NaN   2026-01-06 15:32:54      15.000      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                   Last Goal Scorer               Last  15.00  Daniele Ghilardi    NaN       NaN   2026-01-06 15:32:54      15.000      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma Marathonbet                       HT/FT Double          Home/Draw  18.00         Home/Draw    NaN       NaN   2026-01-06 07:11:56      16.115      1.116972                   0.3       False                       6                     5                                                                                                                                10Bet, 1xbet, Pinnacle, Sbo, Unibet                                                                                                                             10Bet, 1xbet, Marathonbet, Pinnacle, Sbo, Unibet
# 2026-01-06 17:00:00+00:00 Lecce vs Roma       1xbet               Highest Scoring Half               Draw   3.38              Draw    NaN       NaN   2026-01-06 07:04:16       3.250      1.040000                   0.3       False                       3                     2                                                                                                                                                 10Bet, WilliamHill                                                                                                                                                    10Bet, 1xbet, WilliamHill
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                       Multicorners               Over   1.72              19.5    NaN       NaN   2026-01-06 15:32:54       1.720      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365            Half Time Correct Score                  1 351.00               3-2    NaN       NaN   2026-01-06 15:32:54     351.000      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                    Team Goalscorer              First  23.00      Matias Perez    NaN       NaN   2026-01-06 15:32:54      23.000      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                Player to be booked             Booked   3.40         Alex Sala    NaN       NaN   2026-01-06 15:32:54       3.400      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma       1xbet                      Correct Score                8:9 100.00               8:9    NaN       NaN   2026-01-06 03:28:24     100.000      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                           1xbet
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                   Half Time Result               Home   5.50              None    NaN       NaN   2026-01-06 15:32:54       5.500      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                      Multi Scorers          3 or More 501.00         Gaby Jean    NaN       NaN   2026-01-06 15:32:54     501.000      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                  1st Player Booked           1st Card  15.00      Danilo Veiga    NaN       NaN   2026-01-06 15:32:54      15.000      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                Player to be booked             Booked   6.50      Plamen Penev    NaN       NaN   2026-01-06 15:32:54       6.500      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365          Player to Score or Assist To Score or Assist   2.50       Leon Bailey    NaN       NaN   2026-01-06 15:32:54       2.500      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                    1st Goal Scorer              First   4.75      Matias Soule    NaN       NaN   2026-01-06 15:32:54       4.750      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                    1st Goal Scorer              First  13.00     Devyne Rensch    NaN       NaN   2026-01-06 15:32:54      13.000      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma       1xbet                           Odd/Even               Even   1.80              Even    NaN       NaN   2026-01-06 05:10:30       1.850      0.972973                   0.3       False                       7                     6                                                                                                             10Bet, 188Bet, Marathonbet, Pinnacle, Sbo, WilliamHill                                                                                                                10Bet, 188Bet, 1xbet, Marathonbet, Pinnacle, Sbo, WilliamHill
# 2026-01-06 17:00:00+00:00 Lecce vs Roma WilliamHill                  Odd/Even 1st Half               Even   1.65              Even    NaN       NaN   2025-12-31 17:19:40       1.650      1.000000                   0.3       False                       5                     4                                                                                                                                10Bet, 1xbet, Marathonbet, Pinnacle                                                                                                                             10Bet, 1xbet, Marathonbet, Pinnacle, WilliamHill
# 2026-01-06 17:00:00+00:00 Lecce vs Roma Marathonbet                  Odd/Even 1st Half               Even   1.61              Even    NaN       NaN   2026-01-06 05:10:16       1.650      0.975758                   0.3       False                       5                     4                                                                                                                                10Bet, 1xbet, Pinnacle, WilliamHill                                                                                                                             10Bet, 1xbet, Marathonbet, Pinnacle, WilliamHill
# 2026-01-06 17:00:00+00:00 Lecce vs Roma WilliamHill     Both Teams To Score - 2nd Half                Yes   4.00               Yes    NaN       NaN   2026-01-06 03:09:10       4.025      0.993789                   0.3       False                       4                     3                                                                                                                                          10Bet, 1xbet, Marathonbet                                                                                                                                       10Bet, 1xbet, Marathonbet, WilliamHill
# 2026-01-06 17:00:00+00:00 Lecce vs Roma WilliamHill     Both Teams To Score - 2nd Half                 No   1.20                No    NaN       NaN   2026-01-06 03:09:10       1.205      0.995851                   0.3       False                       4                     3                                                                                                                                          10Bet, 1xbet, Marathonbet                                                                                                                                       10Bet, 1xbet, Marathonbet, WilliamHill
# 2026-01-06 17:00:00+00:00 Lecce vs Roma Marathonbet     Both Teams To Score - 2nd Half                 No   1.20                No    NaN       NaN   2026-01-06 07:05:35       1.205      0.995851                   0.3       False                       4                     3                                                                                                                                          10Bet, 1xbet, WilliamHill                                                                                                                                       10Bet, 1xbet, Marathonbet, WilliamHill
# 2026-01-06 17:00:00+00:00 Lecce vs Roma    Pinnacle                       Total - Away              Under   1.81             Under    1.5       NaN   2026-01-06 06:55:56       1.770      1.022599                   0.3       False                       5                     4                                                                                                                                  10Bet, 1xbet, Marathonbet, Unibet                                                                                                                                  10Bet, 1xbet, Marathonbet, Pinnacle, Unibet
# 2026-01-06 17:00:00+00:00 Lecce vs Roma Interwetten                    Fulltime Result               Away   1.77              Away    NaN       NaN   2026-01-06 15:30:15       1.780      0.994382                   0.3       False                      19                    18    10Bet, 188Bet, 1xbet, 888Sport, Betfair, Betsson, CloudBet, Dafabet, HKJC, Ladbrokes, MansionBet, Marathonbet, MelBet, Pinnacle, Sbo, Unibet, WilliamHill, bwin 10Bet, 188Bet, 1xbet, 888Sport, Betfair, Betsson, CloudBet, Dafabet, HKJC, Interwetten, Ladbrokes, MansionBet, Marathonbet, MelBet, Pinnacle, Sbo, Unibet, WilliamHill, bwin
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                        Goalscorers            Anytime   9.50     Youssef Maleh    NaN       NaN   2026-01-06 15:32:54       9.500      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                       Corners Race            Neither   1.72                 7    NaN       NaN   2026-01-06 15:32:54       1.720      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                Both Teams to Score                Yes   2.05              None    NaN       NaN   2026-01-06 15:32:54       2.050      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                       Player Shots                0.5   2.25      Corrie Ndaba    NaN       NaN   2026-01-06 15:32:54       2.250      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                       Player Shots                4.5   8.00     Nikola Stulic    NaN       NaN   2026-01-06 15:32:54       8.000      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365 Player Shots on Target Outside Box                0.5   4.00       Leon Bailey    NaN       NaN   2026-01-06 15:32:54       4.000      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      bet365                         Team Shots                  2   1.90              None    NaN       NaN   2026-01-06 15:32:54       1.850      1.027027                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                          bet365
# 2026-01-06 17:00:00+00:00 Lecce vs Roma Marathonbet                     Asian Handicap               Away   6.25              Away    NaN      2.25   2026-01-06 07:11:56       6.250      1.000000                   0.3       False                       2                     1                                                                                                                                                              1xbet                                                                                                                                                           1xbet, Marathonbet
# 2026-01-06 17:00:00+00:00 Lecce vs Roma      Unibet                   Goals Over/Under               Over   1.38              Over    1.5       NaN   2026-01-06 03:09:49       1.400      0.985714                   0.3       False                       5                     4                                                                                                                                10Bet, 1xbet, Marathonbet, Pinnacle                                                                                                                                  10Bet, 1xbet, Marathonbet, Pinnacle, Unibet
# 2026-01-06 17:00:00+00:00 Lecce vs Roma WilliamHill          Goals Over/Under 2nd Half               Over  15.00              Over    3.5       NaN   2026-01-06 03:09:10      15.000      1.000000                   0.3       False                       2                     1                                                                                                                                                              1xbet                                                                                                                                                           1xbet, WilliamHill
# 2026-01-06 17:00:00+00:00 Lecce vs Roma       1xbet                       Total - Home               Over  15.50              Over    2.5       NaN   2026-01-06 05:28:19      15.500      1.000000                   0.3       False                       1                     0                                                                                                                                                                                                                                                                                                                                           1xbet
# 2026-01-06 17:00:00+00:00 Lecce vs Roma    888Sport                    Fulltime Result               Home   5.00              Home    NaN       NaN   2026-01-06 15:29:03       5.150      0.970874                   0.3       False                      19                    18 10Bet, 188Bet, 1xbet, Betfair, Betsson, CloudBet, Dafabet, HKJC, Interwetten, Ladbrokes, MansionBet, Marathonbet, MelBet, Pinnacle, Sbo, Unibet, WilliamHill, bwin 10Bet, 188Bet, 1xbet, 888Sport, Betfair, Betsson, CloudBet, Dafabet, HKJC, Interwetten, Ladbrokes, MansionBet, Marathonbet, MelBet, Pinnacle, Sbo, Unibet, WilliamHill, bwin
# 2026-01-06 17:00:00+00:00 Lecce vs Roma    888Sport                    Fulltime Result               Draw   3.30              Draw    NaN       NaN   2026-01-06 15:29:03       3.360      0.982143                   0.3       False                      19                    18 10Bet, 188Bet, 1xbet, Betfair, Betsson, CloudBet, Dafabet, HKJC, Interwetten, Ladbrokes, MansionBet, Marathonbet, MelBet, Pinnacle, Sbo, Unibet, WilliamHill, bwin 10Bet, 188Bet, 1xbet, 888Sport, Betfair, Betsson, CloudBet, Dafabet, HKJC, Interwetten, Ladbrokes, MansionBet, Marathonbet, MelBet, Pinnacle, Sbo, Unibet, WilliamHill, bwin
# Value bets found at threshold 30%: 200 rows
#                StartingAt                   Fixture   Bookmaker            Market     Label   Odds      Name  Total  Handicap LatestBookmakerUpdate  OddsMedian  OddsVsMedian  ValueBetThresholdPct  IsValueBet  ComparedBookmakerCount  OtherBookmakersCount                               OtherBookmakersComparedStr                                         ComparedBookmakersStr
# 2026-01-06 17:00:00+00:00             Lecce vs Roma      MelBet    Asian Handicap      Away   3.16      Away    NaN      -1.5   2026-01-06 15:29:59       2.090      1.511962                   0.3        True                       2                     1                                                    1xbet                                                 1xbet, MelBet
# 2026-01-06 17:00:00+00:00             Lecce vs Roma      bet365        Team Cards         1   2.50      None    NaN       NaN   2026-01-06 15:32:54       1.905      1.312336                   0.3        True                       1                     0                                                                                                                 bet365
# 2026-01-06 17:00:00+00:00             Lecce vs Roma      bet365  Team Total Goals         2  11.00      None    NaN       NaN   2026-01-06 15:32:54       1.860      5.913978                   0.3        True                       1                     0                                                                                                                 bet365
# 2026-01-06 17:00:00+00:00             Lecce vs Roma      bet365 Team Performances         1   4.75      None    NaN       NaN   2026-01-06 15:32:54       2.300      2.065217                   0.3        True                       1                     0                                                                                                                 bet365
# 2026-01-06 17:00:00+00:00             Lecce vs Roma      bet365 Team Performances         2   6.50      None    NaN       NaN   2026-01-06 15:32:54       2.235      2.908277                   0.3        True                       1                     0                                                                                                                 bet365
# 2026-01-06 17:00:00+00:00             Lecce vs Roma    Pinnacle     Correct Score       3:6 226.00       3:6    NaN       NaN   2026-01-06 06:55:45     163.000      1.386503                   0.3        True                       2                     1                                                    1xbet                                               1xbet, Pinnacle
# 2026-01-06 17:00:00+00:00             Lecce vs Roma    Pinnacle     Correct Score       4:5 251.00       4:5    NaN       NaN   2026-01-06 06:55:45     175.500      1.430199                   0.3        True                       2                     1                                                    1xbet                                               1xbet, Pinnacle
# 2026-01-06 17:00:00+00:00             Lecce vs Roma    Pinnacle     Correct Score       5:3 201.00       5:3    NaN       NaN   2026-01-06 06:55:45     150.500      1.335548                   0.3        True                       2                     1                                                    1xbet                                               1xbet, Pinnacle
# 2026-01-06 17:00:00+00:00             Lecce vs Roma    Pinnacle     Correct Score       7:1 226.00       7:1    NaN       NaN   2026-01-06 06:55:45     151.000      1.496689                   0.3        True                       3                     2                                       1xbet, WilliamHill                                  1xbet, Pinnacle, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma    Pinnacle     Correct Score       8:0 226.00       8:0    NaN       NaN   2026-01-06 06:55:45     151.000      1.496689                   0.3        True                       3                     2                                       1xbet, WilliamHill                                  1xbet, Pinnacle, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma    Pinnacle     Correct Score       0:8 226.00       0:8    NaN       NaN   2026-01-06 06:55:45     151.000      1.496689                   0.3        True                       3                     2                                       1xbet, WilliamHill                                  1xbet, Pinnacle, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma    Pinnacle     Correct Score       0:9 226.00       0:9    NaN       NaN   2026-01-06 06:55:45     151.000      1.496689                   0.3        True                       3                     2                                       1xbet, WilliamHill                                  1xbet, Pinnacle, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma    Pinnacle     Correct Score      0:10 226.00      0:10    NaN       NaN   2026-01-06 06:55:45     151.000      1.496689                   0.3        True                       3                     2                                       1xbet, WilliamHill                                  1xbet, Pinnacle, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma    Pinnacle     Correct Score       1:7 201.00       1:7    NaN       NaN   2026-01-06 06:55:45     151.000      1.331126                   0.3        True                       3                     2                                       1xbet, WilliamHill                                  1xbet, Pinnacle, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma    Pinnacle     Correct Score       1:8 301.00       1:8    NaN       NaN   2026-01-06 06:55:45     200.500      1.501247                   0.3        True                       2                     1                                                    1xbet                                               1xbet, Pinnacle
# 2026-01-06 17:00:00+00:00             Lecce vs Roma    Pinnacle     Correct Score       2:7 201.00       2:7    NaN       NaN   2026-01-06 06:55:45     150.500      1.335548                   0.3        True                       2                     1                                                    1xbet                                               1xbet, Pinnacle
# 2026-01-06 17:00:00+00:00             Lecce vs Roma    Pinnacle     Correct Score       2:8 201.00       2:8    NaN       NaN   2026-01-06 06:55:45     150.500      1.335548                   0.3        True                       2                     1                                                    1xbet                                               1xbet, Pinnacle
# 2026-01-06 17:00:00+00:00             Lecce vs Roma    Pinnacle     Correct Score       3:7 201.00       3:7    NaN       NaN   2026-01-06 06:55:45     150.500      1.335548                   0.3        True                       2                     1                                                    1xbet                                               1xbet, Pinnacle
# 2026-01-06 17:00:00+00:00             Lecce vs Roma         Sbo     Correct Score       3:0 100.84       3:0    NaN       NaN   2026-01-06 06:01:45      71.000      1.420282                   0.3        True                       7                     6 10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, WilliamHill 10Bet, 1xbet, Marathonbet, Pinnacle, Sbo, Unibet, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma         Sbo     Correct Score       3:2  76.84       3:2    NaN       NaN   2026-01-06 06:01:45      51.000      1.506667                   0.3        True                       7                     6 10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, WilliamHill 10Bet, 1xbet, Marathonbet, Pinnacle, Sbo, Unibet, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma         Sbo     Correct Score       4:0 240.04       4:0    NaN       NaN   2026-01-06 06:01:45     113.000      2.124248                   0.3        True                       4                     3                             1xbet, Pinnacle, WilliamHill                             1xbet, Pinnacle, Sbo, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma         Sbo     Correct Score       4:1 240.04       4:1    NaN       NaN   2026-01-06 06:01:45     101.000      2.376634                   0.3        True                       5                     4                      10Bet, 1xbet, Pinnacle, WilliamHill                      10Bet, 1xbet, Pinnacle, Sbo, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma         Sbo     Correct Score       2:3  36.52       2:3    NaN       NaN   2026-01-06 06:01:45      26.000      1.404615                   0.3        True                       7                     6 10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, WilliamHill 10Bet, 1xbet, Marathonbet, Pinnacle, Sbo, Unibet, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma         Sbo     Correct Score       3:3 144.04       3:3    NaN       NaN   2026-01-06 06:01:45      76.000      1.895263                   0.3        True                       7                     6 10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, WilliamHill 10Bet, 1xbet, Marathonbet, Pinnacle, Sbo, Unibet, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma         Sbo     Correct Score       0:4  38.44       0:4    NaN       NaN   2026-01-06 06:01:45      26.000      1.478462                   0.3        True                       7                     6 10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, WilliamHill 10Bet, 1xbet, Marathonbet, Pinnacle, Sbo, Unibet, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma         Sbo     Correct Score       1:4  42.28       1:4    NaN       NaN   2026-01-06 06:01:45      31.000      1.363871                   0.3        True                       7                     6 10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, WilliamHill 10Bet, 1xbet, Marathonbet, Pinnacle, Sbo, Unibet, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma         Sbo     Correct Score       4:2 240.04       4:2    NaN       NaN   2026-01-06 06:01:45     126.000      1.905079                   0.3        True                       5                     4                      10Bet, 1xbet, Pinnacle, WilliamHill                      10Bet, 1xbet, Pinnacle, Sbo, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma         Sbo     Correct Score       3:4 240.04       3:4    NaN       NaN   2026-01-06 06:01:45     101.000      2.376634                   0.3        True                       5                     4                      10Bet, 1xbet, Pinnacle, WilliamHill                      10Bet, 1xbet, Pinnacle, Sbo, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma         Sbo     Correct Score       4:3 240.04       4:3    NaN       NaN   2026-01-06 06:01:45     151.000      1.589669                   0.3        True                       4                     3                             1xbet, Pinnacle, WilliamHill                             1xbet, Pinnacle, Sbo, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma         Sbo     Correct Score       4:4 240.04       4:4    NaN       NaN   2026-01-06 06:01:45     163.500      1.468135                   0.3        True                       4                     3                             1xbet, Pinnacle, WilliamHill                             1xbet, Pinnacle, Sbo, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma       1xbet     Correct Score       1:5 100.00       1:5    NaN       NaN   2026-01-06 03:28:24      71.000      1.408451                   0.3        True                       6                     5        10Bet, Marathonbet, Pinnacle, Unibet, WilliamHill      10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma Marathonbet      HT/FT Double Home/Away  31.00 Home/Away    NaN       NaN   2026-01-06 07:11:56      23.430      1.323090                   0.3        True                       6                     5                      10Bet, 1xbet, Pinnacle, Sbo, Unibet              10Bet, 1xbet, Marathonbet, Pinnacle, Sbo, Unibet
# 2026-01-06 17:00:00+00:00             Lecce vs Roma Marathonbet      HT/FT Double Away/Home  61.00 Away/Home    NaN       NaN   2026-01-06 07:11:56      43.465      1.403428                   0.3        True                       6                     5                      10Bet, 1xbet, Pinnacle, Sbo, Unibet              10Bet, 1xbet, Marathonbet, Pinnacle, Sbo, Unibet
# 2026-01-06 17:00:00+00:00             Lecce vs Roma       1xbet      HT/FT Double Home/Away  31.00 Home/Away    NaN       NaN   2026-01-06 07:12:53      23.430      1.323090                   0.3        True                       6                     5                10Bet, Marathonbet, Pinnacle, Sbo, Unibet              10Bet, 1xbet, Marathonbet, Pinnacle, Sbo, Unibet
# 2026-01-06 17:00:00+00:00             Lecce vs Roma       1xbet      HT/FT Double Away/Home  60.00 Away/Home    NaN       NaN   2026-01-06 07:12:53      43.465      1.380421                   0.3        True                       6                     5                10Bet, Marathonbet, Pinnacle, Sbo, Unibet              10Bet, 1xbet, Marathonbet, Pinnacle, Sbo, Unibet
# 2026-01-06 17:00:00+00:00             Lecce vs Roma    Pinnacle   Handicap Result      Home  15.70      Home    NaN      -1.0   2026-01-06 06:55:56      11.500      1.365217                   0.3        True                       4                     3                               10Bet, Marathonbet, Unibet                          10Bet, Marathonbet, Pinnacle, Unibet
# 2026-01-06 17:00:00+00:00             Lecce vs Roma Marathonbet     Correct Score       2:3  35.00       2:3    NaN       NaN   2026-01-06 06:19:45      26.000      1.346154                   0.3        True                       7                     6         10Bet, 1xbet, Pinnacle, Sbo, Unibet, WilliamHill 10Bet, 1xbet, Marathonbet, Pinnacle, Sbo, Unibet, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma    Pinnacle     Correct Score       6:0 226.00       6:0    NaN       NaN   2026-01-06 06:55:45     151.000      1.496689                   0.3        True                       3                     2                                       1xbet, WilliamHill                                  1xbet, Pinnacle, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma    Pinnacle     Correct Score       6:1 251.00       6:1    NaN       NaN   2026-01-06 06:55:45     151.000      1.662252                   0.3        True                       3                     2                                       1xbet, WilliamHill                                  1xbet, Pinnacle, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma    Pinnacle     Correct Score       6:2 201.00       6:2    NaN       NaN   2026-01-06 06:55:45     151.000      1.331126                   0.3        True                       3                     2                                       1xbet, WilliamHill                                  1xbet, Pinnacle, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma      bet365  Team Total Goals         2   4.33      None    NaN       NaN   2026-01-06 15:32:54       1.860      2.327957                   0.3        True                       1                     0                                                                                                                 bet365
# 2026-01-06 17:00:00+00:00             Lecce vs Roma      bet365  Team Total Goals         2  26.00      None    NaN       NaN   2026-01-06 15:32:54       1.860     13.978495                   0.3        True                       1                     0                                                                                                                 bet365
# 2026-01-06 17:00:00+00:00             Lecce vs Roma      bet365  Team Total Goals         2   4.33      None    NaN       NaN   2026-01-06 15:32:54       1.860      2.327957                   0.3        True                       1                     0                                                                                                                 bet365
# 2026-01-06 17:00:00+00:00             Lecce vs Roma    Pinnacle     Correct Score       7:0 226.00       7:0    NaN       NaN   2026-01-06 06:55:45     151.000      1.496689                   0.3        True                       3                     2                                       1xbet, WilliamHill                                  1xbet, Pinnacle, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma         Sbo     Correct Score       2:4  91.24       2:4    NaN       NaN   2026-01-06 06:01:45      67.000      1.361791                   0.3        True                       7                     6 10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, WilliamHill 10Bet, 1xbet, Marathonbet, Pinnacle, Sbo, Unibet, WilliamHill
# 2026-01-06 17:00:00+00:00             Lecce vs Roma      bet365 Team Performances         2   7.00      None    NaN       NaN   2026-01-06 12:50:57       2.235      3.131991                   0.3        True                       1                     0                                                                                                                 bet365
# 2026-01-06 17:00:00+00:00             Lecce vs Roma      bet365  Team Total Goals         1  51.00      None    NaN       NaN   2026-01-06 15:32:54       1.880     27.127660                   0.3        True                       1                     0                                                                                                                 bet365
# 2026-01-06 17:00:00+00:00             Lecce vs Roma      bet365  Team Total Goals         1   4.33      None    NaN       NaN   2026-01-06 15:32:54       1.880      2.303191                   0.3        True                       1                     0                                                                                                                 bet365
# 2026-01-06 17:00:00+00:00             Lecce vs Roma      bet365  Team Total Goals         1  15.00      None    NaN       NaN   2026-01-06 15:32:54       1.880      7.978723                   0.3        True                       1                     0                                                                                                                 bet365
# 2026-01-06 18:00:00+00:00 Granada vs Rayo Vallecano         Sbo     Correct Score       0:4  62.44       0:4    NaN       NaN   2026-01-06 07:01:58      37.710      1.655794                   0.3        True                       7                     6 10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, WilliamHill 10Bet, 1xbet, Marathonbet, Pinnacle, Sbo, Unibet, WilliamHill
