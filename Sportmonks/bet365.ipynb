# %%
import re
import requests
import pandas as pd
from datetime import datetime, timedelta, timezone

API_TOKEN = "guthxAv1rvKshVf1XgEeNbVGvXX2V1aDzDVhlmj98EaaF6akBm6fEts7IbEJ"
BASE_URL = "https://api.sportmonks.com/v3/football"
BOOKMAKER_URL = "https://api.sportmonks.com/v3/odds/bookmakers"  # bookmaker lookup is under /v3/odds/...

BET365_NAME = "bet365"  # we will match case-insensitively


# -------------------------
# Text helpers
# -------------------------
def _norm(s) -> str:
    if s is None:
        return ""
    s = str(s).lower().strip()
    s = re.sub(r"\s+", " ", s)
    return s


# -------------------------
# Fixtures (next X hours)
# -------------------------
def fetch_fixtures_next_hours(hours: int = 20) -> pd.DataFrame:
    now_utc = datetime.now(timezone.utc)
    end_utc = now_utc + timedelta(hours=hours)

    start_date = now_utc.date()
    end_date = (now_utc + timedelta(days=1)).date()
    endpoint = f"/fixtures/between/{start_date:%Y-%m-%d}/{end_date:%Y-%m-%d}"

    session = requests.Session()
    fixtures = []
    page = 1

    while True:
        r = session.get(
            f"{BASE_URL}{endpoint}",
            params={"api_token": API_TOKEN, "page": page},
            timeout=30,
        )
        r.raise_for_status()
        payload = r.json()

        fixtures.extend(payload.get("data") or [])

        pagination = ((payload.get("meta") or {}).get("pagination")) or {}
        has_more = pagination.get("has_more")
        total_pages = pagination.get("total_pages")
        current_page = pagination.get("current_page")

        if has_more is False:
            break
        if total_pages is not None and current_page is not None and int(current_page) >= int(total_pages):
            break
        if has_more is None and (total_pages is None or current_page is None):
            break

        page += 1

    df = pd.DataFrame(
        {
            "FixtureID": [f.get("id") for f in fixtures],
            "Fixture": [f.get("name") for f in fixtures],
            "StartingAt": [f.get("starting_at") for f in fixtures],
        }
    )

    if df.empty:
        return df

    df["StartingAt"] = pd.to_datetime(df["StartingAt"], utc=True, errors="coerce")
    df = df[df["StartingAt"].between(now_utc, end_utc)].reset_index(drop=True)
    return df


# -------------------------
# Bookmaker ID -> Name lookup (cached)
# -------------------------
def _get_bookmaker_name(bookmaker_id: int | None, session: requests.Session, cache: dict[int, str]) -> str | None:
    if bookmaker_id is None:
        return None

    try:
        bookmaker_id_int = int(bookmaker_id)
    except (TypeError, ValueError):
        return None

    if bookmaker_id_int in cache:
        return cache[bookmaker_id_int]

    r = session.get(
        f"{BOOKMAKER_URL}/{bookmaker_id_int}",
        params={"api_token": API_TOKEN},
        timeout=30,
    )
    if r.status_code == 404:
        return None
    r.raise_for_status()

    data = (r.json() or {}).get("data") or {}
    name = data.get("name")
    if isinstance(name, str) and name.strip():
        cache[bookmaker_id_int] = name.strip()
        return cache[bookmaker_id_int]

    return None


# -------------------------
# Odds fetch (bet365 only)
# -------------------------
def fetch_odds_prematch_for_fixture_bet365_only(
    fixture_id: int,
    session: requests.Session,
    bookmaker_cache: dict[int, str],
) -> list[dict]:
    endpoint = f"/odds/pre-match/fixtures/{fixture_id}"

    r = session.get(
        f"{BASE_URL}{endpoint}",
        params={"api_token": API_TOKEN},
        timeout=30,
    )
    if r.status_code == 404:
        return []

    r.raise_for_status()
    odds = r.json().get("data") or []

    rows = []
    for odd in odds:
        bookmaker_id = odd.get("bookmaker_id")
        bookmaker_name = _get_bookmaker_name(bookmaker_id, session, bookmaker_cache)

        # Keep only bet365 (case-insensitive match)
        if _norm(bookmaker_name) != BET365_NAME:
            continue

        rows.append(
            {
                "OddID": odd.get("id"),
                "FixtureID": odd.get("fixture_id"),
                "MarketID": odd.get("market_id"),
                "BookmakerID": bookmaker_id,
                "Bookmaker": bookmaker_name,

                "Market": odd.get("market_description"),
                "Label": odd.get("label"),
                "Name": odd.get("name"),

                "Value": odd.get("value"),
                "DP3": odd.get("dp3"),
                "Total": odd.get("total"),
                "Handicap": odd.get("handicap"),

                "Participants": odd.get("participants"),
                "LatestBookmakerUpdate": odd.get("latest_bookmaker_update"),
            }
        )

    return rows


def fetch_bet365_odds_next_hours(hours: int = 20) -> pd.DataFrame:
    fixtures_df = fetch_fixtures_next_hours(hours=hours)
    if fixtures_df.empty:
        return pd.DataFrame()

    session = requests.Session()
    bookmaker_cache: dict[int, str] = {}
    rows: list[dict] = []

    for fid in fixtures_df["FixtureID"].astype(int):
        rows.extend(fetch_odds_prematch_for_fixture_bet365_only(fid, session, bookmaker_cache))

    df = pd.DataFrame(rows)
    if df.empty:
        return df

    df = df.merge(fixtures_df, on="FixtureID", how="left")

    # Normalize numeric fields
    df["Odds"] = pd.to_numeric(df["Value"], errors="coerce")
    df["Total"] = pd.to_numeric(df["Total"], errors="coerce")
    df["Handicap"] = pd.to_numeric(df["Handicap"], errors="coerce")

    # Drop unusable odds rows
    df = df.dropna(subset=["Odds", "Bookmaker", "StartingAt"]).reset_index(drop=True)

    return df


# -------------------------
# Example usage
# -------------------------
df_bet365 = fetch_bet365_odds_next_hours(hours=20)

print(f"Rows from bet365: {len(df_bet365)}")
print(df_bet365[[
    "StartingAt", "Fixture", "Bookmaker", "Market", "Label", "Name",
    "Odds", "Total", "Handicap", "LatestBookmakerUpdate"
]].head(50))

cols_to_drop = [
    "OddID",
    "FixtureID",
    "MarketID",
    "BookmakerID",
    "DP3",
    "Participants",
    "Value",
]

df_bet365 = df_bet365.drop(
    columns=[c for c in cols_to_drop if c in df_bet365.columns],
    errors="ignore"
)

# Save to CSV if you want
df_bet365.to_csv("bet365_odds.csv", index=False, encoding="utf-8")
print("Saved bet365_odds.csv")
# Out:
# Rows from bet365: 28230
#                   StartingAt              Fixture Bookmaker  \
# 0  2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 1  2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 2  2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 3  2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 4  2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 5  2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 6  2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 7  2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 8  2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 9  2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 10 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 11 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 12 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 13 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 14 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 15 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 16 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 17 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 18 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 19 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 20 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 21 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 22 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 23 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 24 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 25 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 26 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 27 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 28 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 29 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 30 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 31 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 32 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 33 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 34 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 35 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 36 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 37 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 38 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 39 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 40 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 41 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 42 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 43 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 44 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 45 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 46 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 47 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 48 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
# 49 2026-01-07 17:30:00+00:00  Bologna vs Atalanta    bet365
#
#                             Market             Label                  Name  \
# 0                     Player Shots               1.5          Henry Camara
# 1                    Correct Score                 1                   6-0
# 2                     Player Shots               0.5         Nicolo Casale
# 3              Player to be booked            Booked           Jhon Lucumi
# 4                     Player Shots               1.5          Remo Freuler
# 5                     Player Shots               1.5         Ciro Immobile
# 6                     Player Shots               1.5        Marten de Roon
# 7                    Card Handicap                 2                  None
# 8                      Goalscorers             First             Emil Holm
# 9              Alternative Corners           Exactly                    14
# 10  Away Team Highest Scoring Half               Tie                  None
# 11                    Player Shots               0.5        Tommaso Pobega
# 12                    Player Shots               3.5             Emil Holm
# 13            Exact 2nd Half Goals          5+ Goals                  None
# 14                 Team Goalscorer              Last          Henry Camara
# 15             Player to be booked            Booked          Martin Vitik
# 16             Alternative Corners              Over                     6
# 17                    Player Shots               0.5       Torbjorn Heggem
# 18                Player to Assist            Assist        Thijs Dallinga
# 19                Player to Assist            Assist             Emil Holm
# 20     Time of First Goal Brackets              1-10                  None
# 21                       Late Goal  Goal after 73:59                  None
# 22  Home Team Highest Scoring Half          1st Half                  None
# 23   Player Headed Shots on Target               1.5          Jens Odgaard
# 24          Player Shots On Target               0.5          Jens Odgaard
# 25           Time of 1st Team Goal                 1                  None
# 26           Time of 1st Team Goal                 1                  None
# 27          Player Shots On Target               1.5        Thijs Dallinga
# 28                    Player Shots               2.5          Remo Freuler
# 29           Alternative Goal Line              Over                   2.0
# 30                 2nd Half Result              Home                  None
# 31                     Goalscorers             First          Juan Miranda
# 32                   Multi Scorers         3 or More           Relja Obric
# 33               1st Player Booked          1st Card           Pietro Comi
# 34                    Player Shots               1.5        Lewis Ferguson
# 35                    Player Shots               1.5  Lorenzo De Silvestri
# 36             First Card Received           No Card                  None
# 37                 2nd Half Result              Away                  None
# 38                    Player Shots               0.5     Gianluca Scamacca
# 39          Player Shots On Target               0.5          Henry Camara
# 40                    Player Shots               0.5         Honest Ahanor
# 41                   Correct Score                 1                   5-3
# 42                     Goalscorers           Anytime     Marco Brescianini
# 43                    Player Shots               3.5         Jonathan Rowe
# 44                 Team Goalscorer              Last           Pietro Comi
# 45   Player Headed Shots on Target               1.5       Nikola Krstovic
# 46                 Player to Score             Score          Juan Miranda
# 47                Player to Assist            Assist           Jhon Lucumi
# 48                    Player Shots               2.5     Marco Brescianini
# 49               Exact Total Goals           4 Goals                  None
#
#       Odds  Total  Handicap LatestBookmakerUpdate
# 0     1.28    NaN       NaN   2026-01-05 15:40:16
# 1   501.00    NaN       NaN   2026-01-07 11:50:14
# 2     1.66    NaN       NaN   2026-01-07 11:50:14
# 3     3.60    NaN       NaN   2026-01-07 11:50:14
# 4     5.00    NaN       NaN   2026-01-07 11:50:14
# 5     1.04    NaN       NaN   2026-01-05 15:40:16
# 6     4.00    NaN       NaN   2026-01-05 15:40:16
# 7     1.90    NaN       0.0   2026-01-07 11:50:14
# 8    17.00    NaN       NaN   2026-01-07 11:50:14
# 9    19.00   14.0       NaN   2026-01-07 11:50:14
# 10    2.30    NaN       NaN   2026-01-07 11:50:14
# 11    1.14    NaN       NaN   2026-01-05 15:40:16
# 12   15.00    NaN       NaN   2026-01-05 15:40:16
# 13   29.00    NaN       NaN   2026-01-07 11:50:14
# 14    4.00    NaN       NaN   2026-01-07 11:50:14
# 15    4.75    NaN       NaN   2026-01-07 11:50:14
# 16    1.20    6.0       NaN   2026-01-07 11:50:14
# 17    2.25    NaN       NaN   2026-01-05 15:40:16
# 18   10.00    NaN       NaN   2026-01-07 11:50:14
# 19    9.00    NaN       NaN   2026-01-07 11:50:14
# 20    4.50    NaN       NaN   2026-01-07 11:50:14
# 21    1.83    NaN       NaN   2026-01-07 11:50:14
# 22    3.60    NaN       NaN   2026-01-07 11:50:14
# 23   29.00    NaN       NaN   2026-01-07 11:50:14
# 24    1.40    NaN       NaN   2026-01-05 14:01:34
# 25    1.83    NaN       NaN   2026-01-06 22:20:34
# 26    1.83    NaN       NaN   2026-01-06 22:20:34
# 27    3.00    NaN       NaN   2026-01-05 14:01:34
# 28   15.00    NaN       NaN   2026-01-05 15:40:16
# 29    1.47    2.0       NaN   2026-01-07 11:50:14
# 30    3.00    NaN       NaN   2026-01-07 11:50:14
# 31   23.00    NaN       NaN   2026-01-07 11:50:14
# 32  401.00    NaN       NaN   2026-01-07 11:50:14
# 33   21.00    NaN       NaN   2026-01-07 11:50:14
# 34    2.20    NaN       NaN   2026-01-07 11:50:14
# 35    8.00    NaN       NaN   2026-01-07 11:50:14
# 36   21.00    NaN       NaN   2026-01-07 11:50:14
# 37    2.75    NaN       NaN   2026-01-07 11:50:14
# 38    1.04    NaN       NaN   2026-01-07 11:50:14
# 39    1.44    NaN       NaN   2026-01-05 14:01:34
# 40    1.83    NaN       NaN   2026-01-05 15:40:16
# 41  301.00    NaN       NaN   2026-01-07 11:50:14
# 42    4.00    NaN       NaN   2026-01-07 11:50:14
# 43    4.33    NaN       NaN   2026-01-07 11:50:14
# 44   19.00    NaN       NaN   2026-01-07 11:50:14
# 45   11.00    NaN       NaN   2026-01-07 11:50:14
# 46    9.00    NaN       NaN   2026-01-07 11:50:14
# 47   17.00    NaN       NaN   2026-01-07 11:50:14
# 48    2.50    NaN       NaN   2026-01-05 15:40:16
# 49    6.00    NaN       NaN   2026-01-07 11:50:14
# Saved bet365_odds.csv
