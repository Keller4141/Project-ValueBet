# %%
import requests
import pandas as pd
from datetime import datetime, timedelta, timezone

API_TOKEN = "KuQ4Rt1ypOCvXfcm3cZXdPhOUlbuOrpHBgJkFm1MWTvtRR8TLhgEI02hjDxz"
BASE_URL = "https://api.sportmonks.com/v3/football"


# -------------------------
# Fixtures (next 12 hours)
# -------------------------
def fetch_fixtures_next_12h() -> pd.DataFrame:
    now_utc = datetime.now(timezone.utc)
    end_utc = now_utc + timedelta(hours=12)

    start_date = now_utc.date()
    end_date = (now_utc + timedelta(days=1)).date()
    endpoint = f"/fixtures/between/{start_date:%Y-%m-%d}/{end_date:%Y-%m-%d}"

    session = requests.Session()
    fixtures = []
    page = 1

    while True:
        r = session.get(
            f"{BASE_URL}{endpoint}",
            params={"api_token": API_TOKEN, "page": page},
            timeout=30,
        )
        r.raise_for_status()
        payload = r.json()

        fixtures.extend(payload.get("data") or [])

        pagination = ((payload.get("meta") or {}).get("pagination")) or {}
        if pagination.get("current_page") is None or pagination.get("current_page") >= pagination.get("total_pages", 0):
            break
        page += 1

    df = pd.DataFrame(
        {
            "FixtureID": [f.get("id") for f in fixtures],
            "Fixture": [f.get("name") for f in fixtures],
            "StartingAt": [f.get("starting_at") for f in fixtures],
        }
    )

    if df.empty:
        return df

    df["StartingAt"] = pd.to_datetime(df["StartingAt"], utc=True, errors="coerce")
    df = df[df["StartingAt"].between(now_utc, end_utc)].reset_index(drop=True)
    return df


# -------------------------
# Odds (schema-faithful)
# -------------------------
def fetch_odds_prematch_for_fixture(fixture_id: int, session: requests.Session) -> list[dict]:
    endpoint = f"/odds/pre-match/fixtures/{fixture_id}"

    r = session.get(
        f"{BASE_URL}{endpoint}",
        params={"api_token": API_TOKEN},
        timeout=30,
    )
    if r.status_code == 404:
        return []

    r.raise_for_status()
    odds = r.json().get("data") or []

    rows = []
    for odd in odds:
        rows.append(
            {
                # Core identifiers
                "OddID": odd.get("id"),
                "FixtureID": odd.get("fixture_id"),
                "MarketID": odd.get("market_id"),
                "BookmakerID": odd.get("bookmaker_id"),

                # Descriptions
                "MarketDescription": odd.get("market_description"),
                "Label": odd.get("label"),
                "Name": odd.get("name"),

                # Prices
                "Value": odd.get("value"),
                "Probability": odd.get("probability"),
                "DP3": odd.get("dp3"),
                "Fractional": odd.get("fractional"),
                "American": odd.get("american"),

                # Result state
                "Winning": odd.get("winning"),
                "Stopped": odd.get("stopped"),

                # Line information
                "Total": odd.get("total"),
                "Handicap": odd.get("handicap"),

                # Player / participants
                "Participants": odd.get("participants"),

                # Metadata
                "LatestBookmakerUpdate": odd.get("latest_bookmaker_update"),
            }
        )

    return rows


# -------------------------
# Combined fetch
# -------------------------
def fetch_odds_next_12h() -> pd.DataFrame:
    fixtures_df = fetch_fixtures_next_12h()
    if fixtures_df.empty:
        return pd.DataFrame()

    session = requests.Session()
    rows = []

    for fid in fixtures_df["FixtureID"].astype(int):
        rows.extend(fetch_odds_prematch_for_fixture(fid, session))

    df = pd.DataFrame(rows)
    if df.empty:
        return df

    # Join fixture metadata
    df = df.merge(fixtures_df, on="FixtureID", how="left")

    # ---- Type normalization (non-destructive) ----
    df["Odds"] = pd.to_numeric(df["Value"], errors="coerce")
    df["Total"] = pd.to_numeric(df["Total"], errors="coerce")
    df["Handicap"] = pd.to_numeric(df["Handicap"], errors="coerce")

    df["Probability"] = pd.to_numeric(df["Probability"], errors="coerce")
    df["DP3"] = pd.to_numeric(df["DP3"], errors="coerce")

    # Keep original string formats too (fractional / american untouched)

    # Drop unusable odds
    df = df.dropna(subset=["Odds", "MarketID", "BookmakerID", "Label", "StartingAt"]).reset_index(drop=True)

    return df


# -------------------------
# Example usage
# -------------------------
df = fetch_odds_next_12h()

df[
    [
        "Fixture",
        "StartingAt",
        "MarketDescription",
        "Label",
        "Odds",
        "Total",
        "Handicap",
        "Participants",
        "BookmakerID",
        "Probability",
        "Fractional",
        "American",
        "Winning",
        "Stopped",
        "LatestBookmakerUpdate",
    ]
].head(50)
# Out:
#           Fixture                StartingAt  \
# 0   Lecce vs Roma 2026-01-06 17:00:00+00:00
# 1   Lecce vs Roma 2026-01-06 17:00:00+00:00
# 2   Lecce vs Roma 2026-01-06 17:00:00+00:00
# 3   Lecce vs Roma 2026-01-06 17:00:00+00:00
# 4   Lecce vs Roma 2026-01-06 17:00:00+00:00
# 5   Lecce vs Roma 2026-01-06 17:00:00+00:00
# 6   Lecce vs Roma 2026-01-06 17:00:00+00:00
# 7   Lecce vs Roma 2026-01-06 17:00:00+00:00
# 8   Lecce vs Roma 2026-01-06 17:00:00+00:00
# 9   Lecce vs Roma 2026-01-06 17:00:00+00:00
# 10  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 11  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 12  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 13  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 14  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 15  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 16  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 17  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 18  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 19  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 20  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 21  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 22  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 23  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 24  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 25  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 26  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 27  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 28  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 29  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 30  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 31  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 32  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 33  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 34  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 35  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 36  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 37  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 38  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 39  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 40  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 41  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 42  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 43  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 44  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 45  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 46  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 47  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 48  Lecce vs Roma 2026-01-06 17:00:00+00:00
# 49  Lecce vs Roma 2026-01-06 17:00:00+00:00
#
#                      MarketDescription               Label    Odds  Total  \
# 0                           Team Shots                   1    1.83    NaN
# 1                           Team Shots                   1    1.83    NaN
# 2                   1st Half Goal Line               Under    1.72    1.0
# 3       Alternative 1st Half Goal Line               Under    1.67    1.0
# 4                         Player Shots                 4.5   11.00    NaN
# 5                         Player Shots                 4.5   21.00    NaN
# 6                          Goalscorers             Anytime    8.50    NaN
# 7                          Goalscorers               First   34.00    NaN
# 8                          Goalscorers               First   41.00    NaN
# 9                          Goalscorers                Last   29.00    NaN
# 10                       Multi Scorers           3 or More  501.00    NaN
# 11       Player Headed Shots on Target                 0.5   29.00    NaN
# 12  Player Shots on Target Outside Box                 0.5   26.00    NaN
# 13                    Last Goal Scorer                Last   15.00    NaN
# 14                    Last Goal Scorer                Last   15.00    NaN
# 15                        HT/FT Double           Home/Draw   18.00    NaN
# 16                Highest Scoring Half                Draw    3.38    NaN
# 17                        Multicorners                Over    1.72    NaN
# 18             Half Time Correct Score                   1  351.00    NaN
# 19                     Team Goalscorer               First   23.00    NaN
# 20                 Player to be booked              Booked    3.40    NaN
# 21                       Correct Score                 8:9  100.00    NaN
# 22                    Half Time Result                Home    5.50    NaN
# 23                       Multi Scorers           3 or More  501.00    NaN
# 24                   1st Player Booked            1st Card   15.00    NaN
# 25                 Player to be booked              Booked    6.50    NaN
# 26           Player to Score or Assist  To Score or Assist    2.50    NaN
# 27                     1st Goal Scorer               First    4.75    NaN
# 28                     1st Goal Scorer               First   13.00    NaN
# 29                            Odd/Even                Even    1.80    NaN
# 30                   Odd/Even 1st Half                Even    1.65    NaN
# 31                   Odd/Even 1st Half                Even    1.61    NaN
# 32      Both Teams To Score - 2nd Half                 Yes    4.00    NaN
# 33      Both Teams To Score - 2nd Half                  No    1.20    NaN
# 34      Both Teams To Score - 2nd Half                  No    1.20    NaN
# 35                        Total - Away               Under    1.84    1.5
# 36                     Fulltime Result                Away    1.75    NaN
# 37                         Goalscorers             Anytime    9.50    NaN
# 38                  1st Half Goal Line                Over    2.07    1.0
# 39      Alternative 1st Half Goal Line                Over    7.00    2.0
# 40      Alternative 1st Half Goal Line               Under    1.35    1.5
# 41      Alternative 1st Half Goal Line               Under    1.22    NaN
# 42      Alternative 1st Half Goal Line               Under    1.10    2.0
# 43                   Asian Total Cards               Under    1.87    4.0
# 44            Number of Cards In Match                Over    1.61    3.5
# 45            Number of Cards In Match               Under    2.20    3.5
# 46                 First Card Received             No Card   21.00    NaN
# 47                 Alternative Corners             Exactly   13.00   13.0
# 48                 Alternative Corners             Exactly   17.00   14.0
# 49                 Alternative Corners             Exactly   21.00   15.0
#
#     Handicap Participants  BookmakerID  Probability Fractional American  \
# 0        NaN         None            2          NaN       11/6     -121
# 1        NaN         None            2          NaN       11/6     -121
# 2        NaN         None            2          NaN      50/29     -138
# 3        NaN         None            2          NaN      57/34     -149
# 4        NaN         None            2          NaN         11     1000
# 5        NaN         None            2          NaN         21     2000
# 6        NaN         None            2          NaN       17/2      750
# 7        NaN         None            2          NaN         34     3300
# 8        NaN         None            2          NaN         41     4000
# 9        NaN         None            2          NaN         29     2800
# 10       NaN         None            2          NaN        501    50000
# 11       NaN         None            2          NaN         29     2800
# 12       NaN         None            2          NaN         26     2500
# 13       NaN         None            2          NaN         15     1400
# 14       NaN         None            2          NaN         15     1400
# 15       NaN         None           16          NaN         18     1700
# 16       NaN         None           35          NaN      71/21      238
# 17       NaN         None            2          NaN      19/11     -138
# 18       NaN         None            2          NaN        351    35000
# 19       NaN         None            2          NaN         23     2200
# 20       NaN         None            2          NaN       17/5      240
# 21       NaN         None           35          NaN        100     9900
# 22       NaN         None            2          NaN       11/2      450
# 23       NaN         None            2          NaN        501    50000
# 24       NaN         None            2          NaN         15     1400
# 25       NaN         None            2          NaN       13/2      550
# 26       NaN         None            2          NaN        5/2      150
# 27       NaN         None            2          NaN       19/4      375
# 28       NaN         None            2          NaN         13     1200
# 29       NaN         None           35          NaN        9/5     -125
# 30       NaN         None           29          NaN      33/20     -154
# 31       NaN         None           16          NaN      29/18     -164
# 32       NaN         None           29          NaN          4      300
# 33       NaN         None           29          NaN        6/5     -501
# 34       NaN         None           16          NaN        6/5     -501
# 35       NaN         None           20          NaN      46/25     -120
# 36       NaN         None           27          NaN        7/4     -134
# 37       NaN         None            2          NaN       19/2      850
# 38       NaN         None            2          NaN      27/13      107
# 39       NaN         None            2          NaN          7      600
# 40       NaN         None            2          NaN      27/20     -286
# 41       NaN         None            2          NaN      38/31     -445
# 42       NaN         None            2          NaN      11/10    -1000
# 43       NaN         None            2          NaN       15/8     -115
# 44       NaN         None            2          NaN      21/13     -163
# 45       NaN         None            2          NaN       11/5      120
# 46       NaN         None            2          NaN         21     2000
# 47       NaN         None            2          NaN         13     1200
# 48       NaN         None            2          NaN         17     1600
# 49       NaN         None            2          NaN         21     2000
#
#     Winning  Stopped LatestBookmakerUpdate
# 0     False     True   2026-01-04 19:40:37
# 1     False     True   2026-01-04 19:40:37
# 2     False    False   2026-01-06 14:21:37
# 3     False     True   2026-01-06 13:40:44
# 4     False    False   2026-01-06 14:21:37
# 5     False    False   2026-01-06 14:21:37
# 6     False    False   2026-01-06 14:21:37
# 7     False    False   2026-01-06 14:21:37
# 8     False    False   2026-01-06 14:21:37
# 9     False    False   2026-01-06 14:21:37
# 10    False    False   2026-01-06 14:21:37
# 11    False    False   2026-01-06 14:21:37
# 12    False    False   2026-01-06 14:21:37
# 13    False    False   2026-01-06 14:21:37
# 14    False    False   2026-01-06 14:21:37
# 15    False    False   2026-01-06 05:45:56
# 16    False    False   2026-01-06 05:10:30
# 17    False    False   2026-01-06 14:21:37
# 18    False    False   2026-01-06 14:21:37
# 19    False    False   2026-01-06 14:21:37
# 20    False    False   2026-01-06 14:21:37
# 21    False    False   2026-01-06 03:28:24
# 22    False    False   2026-01-06 14:21:37
# 23    False    False   2026-01-06 14:21:37
# 24    False    False   2026-01-06 14:21:37
# 25    False    False   2026-01-06 14:21:37
# 26    False    False   2026-01-06 14:21:37
# 27    False    False   2026-01-06 14:21:37
# 28    False    False   2026-01-06 14:21:37
# 29    False    False   2026-01-06 05:10:30
# 30    False    False   2025-12-31 17:19:40
# 31    False    False   2026-01-06 05:10:16
# 32    False    False   2026-01-06 03:09:10
# 33    False    False   2026-01-06 03:09:10
# 34    False    False   2026-01-06 04:11:01
# 35    False    False   2026-01-06 05:43:45
# 36    False    False   2026-01-06 14:30:44
# 37    False    False   2026-01-06 14:21:37
# 38    False    False   2026-01-06 14:21:37
# 39    False    False   2026-01-06 14:21:37
# 40    False    False   2026-01-06 14:21:37
# 41    False    False   2026-01-06 14:21:37
# 42    False    False   2026-01-06 14:21:37
# 43    False    False   2026-01-06 14:21:37
# 44    False    False   2026-01-06 14:21:37
# 45    False    False   2026-01-06 14:21:37
# 46    False    False   2026-01-06 14:21:37
# 47    False    False   2026-01-06 14:21:37
# 48    False    False   2026-01-06 14:21:37
# 49    False    False   2026-01-06 14:21:37
