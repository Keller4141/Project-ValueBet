# %%
import pandas as pd
import numpy as np

# =========================
# CONFIG
# =========================
BETINIA_CSV = "betinia_player_props.csv"
EXPEKT_CSV  = "expekt_player_props.csv"

OUT_COMBINED = "betinia_expekt_combined.csv"

# Hvis du vil kræve deadline matcher også, sæt True
MERGE_WITH_DEADLINE = False

# =========================
# LOAD
# =========================
df_betinia = pd.read_csv(BETINIA_CSV)
df_expekt  = pd.read_csv(EXPEKT_CSV)

if df_betinia.empty:
    raise ValueError("Betinia CSV er tom.")
if df_expekt.empty:
    raise ValueError("Expekt CSV er tom.")

# =========================
# NORMALIZE / TYPES
# =========================
for df in [df_betinia, df_expekt]:
    # sikr string keys uden ekstra spaces
    for c in ["event", "player", "selectionLabel", "marketLabel"]:
        if c in df.columns:
            df[c] = df[c].astype(str).str.strip()

    if "deadline" in df.columns:
        df["deadline"] = df["deadline"].astype(str).str.strip()

    # odds -> float
    df["odds_decimal"] = pd.to_numeric(df["odds_decimal"], errors="coerce")

# Rename odds/status per bookmaker
df_betinia = df_betinia.rename(columns={
    "odds_decimal": "odds_decimal_betinia",
    "status_selection": "status_selection_betinia",
})

df_expekt = df_expekt.rename(columns={
    "odds_decimal": "odds_decimal_expekt",
    "status_selection": "status_selection_expekt",
})

# =========================
# MERGE
# =========================
if MERGE_WITH_DEADLINE:
    keys = ["event", "player", "selectionLabel", "marketLabel", "deadline"]
else:
    keys = ["event", "player", "selectionLabel", "marketLabel"]

# Vi starter med Betinia som venstre, og mapper Expekt ind
df_merged = df_betinia.merge(df_expekt, on=keys, how="left")

# =========================
# PAYOUT + RATIOS
# =========================
# payout = decimal odds (for 1 kr indsats giver decimal tilbage)
df_merged["payout_betinia"] = df_merged["odds_decimal_betinia"]
df_merged["payout_expekt"]  = df_merged["odds_decimal_expekt"]

valid = (
    df_merged["payout_betinia"].notna() &
    df_merged["payout_expekt"].notna() &
    (df_merged["payout_betinia"] > 0) &
    (df_merged["payout_expekt"] > 0)
)

df_merged["ratio_betinia_over_expekt"] = np.nan
df_merged["ratio_expekt_over_betinia"] = np.nan

df_merged.loc[valid, "ratio_betinia_over_expekt"] = (
    df_merged.loc[valid, "payout_betinia"] / df_merged.loc[valid, "payout_expekt"]
)
df_merged.loc[valid, "ratio_expekt_over_betinia"] = (
    df_merged.loc[valid, "payout_expekt"] / df_merged.loc[valid, "payout_betinia"]
)

df_merged["ratio_max"] = df_merged[
    ["ratio_betinia_over_expekt", "ratio_expekt_over_betinia"]
].max(axis=1)

df_merged["best_bookmaker"] = np.where(
    df_merged["ratio_betinia_over_expekt"] >= df_merged["ratio_expekt_over_betinia"],
    "Betinia",
    "Expekt"
)

df_merged["best_payout"] = np.where(
    df_merged["best_bookmaker"] == "Betinia",
    df_merged["payout_betinia"],
    df_merged["payout_expekt"]
)

df_merged["other_bookmaker"] = np.where(
    df_merged["best_bookmaker"] == "Betinia",
    "Expekt",
    "Betinia"
)

df_merged["other_payout"] = np.where(
    df_merged["best_bookmaker"] == "Betinia",
    df_merged["payout_expekt"],
    df_merged["payout_betinia"]
)

# =========================
# OUTPUT
# =========================
df_merged.to_csv(OUT_COMBINED, index=False, encoding="utf-8")

n_total = len(df_merged)
n_match = df_merged["payout_expekt"].notna().sum()
print(f"Merge matches (Expekt found): {n_match}/{n_total}")
print(f"Saved combined CSV: {OUT_COMBINED}")

# Top 20 hvor begge findes og ratio er størst
df_top = df_merged[valid].copy()
df_top = df_top.sort_values("ratio_max", ascending=False, kind="stable")

cols_show = [
    "event", "player", "selectionLabel", "marketLabel"
]
if "deadline" in df_top.columns:
    cols_show.append("deadline")

cols_show += [
    "payout_betinia", "payout_expekt",
    "best_bookmaker", "best_payout",
    "other_bookmaker", "other_payout",
    "ratio_max"
]

print("\nTOP 20 ratios (kun hvor begge odds findes):")
print(df_top[cols_show].head(100).to_string(index=False))
# Out:
# Merge matches (Expekt found): 304/606
# Saved combined CSV: betinia_expekt_combined.csv
#
# TOP 20 ratios (kun hvor begge odds findes):
#                                    event             player selectionLabel                                          marketLabel  payout_betinia  payout_expekt best_bookmaker  best_payout other_bookmaker  other_payout  ratio_max
# Eintracht Frankfurt vs Borussia Dortmund      Ansgar Knauff       Over 2.5    Spillers samlede antal tacklinger | Ansgar Knauff          7.5000           2.38        Betinia       7.5000          Expekt        2.3800   3.151261
# Eintracht Frankfurt vs Borussia Dortmund      Karim Adeyemi       Over 2.5    Spillers samlede antal tacklinger | Karim Adeyemi          6.6667           2.40        Betinia       6.6667          Expekt        2.4000   2.777792
# Eintracht Frankfurt vs Borussia Dortmund      Ansgar Knauff       Over 1.5    Spillers samlede antal tacklinger | Ansgar Knauff          3.6667           1.40        Betinia       3.6667          Expekt        1.4000   2.619071
# Eintracht Frankfurt vs Borussia Dortmund   Maximilian Beier       Over 4.5       Spillers samlede antal skud | Maximilian Beier          3.1000           8.00         Expekt       8.0000         Betinia        3.1000   2.580645
# Eintracht Frankfurt vs Borussia Dortmund  Younes Ebnoutalib       Over 0.5  Spillers samlede antal assister | Younes Ebnoutalib          2.7143           7.00         Expekt       7.0000         Betinia        2.7143   2.578934
# Eintracht Frankfurt vs Borussia Dortmund      Karim Adeyemi       Over 1.5    Spillers samlede antal tacklinger | Karim Adeyemi          3.6000           1.44        Betinia       3.6000          Expekt        1.4400   2.500000
# Eintracht Frankfurt vs Borussia Dortmund     Jessic Ngankam       Over 0.5     Spillers samlede antal assister | Jessic Ngankam          2.7143           6.50         Expekt       6.5000         Betinia        2.7143   2.394724
# Eintracht Frankfurt vs Borussia Dortmund   Maximilian Beier       Over 0.5   Spillers samlede antal assister | Maximilian Beier          2.1429           5.00         Expekt       5.0000         Betinia        2.1429   2.333287
# Eintracht Frankfurt vs Borussia Dortmund     Jessic Ngankam       Over 1.5   Spillers samlede antal tacklinger | Jessic Ngankam          4.0000           1.73        Betinia       4.0000          Expekt        1.7300   2.312139
# Eintracht Frankfurt vs Borussia Dortmund   Maximilian Beier       Over 3.5       Spillers samlede antal skud | Maximilian Beier          1.9500           4.50         Expekt       4.5000         Betinia        1.9500   2.307692
# Eintracht Frankfurt vs Borussia Dortmund      Karim Adeyemi       Over 0.5      Spillers samlede antal assister | Karim Adeyemi          2.2000           5.00         Expekt       5.0000         Betinia        2.2000   2.272727
# Eintracht Frankfurt vs Borussia Dortmund      Ansgar Knauff       Over 0.5      Spillers samlede antal assister | Ansgar Knauff          2.6667           6.00         Expekt       6.0000         Betinia        2.6667   2.249972
# Eintracht Frankfurt vs Borussia Dortmund      Arthur Theate       Over 1.5            Antal afslutninger på mål | Arthur Theate         14.0000          31.00         Expekt      31.0000         Betinia       14.0000   2.214286
# Eintracht Frankfurt vs Borussia Dortmund     Jessic Ngankam       Over 2.5   Spillers samlede antal tacklinger | Jessic Ngankam          7.5000           3.40        Betinia       7.5000          Expekt        3.4000   2.205882
# Eintracht Frankfurt vs Borussia Dortmund Nico Schlotterbeck       Over 0.5 Spillers samlede antal assister | Nico Schlotterbeck          5.0000          11.00         Expekt      11.0000         Betinia        5.0000   2.200000
# Eintracht Frankfurt vs Borussia Dortmund    Nathaniel Brown       Over 1.5          Antal afslutninger på mål | Nathaniel Brown         12.0000           5.50        Betinia      12.0000          Expekt        5.5000   2.181818
# Eintracht Frankfurt vs Borussia Dortmund         Ritsu Doan       Over 0.5         Spillers samlede antal assister | Ritsu Doan          2.5455           5.50         Expekt       5.5000         Betinia        2.5455   2.160676
# Eintracht Frankfurt vs Borussia Dortmund      Aurele Amenda       Over 0.5      Spillers samlede antal assister | Aurele Amenda          9.0000          19.00         Expekt      19.0000         Betinia        9.0000   2.111111
# Eintracht Frankfurt vs Borussia Dortmund     Mahmoud Dahoud       Over 1.5           Antal afslutninger på mål | Mahmoud Dahoud         20.0000           9.50        Betinia      20.0000          Expekt        9.5000   2.105263
# Eintracht Frankfurt vs Borussia Dortmund      Aurele Amenda       Over 1.5              Spiller Frispark Begået | Aurele Amenda          1.9000           4.00         Expekt       4.0000         Betinia        1.9000   2.105263
# Eintracht Frankfurt vs Borussia Dortmund    Daniel Svensson            Yes                   Spiller får kort | Daniel Svensson          4.0000           8.00         Expekt       8.0000         Betinia        4.0000   2.000000
# Eintracht Frankfurt vs Borussia Dortmund      Arthur Theate       Over 1.5          Spillers samlede antal skud | Arthur Theate          2.7500           5.50         Expekt       5.5000         Betinia        2.7500   2.000000
# Eintracht Frankfurt vs Borussia Dortmund      Karim Adeyemi       Over 4.5          Spillers samlede antal skud | Karim Adeyemi          3.6667           7.00         Expekt       7.0000         Betinia        3.6667   1.909074
# Eintracht Frankfurt vs Borussia Dortmund    Daniel Svensson            Yes                     Spiller scorer | Daniel Svensson          5.0000           9.50         Expekt       9.5000         Betinia        5.0000   1.900000
# Eintracht Frankfurt vs Borussia Dortmund       Felix Nmecha       Over 0.5       Spillers samlede antal assister | Felix Nmecha          2.9000           5.50         Expekt       5.5000         Betinia        2.9000   1.896552
# Eintracht Frankfurt vs Borussia Dortmund Jean Matteo Bahoya       Over 0.5 Spillers samlede antal assister | Jean Matteo Bahoya          3.2000           6.00         Expekt       6.0000         Betinia        3.2000   1.875000
# Eintracht Frankfurt vs Borussia Dortmund    Daniel Svensson       Over 1.5          Antal afslutninger på mål | Daniel Svensson         11.0000           6.00        Betinia      11.0000          Expekt        6.0000   1.833333
# Eintracht Frankfurt vs Borussia Dortmund Jean Matteo Bahoya       Over 1.5         Spiller Frispark Begået | Jean Matteo Bahoya          2.3000           4.20         Expekt       4.2000         Betinia        2.3000   1.826087
# Eintracht Frankfurt vs Borussia Dortmund   Maximilian Beier       Over 2.5         Antal afslutninger på mål | Maximilian Beier          5.0000           9.00         Expekt       9.0000         Betinia        5.0000   1.800000
# Eintracht Frankfurt vs Borussia Dortmund      Karim Adeyemi       Over 3.5          Spillers samlede antal skud | Karim Adeyemi          2.2500           4.00         Expekt       4.0000         Betinia        2.2500   1.777778
# Eintracht Frankfurt vs Borussia Dortmund    Daniel Svensson       Over 0.5    Spillers samlede antal assister | Daniel Svensson          3.1000           5.50         Expekt       5.5000         Betinia        3.1000   1.774194
# Eintracht Frankfurt vs Borussia Dortmund     Julian Ryerson       Over 0.5     Spillers samlede antal assister | Julian Ryerson          3.1000           5.50         Expekt       5.5000         Betinia        3.1000   1.774194
# Eintracht Frankfurt vs Borussia Dortmund      Arthur Theate       Over 0.5      Spillers samlede antal assister | Arthur Theate          7.5000          13.00         Expekt      13.0000         Betinia        7.5000   1.733333
# Eintracht Frankfurt vs Borussia Dortmund         Robin Koch       Over 0.5         Spillers samlede antal assister | Robin Koch          7.5000          13.00         Expekt      13.0000         Betinia        7.5000   1.733333
# Eintracht Frankfurt vs Borussia Dortmund         Robin Koch       Over 1.5               Antal afslutninger på mål | Robin Koch         20.0000          34.00         Expekt      34.0000         Betinia       20.0000   1.700000
# Eintracht Frankfurt vs Borussia Dortmund      Julian Brandt       Over 0.5      Spillers samlede antal assister | Julian Brandt          2.3637           4.00         Expekt       4.0000         Betinia        2.3637   1.692262
# Eintracht Frankfurt vs Borussia Dortmund     Mahmoud Dahoud       Over 1.5             Spiller Frispark Begået | Mahmoud Dahoud          1.7143           2.88         Expekt       2.8800         Betinia        1.7143   1.679986
# Eintracht Frankfurt vs Borussia Dortmund      Arthur Theate       Over 0.5            Antal afslutninger på mål | Arthur Theate          3.0000           5.00         Expekt       5.0000         Betinia        3.0000   1.666667
# Eintracht Frankfurt vs Borussia Dortmund   Timothy Chandler       Over 1.5           Spiller Frispark Begået | Timothy Chandler          2.2500           3.75         Expekt       3.7500         Betinia        2.2500   1.666667
# Eintracht Frankfurt vs Borussia Dortmund           Emre Can       Over 0.5           Spillers samlede antal assister | Emre Can          4.5000           7.50         Expekt       7.5000         Betinia        4.5000   1.666667
# Eintracht Frankfurt vs Borussia Dortmund       Hugo Larsson       Over 0.5       Spillers samlede antal assister | Hugo Larsson          4.5000           7.50         Expekt       7.5000         Betinia        4.5000   1.666667
# Eintracht Frankfurt vs Borussia Dortmund       Felix Nmecha       Over 2.5           Spillers samlede antal skud | Felix Nmecha          3.0000           5.00         Expekt       5.0000         Betinia        3.0000   1.666667
# Eintracht Frankfurt vs Borussia Dortmund   Maximilian Beier       Over 2.5       Spillers samlede antal skud | Maximilian Beier          1.3847           2.30         Expekt       2.3000         Betinia        1.3847   1.661010
# Eintracht Frankfurt vs Borussia Dortmund   Maximilian Beier       Over 1.5         Antal afslutninger på mål | Maximilian Beier          2.3000           3.80         Expekt       3.8000         Betinia        2.3000   1.652174
# Eintracht Frankfurt vs Borussia Dortmund      Julian Brandt            Yes                     Spiller får kort | Julian Brandt          5.5000           9.00         Expekt       9.0000         Betinia        5.5000   1.636364
# Eintracht Frankfurt vs Borussia Dortmund    Nathaniel Brown       Over 1.5            Spiller Frispark Begået | Nathaniel Brown          3.6000           2.20        Betinia       3.6000          Expekt        2.2000   1.636364
# Eintracht Frankfurt vs Borussia Dortmund  Julien Duranville       Over 1.5          Spiller Frispark Begået | Julien Duranville          1.9000           3.10         Expekt       3.1000         Betinia        1.9000   1.631579
# Eintracht Frankfurt vs Borussia Dortmund       Felix Nmecha            Yes                        Spiller scorer | Felix Nmecha          4.0000           6.50         Expekt       6.5000         Betinia        4.0000   1.625000
# Eintracht Frankfurt vs Borussia Dortmund    Daniel Svensson       Over 1.5            Spiller Frispark Begået | Daniel Svensson          2.3637           3.80         Expekt       3.8000         Betinia        2.3637   1.607649
# Eintracht Frankfurt vs Borussia Dortmund    Marcel Sabitzer       Over 0.5    Spillers samlede antal assister | Marcel Sabitzer          3.8000           6.00         Expekt       6.0000         Betinia        3.8000   1.578947
# Eintracht Frankfurt vs Borussia Dortmund Carney Chukwuemeka       Over 0.5 Spillers samlede antal assister | Carney Chukwuemeka          2.8572           4.50         Expekt       4.5000         Betinia        2.8572   1.574969
# Eintracht Frankfurt vs Borussia Dortmund      Aurele Amenda       Over 2.5    Spillers samlede antal tacklinger | Aurele Amenda          2.8572           4.50         Expekt       4.5000         Betinia        2.8572   1.574969
# Eintracht Frankfurt vs Borussia Dortmund     Waldemar Anton       Over 0.5     Spillers samlede antal assister | Waldemar Anton          7.0000          11.00         Expekt      11.0000         Betinia        7.0000   1.571429
# Eintracht Frankfurt vs Borussia Dortmund         Ritsu Doan            Yes                          Spiller scorer | Ritsu Doan          3.2000           5.00         Expekt       5.0000         Betinia        3.2000   1.562500
# Eintracht Frankfurt vs Borussia Dortmund      Ansgar Knauff       Over 3.5          Spillers samlede antal skud | Ansgar Knauff          2.4000           3.75         Expekt       3.7500         Betinia        2.4000   1.562500
# Eintracht Frankfurt vs Borussia Dortmund  Arnaud Kalimuendo            Yes                   Spiller scorer | Arnaud Kalimuendo          2.2500           3.50         Expekt       3.5000         Betinia        2.2500   1.555556
# Eintracht Frankfurt vs Borussia Dortmund           Emre Can       Over 1.5                 Antal afslutninger på mål | Emre Can         11.0000          17.00         Expekt      17.0000         Betinia       11.0000   1.545455
# Eintracht Frankfurt vs Borussia Dortmund       Felix Nmecha       Over 1.5             Antal afslutninger på mål | Felix Nmecha          5.5000           8.50         Expekt       8.5000         Betinia        5.5000   1.545455
# Eintracht Frankfurt vs Borussia Dortmund      Julian Brandt       Over 1.5    Spillers samlede antal tacklinger | Julian Brandt          4.2000           2.75        Betinia       4.2000          Expekt        2.7500   1.527273
# Eintracht Frankfurt vs Borussia Dortmund       Hugo Larsson       Over 1.5     Spillers samlede antal tacklinger | Hugo Larsson          2.1000           1.40        Betinia       2.1000          Expekt        1.4000   1.500000
# Eintracht Frankfurt vs Borussia Dortmund  Julien Duranville       Over 1.5        Antal afslutninger på mål | Julien Duranville          6.0000           4.00        Betinia       6.0000          Expekt        4.0000   1.500000
# Eintracht Frankfurt vs Borussia Dortmund  Younes Ebnoutalib            Yes                 Spiller får kort | Younes Ebnoutalib          5.0000           7.50         Expekt       7.5000         Betinia        5.0000   1.500000
# Eintracht Frankfurt vs Borussia Dortmund      Aurele Amenda       Over 1.5          Spillers samlede antal skud | Aurele Amenda          5.0000           7.50         Expekt       7.5000         Betinia        5.0000   1.500000
# Eintracht Frankfurt vs Borussia Dortmund         Robin Koch       Over 0.5               Antal afslutninger på mål | Robin Koch          3.6667           5.50         Expekt       5.5000         Betinia        3.6667   1.499986
# Eintracht Frankfurt vs Borussia Dortmund           Emre Can       Over 0.5                 Antal afslutninger på mål | Emre Can          2.6667           4.00         Expekt       4.0000         Betinia        2.6667   1.499981
# Eintracht Frankfurt vs Borussia Dortmund    Nathaniel Brown       Over 1.5        Spillers samlede antal skud | Nathaniel Brown          2.8572           1.91        Betinia       2.8572          Expekt        1.9100   1.495916
# Eintracht Frankfurt vs Borussia Dortmund        Niklas Sule       Over 1.5                Spiller Frispark Begået | Niklas Sule          5.5000           3.80        Betinia       5.5000          Expekt        3.8000   1.447368
# Eintracht Frankfurt vs Borussia Dortmund  Julien Duranville            Yes                   Spiller scorer | Julien Duranville          6.5000           4.50        Betinia       6.5000          Expekt        4.5000   1.444444
# Eintracht Frankfurt vs Borussia Dortmund        Niklas Sule       Over 1.5            Spillers samlede antal skud | Niklas Sule          4.5000           6.50         Expekt       6.5000         Betinia        4.5000   1.444444
# Eintracht Frankfurt vs Borussia Dortmund         Robin Koch            Yes                        Spiller får kort | Robin Koch          3.0000           4.33         Expekt       4.3300         Betinia        3.0000   1.443333
# Eintracht Frankfurt vs Borussia Dortmund    Nathaniel Brown       Over 0.5          Antal afslutninger på mål | Nathaniel Brown          2.7500           1.91        Betinia       2.7500          Expekt        1.9100   1.439791
# Eintracht Frankfurt vs Borussia Dortmund         Ritsu Doan       Over 1.5       Spillers samlede antal tacklinger | Ritsu Doan          2.2000           1.53        Betinia       2.2000          Expekt        1.5300   1.437908
# Eintracht Frankfurt vs Borussia Dortmund     Mahmoud Dahoud       Over 1.5   Spillers samlede antal tacklinger | Mahmoud Dahoud          1.8750           1.33        Betinia       1.8750          Expekt        1.3300   1.409774
# Eintracht Frankfurt vs Borussia Dortmund       Felix Nmecha            Yes                      Spiller får kort | Felix Nmecha          3.2000           4.50         Expekt       4.5000         Betinia        3.2000   1.406250
# Eintracht Frankfurt vs Borussia Dortmund    Marcel Sabitzer            Yes                   Spiller får kort | Marcel Sabitzer          3.2000           4.50         Expekt       4.5000         Betinia        3.2000   1.406250
# Eintracht Frankfurt vs Borussia Dortmund           Emre Can       Over 1.5               Spillers samlede antal skud | Emre Can          3.0000           4.20         Expekt       4.2000         Betinia        3.0000   1.400000
# Eintracht Frankfurt vs Borussia Dortmund      Karim Adeyemi       Over 2.5          Spillers samlede antal skud | Karim Adeyemi          1.5000           2.10         Expekt       2.1000         Betinia        1.5000   1.400000
# Eintracht Frankfurt vs Borussia Dortmund        Niklas Sule            Yes                       Spiller får kort | Niklas Sule          5.0000           7.00         Expekt       7.0000         Betinia        5.0000   1.400000
# Eintracht Frankfurt vs Borussia Dortmund       Felix Nmecha       Over 0.5             Antal afslutninger på mål | Felix Nmecha          1.8750           2.60         Expekt       2.6000         Betinia        1.8750   1.386667
# Eintracht Frankfurt vs Borussia Dortmund        Love Arrhov            Yes                       Spiller får kort | Love Arrhov          6.5000           9.00         Expekt       9.0000         Betinia        6.5000   1.384615
# Eintracht Frankfurt vs Borussia Dortmund     Julian Ryerson            Yes                      Spiller scorer | Julian Ryerson          6.5000           9.00         Expekt       9.0000         Betinia        6.5000   1.384615
# Eintracht Frankfurt vs Borussia Dortmund      Arthur Theate       Over 0.5          Spillers samlede antal skud | Arthur Theate          1.3847           1.91         Expekt       1.9100         Betinia        1.3847   1.379360
# Eintracht Frankfurt vs Borussia Dortmund      Aurele Amenda       Over 0.5            Antal afslutninger på mål | Aurele Amenda          4.0000           5.50         Expekt       5.5000         Betinia        4.0000   1.375000
# Eintracht Frankfurt vs Borussia Dortmund    Daniel Svensson       Over 2.5        Spillers samlede antal skud | Daniel Svensson          5.5000           4.00        Betinia       5.5000          Expekt        4.0000   1.375000
# Eintracht Frankfurt vs Borussia Dortmund       Felix Nmecha       Over 1.5           Spillers samlede antal skud | Felix Nmecha          1.6800           2.30         Expekt       2.3000         Betinia        1.6800   1.369048
# Eintracht Frankfurt vs Borussia Dortmund     Mahmoud Dahoud       Over 0.5     Spillers samlede antal assister | Mahmoud Dahoud          4.7500           6.50         Expekt       6.5000         Betinia        4.7500   1.368421
# Eintracht Frankfurt vs Borussia Dortmund    Daniel Svensson       Over 0.5          Antal afslutninger på mål | Daniel Svensson          2.6667           1.95        Betinia       2.6667          Expekt        1.9500   1.367538
# Eintracht Frankfurt vs Borussia Dortmund  Julien Duranville       Over 0.5  Spillers samlede antal assister | Julien Duranville          3.6667           5.00         Expekt       5.0000         Betinia        3.6667   1.363624
# Eintracht Frankfurt vs Borussia Dortmund      Aurele Amenda       Over 0.5              Spiller Frispark Begået | Aurele Amenda          1.1539           1.57         Expekt       1.5700         Betinia        1.1539   1.360603
# Eintracht Frankfurt vs Borussia Dortmund     Mahmoud Dahoud       Over 2.5   Spillers samlede antal tacklinger | Mahmoud Dahoud          2.8572           2.10        Betinia       2.8572          Expekt        2.1000   1.360571
# Eintracht Frankfurt vs Borussia Dortmund         Robin Koch       Over 1.5       Spillers samlede antal tacklinger | Robin Koch          1.8750           1.40        Betinia       1.8750          Expekt        1.4000   1.339286
# Eintracht Frankfurt vs Borussia Dortmund      Karim Adeyemi            Yes                       Spiller scorer | Karim Adeyemi          3.0000           4.00         Expekt       4.0000         Betinia        3.0000   1.333333
# Eintracht Frankfurt vs Borussia Dortmund    Marcel Sabitzer       Over 1.5            Spiller Frispark Begået | Marcel Sabitzer          2.7143           3.60         Expekt       3.6000         Betinia        2.7143   1.326309
# Eintracht Frankfurt vs Borussia Dortmund   Maximilian Beier       Over 1.5 Spillers samlede antal tacklinger | Maximilian Beier          2.9000           2.20        Betinia       2.9000          Expekt        2.2000   1.318182
# Eintracht Frankfurt vs Borussia Dortmund   Maximilian Beier            Yes                    Spiller scorer | Maximilian Beier          2.6667           3.50         Expekt       3.5000         Betinia        2.6667   1.312484
# Eintracht Frankfurt vs Borussia Dortmund     Jessic Ngankam            Yes                      Spiller scorer | Jessic Ngankam          2.9000           3.80         Expekt       3.8000         Betinia        2.9000   1.310345
# Eintracht Frankfurt vs Borussia Dortmund     Mahmoud Dahoud       Over 0.5           Antal afslutninger på mål | Mahmoud Dahoud          3.6000           2.75        Betinia       3.6000          Expekt        2.7500   1.309091
# Eintracht Frankfurt vs Borussia Dortmund     Julian Ryerson       Over 1.5           Antal afslutninger på mål | Julian Ryerson         17.0000          13.00        Betinia      17.0000          Expekt       13.0000   1.307692
# Eintracht Frankfurt vs Borussia Dortmund Carney Chukwuemeka       Over 1.5         Spiller Frispark Begået | Carney Chukwuemeka          3.4000           2.60        Betinia       3.4000          Expekt        2.6000   1.307692
# Eintracht Frankfurt vs Borussia Dortmund   Maximilian Beier            Yes                  Spiller får kort | Maximilian Beier          5.0000           6.50         Expekt       6.5000         Betinia        5.0000   1.300000
