# %%
import json
import re
import pandas as pd
from datetime import datetime, timezone

IN_PATH = ["betano.txt", "betano1.txt", "betano2.txt", "betano3.txt", "betano4.txt", "betano5.txt", "betano6.txt", "betano7.txt", "betano8.txt", "betano9.txt", "betano10.txt", "betano11.txt"]
OUT_CSV = "betano_player_props.csv"

COLUMNS = [
    "event",
    "player",
    "selectionLabel",
    "odds_decimal",
    "status_selection",
    "marketLabel",
    "deadline",
]

# =========================
# HELPERS
# =========================
def load_json(path: str) -> dict:
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

def ms_to_iso_utc(ms):
    if ms is None:
        return None
    try:
        ms = int(ms)
        return datetime.fromtimestamp(ms / 1000, tz=timezone.utc).isoformat()
    except Exception:
        return None

def selection_price_decimal(sel: dict):
    p = sel.get("price")
    if isinstance(p, (int, float)):
        return p
    if isinstance(p, str):
        return p.strip()
    if isinstance(p, dict):
        for k in ["decimal", "odds", "value"]:
            if k in p:
                return p.get(k)
    odds_formats = sel.get("oddsFormats") or {}
    if isinstance(odds_formats, dict) and "decimal" in odds_formats:
        return odds_formats.get("decimal")
    return None

def is_full_match_market(market: dict, raw_header: str) -> bool:
    parts = []
    if isinstance(raw_header, str):
        parts.append(raw_header)
    nm = market.get("name")
    if isinstance(nm, str):
        parts.append(nm)
    txt = " | ".join(parts).lower()

    bad_tokens = [
        "1. halvleg", "2. halvleg", "halvleg",
        "1st half", "2nd half", "first half", "second half",
        "periode", "period", "quarter", "q1", "q2", "q3", "q4",
        "overtime", "over time", "ekstra tid", "forlænget",
        "inkl. overtid", "incl. overtime",
    ]
    return not any(t in txt for t in bad_tokens)

def pick_market_header(market: dict) -> str:
    tl = market.get("tableLayout") or {}
    # title kan være "Målscorer" hos dig
    for key in ["title", "headerTitle"]:
        v = tl.get(key)
        if isinstance(v, str) and v.strip():
            return v.strip()

    nm = market.get("name")
    if isinstance(nm, str) and nm.strip():
        return nm.strip()
    return None

def strip_leading_player_from_header(header: str, players_in_market):
    if not isinstance(header, str) or not header.strip():
        return header
    header = header.strip()

    players_sorted = sorted(
        [p for p in players_in_market if isinstance(p, str) and p.strip()],
        key=lambda x: len(x),
        reverse=True
    )
    for p in players_sorted:
        p = p.strip()
        if header.lower().startswith(p.lower() + " "):
            return header[len(p):].strip()
    return header

def normalize_selection_label_count(label: str):
    """
    1+ -> Over 0.5
    2+ -> Over 1.5
    3+ -> Over 2.5
    """
    if not isinstance(label, str):
        return None
    s = label.strip()
    m = re.fullmatch(r"(\d+)\+", s)
    if not m:
        return None
    x = int(m.group(1))
    return f"Over {x - 0.5}"

def normalize_market_type(header: str):
    """
    Map til dine ønskede labels.
    """
    if not isinstance(header, str) or not header.strip():
        return None
    h = header.strip().lower()

    # Målscorer
    if "målscorer" in h or "scorer" in h:
        return "Spiller scorer"

    # Kort
    if "kort" in h or "card" in h:
        return "Spiller får kort"

    # Skud på mål
    if re.search(r"\bskud\s+p[åa]\s+m[åa]l\b", h):
        return "Antal afslutninger på mål"

    # Skud (total)
    if "skud" in h and not re.search(r"\bskud\s+p[åa]\s+m[åa]l\b", h):
        return "Spillers samlede antal skud"

    # Assists
    if "assist" in h:
        return "Spillers samlede antal assister"

    # Redninger
    if "redning" in h or "saves" in h:
        return "Målmand Redninger"

    return None

def get_column_titles(market: dict):
    tl = market.get("tableLayout") or {}
    cols = tl.get("columnTitles") or []
    out = []
    if isinstance(cols, list):
        for c in cols:
            t = c.get("title")
            if isinstance(t, str) and t.strip():
                out.append(t.strip())
    return out

def build_event_name_betano(evt: dict) -> str:
    """
    Returnerer 'Hold1 vs Hold2' for Betano events.
    """
    if not isinstance(evt, dict):
        return "unknown_event"

    # 1️⃣ Forsøg via participants (mest robust)
    parts = evt.get("participants") or []
    names = []

    if isinstance(parts, list):
        for p in sorted(parts, key=lambda x: x.get("sortOrder", 9999)):
            name = p.get("label") or p.get("name")
            if isinstance(name, str) and name.strip():
                names.append(name.strip())

    if len(names) >= 2:
        return f"{names[0]} vs {names[1]}"

    # 2️⃣ Fallback: name / shortName
    for key in ["name", "shortName"]:
        v = evt.get(key)
        if isinstance(v, str) and v.strip():
            s = v.strip()
            s = s.replace(" - ", " vs ")
            s = s.replace(" v ", " vs ")
            return s

    # 3️⃣ Sidste fallback
    return str(evt.get("id") or evt.get("eventId") or "unknown_event")

# =========================
# PARSER
# =========================
def parse_betano_player_props(doc: dict) -> pd.DataFrame:
    evt = ((doc.get("data") or {}).get("event")) or doc.get("event") or {}
    event_name = build_event_name_betano(evt)
    markets = evt.get("markets") or []
    if not isinstance(markets, list):
        markets = []

    rows_out = []

    for market in markets:
        tl = market.get("tableLayout") or {}
        rows = tl.get("rows") or []
        if not isinstance(rows, list) or len(rows) == 0:
            continue

        raw_header = pick_market_header(market)
        if not is_full_match_market(market, raw_header):
            continue

        # player navne i markedet
        players_in_market = []
        for r in rows:
            nm = r.get("title") or r.get("name")
            if isinstance(nm, str) and nm.strip():
                players_in_market.append(nm.strip())

        header_no_player = strip_leading_player_from_header(raw_header, players_in_market)
        market_type = normalize_market_type(header_no_player)
        if market_type is None:
            continue

        # kun dine ønskede markeder
        if market_type not in {
            "Antal afslutninger på mål",
            "Spillers samlede antal skud",
            "Målmand Redninger",
            "Spillers samlede antal assister",
            "Spiller får kort",
            "Spiller scorer",
        }:
            continue

        deadline = ms_to_iso_utc(
            market.get("marketCloseTimeMillis")
            or market.get("closeTimeMillis")
            or market.get("deadlineMillis")
        )
        status_market = market.get("status") or market.get("marketStatus") or "Open"

        # special-case: Målscorer skal være "Når som helst"
        col_titles = get_column_titles(market)
        require_anytime = (market_type == "Spiller scorer")
        has_anytime = any(ct.lower() == "når som helst" for ct in col_titles)

        # Hvis det er målscorer men ikke har "Når som helst", så skip (du bad specifikt om den)
        if require_anytime and not has_anytime:
            continue

        for r in rows:
            player = r.get("title") or r.get("name")
            if not (isinstance(player, str) and player.strip()):
                continue
            player = player.strip()

            group_selections = r.get("groupSelections") or []
            if not isinstance(group_selections, list):
                continue

            for gs in group_selections:
                sels = gs.get("selections") or []
                if not isinstance(sels, list):
                    continue

                for sel in sels:
                    raw_label = sel.get("name") or sel.get("label")
                    if not (isinstance(raw_label, str) and raw_label.strip()):
                        continue
                    raw_label = raw_label.strip()

                    odds_dec = selection_price_decimal(sel)
                    odds_dec = pd.to_numeric(odds_dec, errors="coerce")
                    if pd.isna(odds_dec) or odds_dec <= 0:
                        continue

                    # -------------------------
                    # MARKET-SPECIFIK FILTRERING
                    # -------------------------
                    if market_type == "Spillers samlede antal assister":
                        # behold KUN Over 0.5 og Over 1.5
                        norm = normalize_selection_label_count(raw_label)  # None hvis label ikke er 1+ / 2+ osv
                        if norm not in {"Over 0.5", "Over 1.5"}:
                            continue
                        selection_label = norm

                    elif market_type == "Spiller scorer":
                        # "Når som helst" => selectionLabel = "yes"
                        selection_label = "Yes"

                    elif market_type == "Spiller får kort":
                        # selectionLabel = "ja"
                        selection_label = "Yes"

                    else:
                        # count markets (skud, skud på mål, redninger)
                        norm = normalize_selection_label_count(raw_label)
                        if norm is None:
                            continue
                        selection_label = norm

                    market_label = f"{market_type} | {player}"

                    rows_out.append({
                        "event": event_name,
                        "player": player,
                        "selectionLabel": selection_label,
                        "odds_decimal": float(odds_dec),
                        "status_selection": status_market,
                        "marketLabel": market_label,
                        "deadline": deadline,
                    })

    df = pd.DataFrame(rows_out, columns=COLUMNS)
    if df.empty:
        return df

    df["odds_decimal"] = pd.to_numeric(df["odds_decimal"], errors="coerce")
    df = df.dropna(subset=["odds_decimal"]).reset_index(drop=True)

    # dedupe pr nøgle
    df = df.sort_values(["event", "marketLabel", "selectionLabel", "odds_decimal"], kind="stable")
    df = df.drop_duplicates(subset=["event", "marketLabel", "selectionLabel"], keep="first").reset_index(drop=True)

    # sort
    df = df.sort_values(["marketLabel", "player", "selectionLabel"], kind="stable").reset_index(drop=True)

    return df

def main():
    dfs = []

    for path in IN_PATH:
        print(f"Loading {path}")
        doc = load_json(path)
        df_part = parse_betano_player_props(doc)

        if not df_part.empty:
            dfs.append(df_part)

    if not dfs:
        raise ValueError("Ingen data blev parsed fra nogen Betano-filer.")

    df = pd.concat(dfs, ignore_index=True)

    # ekstra dedupe på tværs af filer (vigtigt)
    df = df.sort_values(
        ["event", "marketLabel", "selectionLabel", "odds_decimal"],
        kind="stable"
    )
    df = df.drop_duplicates(
        subset=["event", "marketLabel", "selectionLabel"],
        keep="first"
    ).reset_index(drop=True)

    df.to_csv(OUT_CSV, index=False, encoding="utf-8")
    print(f"Saved {len(df)} rows to {OUT_CSV}")
    print(df.head(50))


if __name__ == "__main__":
    main()
# Out:
# Loading betano.txt
# Loading betano1.txt
# Loading betano2.txt
# Loading betano3.txt
# Loading betano4.txt
# Loading betano5.txt
# Loading betano6.txt
# Loading betano7.txt
# Loading betano8.txt
# Loading betano9.txt
# Loading betano10.txt
# Loading betano11.txt
# Saved 7745 rows to betano_player_props.csv
#                             event                    player selectionLabel  \
# 0   AS Roma vs US Sassuolo Calcio  Alessandro Gianni Romano       Over 0.5
# 1   AS Roma vs US Sassuolo Calcio  Alessandro Gianni Romano       Over 1.5
# 2   AS Roma vs US Sassuolo Calcio  Alessandro Gianni Romano       Over 2.5
# 3   AS Roma vs US Sassuolo Calcio              Alieu Fadera       Over 0.5
# 4   AS Roma vs US Sassuolo Calcio              Alieu Fadera       Over 1.5
# 5   AS Roma vs US Sassuolo Calcio              Alieu Fadera       Over 2.5
# 6   AS Roma vs US Sassuolo Calcio              Alieu Fadera       Over 3.5
# 7   AS Roma vs US Sassuolo Calcio          Andrea Pinamonti       Over 0.5
# 8   AS Roma vs US Sassuolo Calcio          Andrea Pinamonti       Over 1.5
# 9   AS Roma vs US Sassuolo Calcio          Andrea Pinamonti       Over 2.5
# 10  AS Roma vs US Sassuolo Calcio          Andrea Pinamonti       Over 3.5
# 11  AS Roma vs US Sassuolo Calcio                  Angeliño       Over 0.5
# 12  AS Roma vs US Sassuolo Calcio                  Angeliño       Over 1.5
# 13  AS Roma vs US Sassuolo Calcio                  Angeliño       Over 2.5
# 14  AS Roma vs US Sassuolo Calcio             Antonio Arena       Over 0.5
# 15  AS Roma vs US Sassuolo Calcio             Antonio Arena       Over 1.5
# 16  AS Roma vs US Sassuolo Calcio             Antonio Arena       Over 2.5
# 17  AS Roma vs US Sassuolo Calcio             Antonio Arena       Over 3.5
# 18  AS Roma vs US Sassuolo Calcio             Antonio Arena       Over 4.5
# 19  AS Roma vs US Sassuolo Calcio          Armand Lauriente       Over 0.5
# 20  AS Roma vs US Sassuolo Calcio          Armand Lauriente       Over 1.5
# 21  AS Roma vs US Sassuolo Calcio          Armand Lauriente       Over 2.5
# 22  AS Roma vs US Sassuolo Calcio          Armand Lauriente       Over 3.5
# 23  AS Roma vs US Sassuolo Calcio             Aster Vranckx       Over 0.5
# 24  AS Roma vs US Sassuolo Calcio             Aster Vranckx       Over 1.5
# 25  AS Roma vs US Sassuolo Calcio             Aster Vranckx       Over 2.5
# 26  AS Roma vs US Sassuolo Calcio           Bryan Cristante       Over 0.5
# 27  AS Roma vs US Sassuolo Calcio           Bryan Cristante       Over 1.5
# 28  AS Roma vs US Sassuolo Calcio           Bryan Cristante       Over 2.5
# 29  AS Roma vs US Sassuolo Calcio              Buba Sangare       Over 0.5
# 30  AS Roma vs US Sassuolo Calcio              Buba Sangare       Over 1.5
# 31  AS Roma vs US Sassuolo Calcio              Buba Sangare       Over 2.5
# 32  AS Roma vs US Sassuolo Calcio              Cas Odenthal       Over 0.5
# 33  AS Roma vs US Sassuolo Calcio              Cas Odenthal       Over 1.5
# 34  AS Roma vs US Sassuolo Calcio       Christian Frangella       Over 0.5
# 35  AS Roma vs US Sassuolo Calcio       Christian Frangella       Over 1.5
# 36  AS Roma vs US Sassuolo Calcio       Christian Frangella       Over 2.5
# 37  AS Roma vs US Sassuolo Calcio          Cristian Volpato       Over 0.5
# 38  AS Roma vs US Sassuolo Calcio          Cristian Volpato       Over 1.5
# 39  AS Roma vs US Sassuolo Calcio          Cristian Volpato       Over 2.5
# 40  AS Roma vs US Sassuolo Calcio          Cristian Volpato       Over 3.5
# 41  AS Roma vs US Sassuolo Calcio          Daniele Ghilardi       Over 0.5
# 42  AS Roma vs US Sassuolo Calcio          Daniele Ghilardi       Over 1.5
# 43  AS Roma vs US Sassuolo Calcio          Daniele Ghilardi       Over 2.5
# 44  AS Roma vs US Sassuolo Calcio             Devyne Rensch       Over 0.5
# 45  AS Roma vs US Sassuolo Calcio             Devyne Rensch       Over 1.5
# 46  AS Roma vs US Sassuolo Calcio             Devyne Rensch       Over 2.5
# 47  AS Roma vs US Sassuolo Calcio           Edoardo Iannoni       Over 0.5
# 48  AS Roma vs US Sassuolo Calcio           Edoardo Iannoni       Over 1.5
# 49  AS Roma vs US Sassuolo Calcio           Edoardo Iannoni       Over 2.5
#
#     odds_decimal status_selection  \
# 0           3.35             Open
# 1          13.50             Open
# 2          23.00             Open
# 3           2.42             Open
# 4           8.50             Open
# 5          19.50             Open
# 6          24.00             Open
# 7           1.75             Open
# 8           4.65             Open
# 9          12.50             Open
# 10         21.00             Open
# 11          3.20             Open
# 12         13.00             Open
# 13         23.00             Open
# 14          1.55             Open
# 15          3.55             Open
# 16          9.00             Open
# 17         18.00             Open
# 18         23.00             Open
# 19          1.75             Open
# 20          4.65             Open
# 21         12.50             Open
# 22         21.00             Open
# 23          3.65             Open
# 24         15.00             Open
# 25         24.00             Open
# 26          3.35             Open
# 27         13.50             Open
# 28         23.00             Open
# 29          3.70             Open
# 30         15.00             Open
# 31         24.00             Open
# 32          6.10             Open
# 33         22.00             Open
# 34          3.65             Open
# 35         15.00             Open
# 36         24.00             Open
# 37          2.35             Open
# 38          8.00             Open
# 39         19.00             Open
# 40         24.00             Open
# 41          4.45             Open
# 42         18.00             Open
# 43         24.00             Open
# 44          3.70             Open
# 45         15.00             Open
# 46         24.00             Open
# 47          3.60             Open
# 48         14.50             Open
# 49         24.00             Open
#
#                                           marketLabel  \
# 0   Antal afslutninger på mål | Alessandro Gianni ...
# 1   Antal afslutninger på mål | Alessandro Gianni ...
# 2   Antal afslutninger på mål | Alessandro Gianni ...
# 3            Antal afslutninger på mål | Alieu Fadera
# 4            Antal afslutninger på mål | Alieu Fadera
# 5            Antal afslutninger på mål | Alieu Fadera
# 6            Antal afslutninger på mål | Alieu Fadera
# 7        Antal afslutninger på mål | Andrea Pinamonti
# 8        Antal afslutninger på mål | Andrea Pinamonti
# 9        Antal afslutninger på mål | Andrea Pinamonti
# 10       Antal afslutninger på mål | Andrea Pinamonti
# 11               Antal afslutninger på mål | Angeliño
# 12               Antal afslutninger på mål | Angeliño
# 13               Antal afslutninger på mål | Angeliño
# 14          Antal afslutninger på mål | Antonio Arena
# 15          Antal afslutninger på mål | Antonio Arena
# 16          Antal afslutninger på mål | Antonio Arena
# 17          Antal afslutninger på mål | Antonio Arena
# 18          Antal afslutninger på mål | Antonio Arena
# 19       Antal afslutninger på mål | Armand Lauriente
# 20       Antal afslutninger på mål | Armand Lauriente
# 21       Antal afslutninger på mål | Armand Lauriente
# 22       Antal afslutninger på mål | Armand Lauriente
# 23          Antal afslutninger på mål | Aster Vranckx
# 24          Antal afslutninger på mål | Aster Vranckx
# 25          Antal afslutninger på mål | Aster Vranckx
# 26        Antal afslutninger på mål | Bryan Cristante
# 27        Antal afslutninger på mål | Bryan Cristante
# 28        Antal afslutninger på mål | Bryan Cristante
# 29           Antal afslutninger på mål | Buba Sangare
# 30           Antal afslutninger på mål | Buba Sangare
# 31           Antal afslutninger på mål | Buba Sangare
# 32           Antal afslutninger på mål | Cas Odenthal
# 33           Antal afslutninger på mål | Cas Odenthal
# 34    Antal afslutninger på mål | Christian Frangella
# 35    Antal afslutninger på mål | Christian Frangella
# 36    Antal afslutninger på mål | Christian Frangella
# 37       Antal afslutninger på mål | Cristian Volpato
# 38       Antal afslutninger på mål | Cristian Volpato
# 39       Antal afslutninger på mål | Cristian Volpato
# 40       Antal afslutninger på mål | Cristian Volpato
# 41       Antal afslutninger på mål | Daniele Ghilardi
# 42       Antal afslutninger på mål | Daniele Ghilardi
# 43       Antal afslutninger på mål | Daniele Ghilardi
# 44          Antal afslutninger på mål | Devyne Rensch
# 45          Antal afslutninger på mål | Devyne Rensch
# 46          Antal afslutninger på mål | Devyne Rensch
# 47        Antal afslutninger på mål | Edoardo Iannoni
# 48        Antal afslutninger på mål | Edoardo Iannoni
# 49        Antal afslutninger på mål | Edoardo Iannoni
#
#                      deadline
# 0   2026-01-10T17:00:00+00:00
# 1   2026-01-10T17:00:00+00:00
# 2   2026-01-10T17:00:00+00:00
# 3   2026-01-10T17:00:00+00:00
# 4   2026-01-10T17:00:00+00:00
# 5   2026-01-10T17:00:00+00:00
# 6   2026-01-10T17:00:00+00:00
# 7   2026-01-10T17:00:00+00:00
# 8   2026-01-10T17:00:00+00:00
# 9   2026-01-10T17:00:00+00:00
# 10  2026-01-10T17:00:00+00:00
# 11  2026-01-10T17:00:00+00:00
# 12  2026-01-10T17:00:00+00:00
# 13  2026-01-10T17:00:00+00:00
# 14  2026-01-10T17:00:00+00:00
# 15  2026-01-10T17:00:00+00:00
# 16  2026-01-10T17:00:00+00:00
# 17  2026-01-10T17:00:00+00:00
# 18  2026-01-10T17:00:00+00:00
# 19  2026-01-10T17:00:00+00:00
# 20  2026-01-10T17:00:00+00:00
# 21  2026-01-10T17:00:00+00:00
# 22  2026-01-10T17:00:00+00:00
# 23  2026-01-10T17:00:00+00:00
# 24  2026-01-10T17:00:00+00:00
# 25  2026-01-10T17:00:00+00:00
# 26  2026-01-10T17:00:00+00:00
# 27  2026-01-10T17:00:00+00:00
# 28  2026-01-10T17:00:00+00:00
# 29  2026-01-10T17:00:00+00:00
# 30  2026-01-10T17:00:00+00:00
# 31  2026-01-10T17:00:00+00:00
# 32  2026-01-10T17:00:00+00:00
# 33  2026-01-10T17:00:00+00:00
# 34  2026-01-10T17:00:00+00:00
# 35  2026-01-10T17:00:00+00:00
# 36  2026-01-10T17:00:00+00:00
# 37  2026-01-10T17:00:00+00:00
# 38  2026-01-10T17:00:00+00:00
# 39  2026-01-10T17:00:00+00:00
# 40  2026-01-10T17:00:00+00:00
# 41  2026-01-10T17:00:00+00:00
# 42  2026-01-10T17:00:00+00:00
# 43  2026-01-10T17:00:00+00:00
# 44  2026-01-10T17:00:00+00:00
# 45  2026-01-10T17:00:00+00:00
# 46  2026-01-10T17:00:00+00:00
# 47  2026-01-10T17:00:00+00:00
# 48  2026-01-10T17:00:00+00:00
# 49  2026-01-10T17:00:00+00:00
