# %%
import requests
import pandas as pd
from datetime import datetime, timedelta, timezone

API_TOKEN = "KuQ4Rt1ypOCvXfcm3cZXdPhOUlbuOrpHBgJkFm1MWTvtRR8TLhgEI02hjDxz"
BASE_URL = "https://api.sportmonks.com/v3/football"


def fetch_fixtures_next_12h() -> pd.DataFrame:
    """Return fixtures starting in the next 12 hours (UTC)."""
    now_utc = datetime.now(timezone.utc)
    end_utc = now_utc + timedelta(hours=12)

    start_date = now_utc.date()
    end_date = (now_utc + timedelta(days=1)).date()
    endpoint = f"/fixtures/between/{start_date:%Y-%m-%d}/{end_date:%Y-%m-%d}"

    session = requests.Session()
    fixtures = []
    page = 1

    while True:
        r = session.get(
            f"{BASE_URL}{endpoint}",
            params={"api_token": API_TOKEN, "page": page},
            timeout=30,
        )
        r.raise_for_status()
        payload = r.json()

        fixtures.extend(payload.get("data") or [])

        pagination = ((payload.get("meta") or {}).get("pagination")) or {}
        current = pagination.get("current_page")
        total = pagination.get("total_pages")
        if current is None or total is None or int(current) >= int(total):
            break
        page += 1

    df = pd.DataFrame(
        {
            "FixtureID": [f.get("id") for f in fixtures],
            "Fixture": [f.get("name") for f in fixtures],
            "StartingAt": [f.get("starting_at") for f in fixtures],
        }
    )

    if df.empty:
        return df

    df["StartingAt"] = pd.to_datetime(df["StartingAt"], utc=True, errors="coerce")
    df = df[df["StartingAt"].between(now_utc, end_utc)].reset_index(drop=True)
    return df


def _extract_bookmaker_name(odd: dict) -> str | None:
    bookmaker = odd.get("bookmaker") or {}
    name = bookmaker.get("name") if isinstance(bookmaker, dict) else None
    if not name:
        name = odd.get("bookmaker_name")
    return name


def fetch_odds_prematch_for_fixture(fixture_id: int, session: requests.Session) -> list[dict]:
    """Pull odds for a single fixture and shape the columns we need."""
    endpoint = f"/odds/pre-match/fixtures/{fixture_id}"

    r = session.get(
        f"{BASE_URL}{endpoint}",
        params={"api_token": API_TOKEN},
        timeout=30,
    )
    if r.status_code == 404:
        return []

    r.raise_for_status()
    odds = r.json().get("data") or []

    rows = []
    for odd in odds:
        rows.append(
            {
                "OddID": odd.get("id"),
                "FixtureID": odd.get("fixture_id"),
                "MarketID": odd.get("market_id"),
                "Bookmaker": _extract_bookmaker_name(odd),
                "MarketDescription": odd.get("market_description"),
                "Label": odd.get("label"),
                "Name": odd.get("name"),
                "Value": odd.get("value"),
                "DP3": odd.get("dp3"),
                "Total": odd.get("total"),
                "Handicap": odd.get("handicap"),
                "LatestBookmakerUpdate": odd.get("latest_bookmaker_update"),
            }
        )

    return rows


def fetch_odds_next_12h() -> pd.DataFrame:
    fixtures_df = fetch_fixtures_next_12h()
    if fixtures_df.empty:
        return pd.DataFrame()

    session = requests.Session()
    rows = []

    for fid in fixtures_df["FixtureID"].astype(int):
        rows.extend(fetch_odds_prematch_for_fixture(fid, session))

    df = pd.DataFrame(rows)
    if df.empty:
        return df

    df = df.merge(fixtures_df, on="FixtureID", how="left")

    df["Odds"] = pd.to_numeric(df["Value"], errors="coerce")
    df["Total"] = pd.to_numeric(df["Total"], errors="coerce")
    df["Handicap"] = pd.to_numeric(df["Handicap"], errors="coerce")

    df = df.dropna(subset=["Odds", "MarketID", "Bookmaker", "Label", "StartingAt"]).reset_index(drop=True)

    return df


# -------------------------
# Example usage
# -------------------------
df = fetch_odds_next_12h()

# Show a concise view without participant IDs/names or bookmaker IDs
columns_to_show = [
    "Fixture",
    "StartingAt",
    "Bookmaker",
    "MarketDescription",
    "Label",
    "Name",
    "Odds",
    "Total",
    "Handicap",
    "LatestBookmakerUpdate",
]

df[columns_to_show].head(50)
# Out:
# Empty DataFrame
# Columns: [Fixture, StartingAt, Bookmaker, MarketDescription, Label, Name, Odds, Total, Handicap, LatestBookmakerUpdate]
# Index: []

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta, timezone

API_TOKEN = "KuQ4Rt1ypOCvXfcm3cZXdPhOUlbuOrpHBgJkFm1MWTvtRR8TLhgEI02hjDxz"
BASE_URL = "https://api.sportmonks.com/v3/football"
BOOKMAKER_URL = "https://api.sportmonks.com/v3/odds/bookmakers"  # bookmaker lookup is under /v3/odds/...

# -------------------------
# Fixtures (next 12 hours)
# -------------------------
def fetch_fixtures_next_12h() -> pd.DataFrame:
    """Return fixtures starting in the next 12 hours (UTC)."""
    now_utc = datetime.now(timezone.utc)
    end_utc = now_utc + timedelta(hours=12)

    start_date = now_utc.date()
    end_date = (now_utc + timedelta(days=1)).date()
    endpoint = f"/fixtures/between/{start_date:%Y-%m-%d}/{end_date:%Y-%m-%d}"

    session = requests.Session()
    fixtures = []
    page = 1

    while True:
        r = session.get(
            f"{BASE_URL}{endpoint}",
            params={"api_token": API_TOKEN, "page": page},
            timeout=30,
        )
        r.raise_for_status()
        payload = r.json()

        fixtures.extend(payload.get("data") or [])

        # Pagination handling: be defensive across endpoints/plans
        pagination = ((payload.get("meta") or {}).get("pagination")) or {}
        has_more = pagination.get("has_more")
        total_pages = pagination.get("total_pages")
        current_page = pagination.get("current_page")

        if has_more is False:
            break
        if total_pages is not None and current_page is not None and int(current_page) >= int(total_pages):
            break
        if has_more is None and (total_pages is None or current_page is None):
            # If the API didn't return pagination metadata, assume single page.
            break

        page += 1

    df = pd.DataFrame(
        {
            "FixtureID": [f.get("id") for f in fixtures],
            "Fixture": [f.get("name") for f in fixtures],
            "StartingAt": [f.get("starting_at") for f in fixtures],
        }
    )

    if df.empty:
        return df

    df["StartingAt"] = pd.to_datetime(df["StartingAt"], utc=True, errors="coerce")
    df = df[df["StartingAt"].between(now_utc, end_utc)].reset_index(drop=True)
    return df


# -------------------------
# Bookmaker ID -> Name lookup (cached)
# -------------------------
def _get_bookmaker_name(bookmaker_id: int | None, session: requests.Session, cache: dict[int, str]) -> str | None:
    """
    Resolve bookmaker_id to bookmaker name via /v3/odds/bookmakers/{ID}.
    Caches results to avoid repeated calls.
    """
    if bookmaker_id is None:
        return None

    try:
        bookmaker_id_int = int(bookmaker_id)
    except (TypeError, ValueError):
        return None

    if bookmaker_id_int in cache:
        return cache[bookmaker_id_int]

    r = session.get(
        f"{BOOKMAKER_URL}/{bookmaker_id_int}",
        params={"api_token": API_TOKEN},
        timeout=30,
    )
    if r.status_code == 404:
        return None
    r.raise_for_status()

    data = (r.json() or {}).get("data") or {}
    name = data.get("name")
    if isinstance(name, str) and name.strip():
        cache[bookmaker_id_int] = name.strip()
        return cache[bookmaker_id_int]

    return None


# -------------------------
# Odds (keep ONLY the fields used in your first version)
# -------------------------
def fetch_odds_prematch_for_fixture(
    fixture_id: int,
    session: requests.Session,
    bookmaker_cache: dict[int, str],
) -> list[dict]:
    """Pull odds for a single fixture and shape the columns we need (first-code schema)."""
    endpoint = f"/odds/pre-match/fixtures/{fixture_id}"

    r = session.get(
        f"{BASE_URL}{endpoint}",
        params={"api_token": API_TOKEN},
        timeout=30,
    )
    if r.status_code == 404:
        return []

    r.raise_for_status()
    odds = r.json().get("data") or []

    rows = []
    for odd in odds:
        bookmaker_id = odd.get("bookmaker_id")
        bookmaker_name = _get_bookmaker_name(bookmaker_id, session, bookmaker_cache)

        rows.append(
            {
                "OddID": odd.get("id"),
                "FixtureID": odd.get("fixture_id"),
                "MarketID": odd.get("market_id"),
                "Bookmaker": bookmaker_name,  # <-- filled reliably via bookmaker_id lookup
                "Market": odd.get("market_description"),
                "Label": odd.get("label"),
                "Name": odd.get("name"),
                "Value": odd.get("value"),
                "DP3": odd.get("dp3"),
                "Total": odd.get("total"),
                "Handicap": odd.get("handicap"),
                "LatestBookmakerUpdate": odd.get("latest_bookmaker_update"),
            }
        )

    return rows


def fetch_odds_next_12h() -> pd.DataFrame:
    fixtures_df = fetch_fixtures_next_12h()
    if fixtures_df.empty:
        return pd.DataFrame()

    session = requests.Session()
    bookmaker_cache: dict[int, str] = {}
    rows: list[dict] = []

    for fid in fixtures_df["FixtureID"].astype(int):
        rows.extend(fetch_odds_prematch_for_fixture(fid, session, bookmaker_cache))

    df = pd.DataFrame(rows)
    if df.empty:
        return df

    df = df.merge(fixtures_df, on="FixtureID", how="left")

    # Normalize types
    df["Odds"] = pd.to_numeric(df["Value"], errors="coerce")
    df["Total"] = pd.to_numeric(df["Total"], errors="coerce")
    df["Handicap"] = pd.to_numeric(df["Handicap"], errors="coerce")

    # Drop unusable odds (same spirit as your original)
    df = df.dropna(subset=["Odds", "MarketID", "Bookmaker", "Label", "StartingAt"]).reset_index(drop=True)

    return df


# -------------------------
# Example usage
# -------------------------
df = fetch_odds_next_12h()

columns_to_show = [
    "StartingAt",
    "Fixture",
    "Bookmaker",
    "Market",
    "Label",
    "Odds",
    "Name",
    "Total",
    "Handicap",
    "LatestBookmakerUpdate",
]

df[columns_to_show].head(50)
# Out:
#                   StartingAt        Fixture    Bookmaker  \
# 0  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 1  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 2  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 3  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 4  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 5  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 6  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 7  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 8  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 9  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 10 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 11 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 12 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 13 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 14 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 15 2026-01-06 17:00:00+00:00  Lecce vs Roma  Marathonbet
# 16 2026-01-06 17:00:00+00:00  Lecce vs Roma        1xbet
# 17 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 18 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 19 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 20 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 21 2026-01-06 17:00:00+00:00  Lecce vs Roma        1xbet
# 22 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 23 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 24 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 25 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 26 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 27 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 28 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 29 2026-01-06 17:00:00+00:00  Lecce vs Roma        1xbet
# 30 2026-01-06 17:00:00+00:00  Lecce vs Roma  WilliamHill
# 31 2026-01-06 17:00:00+00:00  Lecce vs Roma  Marathonbet
# 32 2026-01-06 17:00:00+00:00  Lecce vs Roma  WilliamHill
# 33 2026-01-06 17:00:00+00:00  Lecce vs Roma  WilliamHill
# 34 2026-01-06 17:00:00+00:00  Lecce vs Roma  Marathonbet
# 35 2026-01-06 17:00:00+00:00  Lecce vs Roma     Pinnacle
# 36 2026-01-06 17:00:00+00:00  Lecce vs Roma  Interwetten
# 37 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 38 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 39 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 40 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 41 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 42 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 43 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 44 2026-01-06 17:00:00+00:00  Lecce vs Roma  Marathonbet
# 45 2026-01-06 17:00:00+00:00  Lecce vs Roma       Unibet
# 46 2026-01-06 17:00:00+00:00  Lecce vs Roma  WilliamHill
# 47 2026-01-06 17:00:00+00:00  Lecce vs Roma        1xbet
# 48 2026-01-06 17:00:00+00:00  Lecce vs Roma     888Sport
# 49 2026-01-06 17:00:00+00:00  Lecce vs Roma     888Sport
#
#                                 Market               Label    Odds  \
# 0                           Team Shots                   1    1.83
# 1                           Team Shots                   1    1.83
# 2                   1st Half Goal Line               Under    1.72
# 3       Alternative 1st Half Goal Line               Under    1.67
# 4                         Player Shots                 4.5   10.00
# 5                         Player Shots                 4.5   21.00
# 6                          Goalscorers             Anytime    8.50
# 7                          Goalscorers               First   34.00
# 8                          Goalscorers               First   41.00
# 9                          Goalscorers                Last   29.00
# 10                       Multi Scorers           3 or More  501.00
# 11       Player Headed Shots on Target                 0.5   29.00
# 12  Player Shots on Target Outside Box                 0.5   26.00
# 13                    Last Goal Scorer                Last   15.00
# 14                    Last Goal Scorer                Last   15.00
# 15                        HT/FT Double           Home/Draw   17.75
# 16                Highest Scoring Half                Draw    3.36
# 17                        Multicorners                Over    1.72
# 18             Half Time Correct Score                   1  351.00
# 19                     Team Goalscorer               First   23.00
# 20                 Player to be booked              Booked    3.40
# 21                       Correct Score                 8:9  100.00
# 22                    Half Time Result                Home    5.50
# 23                       Multi Scorers           3 or More  501.00
# 24                   1st Player Booked            1st Card   15.00
# 25                 Player to be booked              Booked    6.50
# 26           Player to Score or Assist  To Score or Assist    2.50
# 27                     1st Goal Scorer               First    4.75
# 28                     1st Goal Scorer               First   13.00
# 29                            Odd/Even                Even    1.80
# 30                   Odd/Even 1st Half                Even    1.65
# 31                   Odd/Even 1st Half                Even    1.61
# 32      Both Teams To Score - 2nd Half                 Yes    4.00
# 33      Both Teams To Score - 2nd Half                  No    1.20
# 34      Both Teams To Score - 2nd Half                  No    1.20
# 35                        Total - Away               Under    1.81
# 36                     Fulltime Result                Away    1.77
# 37                         Goalscorers             Anytime    9.50
# 38                        Corners Race             Neither    1.72
# 39                 Both Teams to Score                 Yes    2.00
# 40                        Player Shots                 0.5    2.25
# 41                        Player Shots                 4.5    8.00
# 42  Player Shots on Target Outside Box                 0.5    4.00
# 43                          Team Shots                   2    1.90
# 44                      Asian Handicap                Away    6.30
# 45                    Goals Over/Under                Over    1.38
# 46           Goals Over/Under 2nd Half                Over   15.00
# 47                        Total - Home                Over   15.50
# 48                     Fulltime Result                Home    5.00
# 49                     Fulltime Result                Draw    3.30
#
#                  Name  Total  Handicap LatestBookmakerUpdate
# 0                None    NaN       NaN   2026-01-04 19:40:37
# 1                None    NaN       NaN   2026-01-04 19:40:37
# 2                 1.0    1.0       NaN   2026-01-06 15:11:13
# 3                 1.0    1.0       NaN   2026-01-06 13:40:44
# 4   Santiago Pierotti    NaN       NaN   2026-01-06 15:11:13
# 5        Tete Morente    NaN       NaN   2026-01-06 15:11:13
# 6        Muhammed Bah    NaN       NaN   2026-01-06 15:11:13
# 7        Corrie Ndaba    NaN       NaN   2026-01-06 15:11:13
# 8        Matias Perez    NaN       NaN   2026-01-06 15:11:13
# 9       Jose Angelino    NaN       NaN   2026-01-06 15:11:13
# 10          Alex Sala    NaN       NaN   2026-01-06 15:11:13
# 11          Alex Sala    NaN       NaN   2026-01-06 15:11:13
# 12        Olaf Gorter    NaN       NaN   2026-01-06 15:11:13
# 13        Olaf Gorter    NaN       NaN   2026-01-06 15:11:13
# 14   Daniele Ghilardi    NaN       NaN   2026-01-06 15:11:13
# 15          Home/Draw    NaN       NaN   2026-01-06 06:39:50
# 16               Draw    NaN       NaN   2026-01-06 06:58:34
# 17               19.5    NaN       NaN   2026-01-06 15:11:13
# 18                3-2    NaN       NaN   2026-01-06 15:11:13
# 19       Matias Perez    NaN       NaN   2026-01-06 15:11:13
# 20          Alex Sala    NaN       NaN   2026-01-06 15:11:13
# 21                8:9    NaN       NaN   2026-01-06 03:28:24
# 22               None    NaN       NaN   2026-01-06 15:11:13
# 23          Gaby Jean    NaN       NaN   2026-01-06 15:11:13
# 24       Danilo Veiga    NaN       NaN   2026-01-06 15:11:13
# 25       Plamen Penev    NaN       NaN   2026-01-06 15:11:13
# 26        Leon Bailey    NaN       NaN   2026-01-06 15:11:13
# 27       Matias Soule    NaN       NaN   2026-01-06 15:11:13
# 28      Devyne Rensch    NaN       NaN   2026-01-06 15:11:13
# 29               Even    NaN       NaN   2026-01-06 05:10:30
# 30               Even    NaN       NaN   2025-12-31 17:19:40
# 31               Even    NaN       NaN   2026-01-06 05:10:16
# 32                Yes    NaN       NaN   2026-01-06 03:09:10
# 33                 No    NaN       NaN   2026-01-06 03:09:10
# 34                 No    NaN       NaN   2026-01-06 06:58:43
# 35              Under    1.5       NaN   2026-01-06 06:55:56
# 36               Away    NaN       NaN   2026-01-06 15:16:20
# 37      Youssef Maleh    NaN       NaN   2026-01-06 15:11:13
# 38                  7    NaN       NaN   2026-01-06 15:11:13
# 39               None    NaN       NaN   2026-01-06 15:11:13
# 40       Corrie Ndaba    NaN       NaN   2026-01-06 15:11:13
# 41      Nikola Stulic    NaN       NaN   2026-01-06 15:11:13
# 42        Leon Bailey    NaN       NaN   2026-01-06 15:11:13
# 43               None    NaN       NaN   2026-01-06 15:11:13
# 44               Away    NaN      2.25   2026-01-06 06:58:43
# 45               Over    1.5       NaN   2026-01-06 03:09:49
# 46               Over    3.5       NaN   2026-01-06 03:09:10
# 47               Over    2.5       NaN   2026-01-06 05:28:19
# 48               Home    NaN       NaN   2026-01-06 15:14:24
# 49               Draw    NaN       NaN   2026-01-06 15:14:24
