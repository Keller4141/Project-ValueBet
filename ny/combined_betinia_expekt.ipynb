# %%
import pandas as pd
import numpy as np
import re
import unicodedata

# =========================
# CONFIG
# =========================
BETINIA_CSV = "betinia_player_props.csv"
EXPEKT_CSV  = "expekt_player_props.csv"
BETANO_CSV  = "betano_player_props.csv"

OUT_COMBINED = "betinia_expekt_betano_combined.csv"

MERGE_WITH_DEADLINE = False

RATIO_THRESHOLD = 1.5
SECOND_BEST_MAX = 3.5

FINAL_COLUMNS = [
    "event",
    "player",
    "selectionLabel",
    "marketLabel",
    "payout_betinia",
    "payout_expekt",
    "payout_betano",
    "best_bookmaker",
    "best_payout",
    "second_best_payout",
    "ratio_best_over_second",
]

# =========================
# EVENT NORMALIZATION
# =========================
def strip_accents(s: str) -> str:
    if not isinstance(s, str):
        return s
    s = unicodedata.normalize("NFKD", s)
    return "".join(ch for ch in s if not unicodedata.combining(ch))

# VIGTIGT: her er dit komma efter "RCD" rettet, og vi håndterer Balompie også
DROP_TOKENS = {
    # generelle klubord
    "fc", "cf", "sc", "ac", "afc", "cfc",
    "ud", "cd", "rcd", "sv", "fk", "sk",
    "club", "klub", "calcio", "association",

    # typiske sponsornavne / ekstra
    "balompie", "balompie",  # efter accent-strip bliver balompié til balompie
    "deportivo",
}

# Nogle ord er farlige at droppe altid (fx "real" kan være en vigtig del af navnet).
# Jeg anbefaler IKKE at droppe "real" generelt.
# Hvis du virkelig vil, så gør det kun som trailing word og kun hvis der er mindst 2 ord tilbage.
DANGEROUS_TOKENS = {"real"}

def clean_team_name(team: str) -> str:
    """
    Normaliserer et holdnavn så "Levante UD" og "Levante" matcher,
    og "Real Betis Balompié" matcher "Real Betis".
    """
    if not isinstance(team, str):
        return None

    s = team.strip()
    s = strip_accents(s)
    s = s.lower()

    # fjern parenteser og tegnsætning
    s = re.sub(r"\([^)]*\)", " ", s)
    s = re.sub(r"[^\w\s]", " ", s)  # kun bogstaver tal underscore mellemrum
    s = re.sub(r"\s+", " ", s).strip()

    if not s:
        return None

    words = s.split()

    # drop leading tokens
    while len(words) >= 2 and words[0] in DROP_TOKENS:
        words.pop(0)

    # drop trailing tokens
    while len(words) >= 2 and words[-1] in DROP_TOKENS:
        words.pop()

    # ekstra: håndter "real" kun som trailing og kun hvis vi stadig har mindst 2 ord bagefter
    while len(words) >= 3 and words[-1] in DANGEROUS_TOKENS:
        words.pop()

    # pæn casing tilbage (title-case)
    out = " ".join(words).strip()
    out = re.sub(r"\s+", " ", out)
    return out.title() if out else None

def normalize_event(event: str) -> str:
    """
    Gør event-navn til "Hold1 vs Hold2" og normaliserer hvert hold.
    """
    if not isinstance(event, str):
        return None

    s = event.strip()

    # ensart separatorer
    s = s.replace(" vs. ", " vs ")
    s = s.replace(" v ", " vs ")
    s = s.replace(" - ", " vs ")

    # split på vs
    parts = [p.strip() for p in s.split("vs")]
    if len(parts) != 2:
        # fallback: bare accent-strip og whitespace
        s2 = strip_accents(s)
        s2 = re.sub(r"\s+", " ", s2).strip()
        return s2

    home_raw, away_raw = parts
    home = clean_team_name(home_raw)
    away = clean_team_name(away_raw)

    if not home or not away:
        s2 = strip_accents(s)
        s2 = re.sub(r"\s+", " ", s2).strip()
        return s2

    return f"{home} vs {away}"

# =========================
# LOAD
# =========================
df_betinia = pd.read_csv(BETINIA_CSV)
df_expekt  = pd.read_csv(EXPEKT_CSV)
df_betano  = pd.read_csv(BETANO_CSV)

if df_betinia.empty:
    raise ValueError("Betinia CSV er tom.")
if df_expekt.empty:
    raise ValueError("Expekt CSV er tom.")
if df_betano.empty:
    raise ValueError("Betano CSV er tom.")

# =========================
# NORMALIZE / TYPES
# =========================
def clean_df(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()

    # keys som strings uden spaces
    for c in ["event", "player", "selectionLabel", "marketLabel"]:
        if c in df.columns:
            df[c] = df[c].astype(str).str.strip()

    if "deadline" in df.columns:
        df["deadline"] = df["deadline"].astype(str).str.strip()

    # NORMALISER EVENT HER (vigtigt for merge)
    if "event" in df.columns:
        df["event"] = df["event"].apply(normalize_event)

    # odds -> float
    if "odds_decimal" in df.columns:
        df["odds_decimal"] = pd.to_numeric(df["odds_decimal"], errors="coerce")

    return df

df_betinia = clean_df(df_betinia)
df_expekt  = clean_df(df_expekt)
df_betano  = clean_df(df_betano)

# Rename odds/status per bookmaker
df_betinia = df_betinia.rename(columns={
    "odds_decimal": "odds_decimal_betinia",
    "status_selection": "status_selection_betinia",
})

df_expekt = df_expekt.rename(columns={
    "odds_decimal": "odds_decimal_expekt",
    "status_selection": "status_selection_expekt",
})

df_betano = df_betano.rename(columns={
    "odds_decimal": "odds_decimal_betano",
    "status_selection": "status_selection_betano",
})

# =========================
# MERGE KEYS
# =========================
if MERGE_WITH_DEADLINE:
    keys = ["event", "player", "selectionLabel", "marketLabel", "deadline"]
else:
    keys = ["event", "player", "selectionLabel", "marketLabel"]

# =========================
# OUTER MERGE
# =========================
df_merged = df_betinia.merge(df_expekt, on=keys, how="outer")
df_merged = df_merged.merge(df_betano, on=keys, how="outer")

# =========================
# PAYOUT COLS
# =========================
df_merged["payout_betinia"] = pd.to_numeric(df_merged.get("odds_decimal_betinia"), errors="coerce")
df_merged["payout_expekt"]  = pd.to_numeric(df_merged.get("odds_decimal_expekt"), errors="coerce")
df_merged["payout_betano"]  = pd.to_numeric(df_merged.get("odds_decimal_betano"), errors="coerce")

# =========================
# BEST + SECOND BEST
# =========================
payout_cols = ["payout_betinia", "payout_expekt", "payout_betano"]
payout_matrix = df_merged[payout_cols].copy()
payout_matrix = payout_matrix.where(payout_matrix > 0)

df_merged["best_payout"] = payout_matrix.max(axis=1)
df_merged["best_bookmaker"] = payout_matrix.idxmax(axis=1)

df_merged["best_bookmaker"] = df_merged["best_bookmaker"].map({
    "payout_betinia": "Betinia",
    "payout_expekt": "Expekt",
    "payout_betano": "Betano",
})

arr = payout_matrix.to_numpy(dtype=float)
sorted_vals = np.sort(arr, axis=1)

second_best = np.full(len(df_merged), np.nan, dtype=float)
for i in range(len(df_merged)):
    row = sorted_vals[i]
    row = row[~np.isnan(row)]
    if len(row) >= 2:
        second_best[i] = row[-2]

df_merged["second_best_payout"] = second_best

valid_best = (
    df_merged["best_payout"].notna() &
    df_merged["second_best_payout"].notna() &
    (df_merged["best_payout"] > 0) &
    (df_merged["second_best_payout"] > 0)
)

df_merged["ratio_best_over_second"] = np.nan
df_merged.loc[valid_best, "ratio_best_over_second"] = (
    df_merged.loc[valid_best, "best_payout"] / df_merged.loc[valid_best, "second_best_payout"]
)

# =========================
# FILTERS
# =========================
df_filtered = df_merged[
    valid_best &
    (df_merged["ratio_best_over_second"] >= RATIO_THRESHOLD) &
    (df_merged["second_best_payout"] <= SECOND_BEST_MAX)
].copy()

# =========================
# OUTPUT
# =========================
df_out = df_filtered[FINAL_COLUMNS].copy()
df_out = df_out.sort_values("ratio_best_over_second", ascending=False, kind="stable").reset_index(drop=True)

df_out.to_csv(OUT_COMBINED, index=False, encoding="utf-8")

print(f"Rows written to CSV: {len(df_out)}")
print(f"Saved CSV: {OUT_COMBINED}")
print(df_out.head(100).to_string(index=False))
# Out:
# Rows written to CSV: 248
# Saved CSV: betinia_expekt_betano_combined.csv
#                      event               player selectionLabel                                            marketLabel  payout_betinia  payout_expekt  payout_betano best_bookmaker  best_payout  second_best_payout  ratio_best_over_second
# Rayo Vallecano vs Mallorca       Alfonso Espino       Over 2.5           Spillers samlede antal skud | Alfonso Espino             NaN           2.15          10.25         Betano      10.2500              2.1500                4.767442
#            Udinese vs Pisa     Michel Aebischer            Yes                      Spiller scorer | Michel Aebischer          2.5455          11.00            NaN         Expekt      11.0000              2.5455                4.321351
#        Levante vs Espanyol        Ramon Terrats       Over 3.5            Spillers samlede antal skud | Ramon Terrats             NaN           3.20          13.00         Betano      13.0000              3.2000                4.062500
#         Atalanta vs Torino    Marco Brescianini       Over 3.5        Spillers samlede antal skud | Marco Brescianini          3.0000            NaN          12.00         Betano      12.0000              3.0000                4.000000
#            Udinese vs Pisa         Juan Arizala            Yes                          Spiller scorer | Juan Arizala          3.0000          10.00            NaN         Expekt      10.0000              3.0000                3.333333
#          Valencia vs Elche      Rodrigo Mendoza       Over 2.5          Spillers samlede antal skud | Rodrigo Mendoza          2.6000            NaN           8.50         Betano       8.5000              2.6000                3.269231
#       Villarreal vs Alaves   Georges Mikautadze       Over 4.5       Spillers samlede antal skud | Georges Mikautadze          1.7143           2.30           7.30         Betano       7.3000              2.3000                3.173913
#          Valencia vs Elche        Lucas Beltran       Over 2.5      Spillers samlede antal tacklinger | Lucas Beltran          3.5000          11.00            NaN         Expekt      11.0000              3.5000                3.142857
#         Atalanta vs Torino    Marco Brescianini       Over 1.5          Antal afslutninger på mål | Marco Brescianini          3.3334            NaN          10.25         Betano      10.2500              3.3334                3.074939
#         Atalanta vs Torino    Marco Brescianini       Over 2.5        Spillers samlede antal skud | Marco Brescianini          1.8000            NaN           5.40         Betano       5.4000              1.8000                3.000000
#            Udinese vs Pisa     Michel Aebischer       Over 0.5     Spillers samlede antal assister | Michel Aebischer          2.6667           8.00            NaN         Expekt       8.0000              2.6667                2.999963
#        Levante vs Espanyol    Roberto Fernandez       Over 0.5    Spillers samlede antal assister | Roberto Fernandez          2.5455           7.50            NaN         Expekt       7.5000              2.5455                2.946376
#       Villarreal vs Alaves          Ayoze Perez       Over 0.5          Spillers samlede antal assister | Ayoze Perez          1.7000           5.00            NaN         Expekt       5.0000              1.7000                2.941176
# Rayo Vallecano vs Mallorca       Alfonso Espino       Over 1.5           Spillers samlede antal skud | Alfonso Espino             NaN           1.33           3.90         Betano       3.9000              1.3300                2.932331
#        Algeriet vs Nigeria        Francis Uzoho            Yes                       Spiller får kort | Francis Uzoho             NaN           8.00           2.77         Expekt       8.0000              2.7700                2.888087
# Rayo Vallecano vs Mallorca                Abdon       Over 0.5                Spillers samlede antal assister | Abdon          3.2000           9.00            NaN         Expekt       9.0000              3.2000                2.812500
#         Atalanta vs Torino    Gianluca Scamacca       Over 0.5    Spillers samlede antal assister | Gianluca Scamacca          2.0000           5.50            NaN         Expekt       5.5000              2.0000                2.750000
#  Real Oviedo vs Real Betis         Lamine Gueye            Yes                        Spiller får kort | Lamine Gueye          2.7500           7.50            NaN         Expekt       7.5000              2.7500                2.727273
#          Valencia vs Elche       Aimar Blazquez       Over 0.5       Spillers samlede antal assister | Aimar Blazquez          2.4000            NaN           6.50         Betano       6.5000              2.4000                2.708333
#            Udinese vs Pisa       Samuele Angori       Over 0.5             Antal afslutninger på mål | Samuele Angori          3.0000           8.00            NaN         Expekt       8.0000              3.0000                2.666667
#  Real Oviedo vs Real Betis        Alberto Reina       Over 2.5            Spillers samlede antal skud | Alberto Reina          3.0000            NaN           7.70         Betano       7.7000              3.0000                2.566667
#  Real Oviedo vs Real Betis           Alex Fores       Over 0.5           Spillers samlede antal assister | Alex Fores          3.3334           8.50            NaN         Expekt       8.5000              3.3334                2.549949
#        Levante vs Espanyol         Jose Morales       Over 0.5         Spillers samlede antal assister | Jose Morales          2.7500            NaN           7.00         Betano       7.0000              2.7500                2.545455
#       Como 1907 vs Bologna        Ciro Immobile       Over 3.5            Spillers samlede antal skud | Ciro Immobile             NaN           3.00           7.60         Betano       7.6000              3.0000                2.533333
#         Atalanta vs Torino            Che Adams       Over 0.5            Spillers samlede antal assister | Che Adams          3.2000           8.00            NaN         Expekt       8.0000              3.2000                2.500000
#          Valencia vs Elche        Lucas Beltran       Over 0.5        Spillers samlede antal assister | Lucas Beltran          2.6000           6.50            NaN         Expekt       6.5000              2.6000                2.500000
#       Villarreal vs Alaves   Georges Mikautadze       Over 3.5       Spillers samlede antal skud | Georges Mikautadze          1.3200           1.53           3.80         Betano       3.8000              1.5300                2.483660
#        Levante vs Espanyol          Ivan Romero       Over 0.5          Spillers samlede antal assister | Ivan Romero          2.6667            NaN           6.60         Betano       6.6000              2.6667                2.474969
# Rayo Vallecano vs Mallorca           Pedro Diaz       Over 0.5           Spillers samlede antal assister | Pedro Diaz          3.0000            NaN           7.40         Betano       7.4000              3.0000                2.466667
#       Como 1907 vs Bologna     Maxence Caqueret       Over 2.5         Spillers samlede antal skud | Maxence Caqueret             NaN           2.70           6.60         Betano       6.6000              2.7000                2.444444
# Rayo Vallecano vs Mallorca        Carlos Martin       Over 0.5        Spillers samlede antal assister | Carlos Martin          2.4546           6.00            NaN         Expekt       6.0000              2.4546                2.444390
#          Valencia vs Elche          Adam Boayar       Over 0.5          Spillers samlede antal assister | Adam Boayar          3.2000            NaN           7.60         Betano       7.6000              3.2000                2.375000
#        Algeriet vs Nigeria       Ramiz Zerrouki       Over 1.5           Spillers samlede antal skud | Ramiz Zerrouki             NaN           2.25           5.30         Betano       5.3000              2.2500                2.355556
# Rayo Vallecano vs Mallorca         Samu Becerra       Over 0.5         Spillers samlede antal assister | Samu Becerra          3.2000            NaN           7.40         Betano       7.4000              3.2000                2.312500
#         Atalanta vs Torino      Gvidas Gineitis       Over 2.5          Spillers samlede antal skud | Gvidas Gineitis             NaN           3.50           8.00         Betano       8.0000              3.5000                2.285714
#  Real Oviedo vs Real Betis       Ivan Corralejo       Over 0.5       Spillers samlede antal assister | Ivan Corralejo          2.3637            NaN           5.40         Betano       5.4000              2.3637                2.284554
#            Udinese vs Pisa        Idrissa Gueye       Over 0.5        Spillers samlede antal assister | Idrissa Gueye          3.1000           7.00            NaN         Expekt       7.0000              3.1000                2.258065
# Rayo Vallecano vs Mallorca        Carlos Martin       Over 4.5            Spillers samlede antal skud | Carlos Martin          2.9000           6.50            NaN         Expekt       6.5000              2.9000                2.241379
# Rayo Vallecano vs Mallorca      Lucas Bergstrom            Yes                     Spiller får kort | Lucas Bergstrom             NaN           7.50           3.35         Expekt       7.5000              3.3500                2.238806
#          Valencia vs Elche      Rodrigo Mendoza       Over 1.5          Spillers samlede antal skud | Rodrigo Mendoza          1.5200            NaN           3.40         Betano       3.4000              1.5200                2.236842
# Egypten vs Elfenbenskysten       Evann Guessand       Over 3.5           Spillers samlede antal skud | Evann Guessand             NaN           2.70           6.00         Betano       6.0000              2.7000                2.222222
#            Udinese vs Pisa         Keinan Davis       Over 0.5         Spillers samlede antal assister | Keinan Davis          2.7143           6.00            NaN         Expekt       6.0000              2.7143                2.210515
#          Valencia vs Elche          Daniel Raba       Over 0.5          Spillers samlede antal assister | Daniel Raba          2.0500           4.50            NaN         Expekt       4.5000              2.0500                2.195122
#        Levante vs Espanyol       Pablo Martinez       Over 2.5           Spillers samlede antal skud | Pablo Martinez          1.7500           2.30           5.00         Betano       5.0000              2.3000                2.173913
#            Udinese vs Pisa         Sandi Lovric            Yes                        Spiller får kort | Sandi Lovric          2.3000           5.00            NaN         Expekt       5.0000              2.3000                2.173913
#        Algeriet vs Nigeria        Monsef Bakrar       Over 4.5            Spillers samlede antal skud | Monsef Bakrar             NaN           3.50           7.60         Betano       7.6000              3.5000                2.171429
# Rayo Vallecano vs Mallorca       Alfonso Espino       Over 0.5             Antal afslutninger på mål | Alfonso Espino             NaN           1.62           3.50         Betano       3.5000              1.6200                2.160494
#            Udinese vs Pisa        Lennon Miller       Over 0.5        Spillers samlede antal assister | Lennon Miller          2.8000           6.00            NaN         Expekt       6.0000              2.8000                2.142857
#        Algeriet vs Nigeria          Ilan Kebbal       Over 2.5              Spillers samlede antal skud | Ilan Kebbal             NaN           2.30           4.90         Betano       4.9000              2.3000                2.130435
#            Udinese vs Pisa           Iker Bravo       Over 0.5           Spillers samlede antal assister | Iker Bravo          3.1000           6.50            NaN         Expekt       6.5000              3.1000                2.096774
#            Udinese vs Pisa       Samuele Angori            Yes                      Spiller får kort | Samuele Angori          3.1000           6.50            NaN         Expekt       6.5000              3.1000                2.096774
#        Algeriet vs Nigeria      Ademola Lookman       Over 4.5          Spillers samlede antal skud | Ademola Lookman             NaN           3.40           7.10         Betano       7.1000              3.4000                2.088235
#  Real Oviedo vs Real Betis       Ivan Corralejo       Over 3.5           Spillers samlede antal skud | Ivan Corralejo          2.9000            NaN           6.00         Betano       6.0000              2.9000                2.068966
#        Algeriet vs Nigeria        Calvin Bassey            Yes                       Spiller får kort | Calvin Bassey             NaN           6.00           2.92         Expekt       6.0000              2.9200                2.054795
#       Como 1907 vs Bologna        Ciro Immobile       Over 2.5            Spillers samlede antal skud | Ciro Immobile             NaN           1.73           3.55         Betano       3.5500              1.7300                2.052023
#          Valencia vs Elche        Adria Pedrosa       Over 0.5              Antal afslutninger på mål | Adria Pedrosa          4.0000           1.95            NaN        Betinia       4.0000              1.9500                2.051282
#          Valencia vs Elche          Eray Comert            Yes                         Spiller får kort | Eray Comert          2.2000           4.50            NaN         Expekt       4.5000              2.2000                2.045455
#          Valencia vs Elche        Lucas Beltran       Over 1.5      Spillers samlede antal tacklinger | Lucas Beltran          2.2000           4.50            NaN         Expekt       4.5000              2.2000                2.045455
#        Levante vs Espanyol         Kareem Tunde       Over 2.5             Spillers samlede antal skud | Kareem Tunde          2.3000            NaN           4.70         Betano       4.7000              2.3000                2.043478
#       Como 1907 vs Bologna       Lewis Ferguson       Over 1.5           Spillers samlede antal skud | Lewis Ferguson             NaN           1.91           3.90         Betano       3.9000              1.9100                2.041885
#            Udinese vs Pisa   Christian Kabasele       Over 2.5 Spillers samlede antal tacklinger | Christian Kabasele          3.2000           6.50            NaN         Expekt       6.5000              3.2000                2.031250
#       Villarreal vs Alaves          Ayoze Perez       Over 2.5        Spillers samlede antal tacklinger | Ayoze Perez          3.2000           6.50            NaN         Expekt       6.5000              3.2000                2.031250
#          Valencia vs Elche       Arnaut Danjuma       Over 1.5             Antal afslutninger på mål | Arnaut Danjuma             NaN           4.20           2.07         Expekt       4.2000              2.0700                2.028986
#  Real Oviedo vs Real Betis         Ilyas Chaira       Over 0.5         Spillers samlede antal assister | Ilyas Chaira             NaN           7.00           3.45         Expekt       7.0000              3.4500                2.028986
#          Valencia vs Elche         David Otorbi       Over 0.5         Spillers samlede antal assister | David Otorbi          2.6667            NaN           5.40         Betano       5.4000              2.6667                2.024975
# Egypten vs Elfenbenskysten        Mohamed Salah       Over 3.5            Spillers samlede antal skud | Mohamed Salah             NaN           2.30           4.65         Betano       4.6500              2.3000                2.021739
# Rayo Vallecano vs Mallorca        Carlos Martin       Over 3.5            Spillers samlede antal skud | Carlos Martin          1.8750           3.75            NaN         Expekt       3.7500              1.8750                2.000000
#            Udinese vs Pisa       Matteo Tramoni       Over 3.5           Spillers samlede antal skud | Matteo Tramoni          3.0000           6.00            NaN         Expekt       6.0000              3.0000                2.000000
#       Villarreal vs Alaves               Calebe       Over 2.5             Spillers samlede antal tacklinger | Calebe          2.0000           4.00            NaN         Expekt       4.0000              2.0000                2.000000
#       Girona vs Ca Osasuna     Cristhian Stuani            Yes                    Spiller får kort | Cristhian Stuani             NaN           2.62           5.20         Betano       5.2000              2.6200                1.984733
#         Atalanta vs Torino   Kamaldeen Sulemana       Over 3.5       Spillers samlede antal skud | Kamaldeen Sulemana             NaN           2.88           5.70         Betano       5.7000              2.8800                1.979167
# Egypten vs Elfenbenskysten       Ghislain Konan       Over 1.5           Spillers samlede antal skud | Ghislain Konan             NaN           3.40           6.70         Betano       6.7000              3.4000                1.970588
#          Valencia vs Elche         Ruben Iranzo       Over 1.5             Spillers samlede antal skud | Ruben Iranzo          3.4000            NaN           6.70         Betano       6.7000              3.4000                1.970588
#         Atalanta vs Torino Charles De Ketelaere       Over 4.5     Spillers samlede antal skud | Charles De Ketelaere             NaN           3.10           6.10         Betano       6.1000              3.1000                1.967742
#        Levante vs Espanyol         Jose Morales       Over 3.5             Spillers samlede antal skud | Jose Morales          3.1000            NaN           6.10         Betano       6.1000              3.1000                1.967742
#        Levante vs Espanyol         Kareem Tunde       Over 0.5         Spillers samlede antal assister | Kareem Tunde          3.1000            NaN           6.10         Betano       6.1000              3.1000                1.967742
#       Villarreal vs Alaves        Ismael Sierra       Over 1.5            Spillers samlede antal skud | Ismael Sierra          3.0000            NaN           5.90         Betano       5.9000              3.0000                1.966667
#        Levante vs Espanyol    Roberto Fernandez            Yes                   Spiller får kort | Roberto Fernandez          2.8000           5.50            NaN         Expekt       5.5000              2.8000                1.964286
#            Udinese vs Pisa       Samuele Angori       Over 1.5           Spillers samlede antal skud | Samuele Angori          2.8000           5.50            NaN         Expekt       5.5000              2.8000                1.964286
#       Villarreal vs Alaves         Nicolas Pepe       Over 3.5             Spillers samlede antal skud | Nicolas Pepe          1.8500           2.40           4.70         Betano       4.7000              2.4000                1.958333
#         Atalanta vs Torino    Zakaria Aboukhlal       Over 2.5  Spillers samlede antal tacklinger | Zakaria Aboukhlal          1.9600           3.80            NaN         Expekt       3.8000              1.9600                1.938776
#            Udinese vs Pisa    Alessandro Zanoli       Over 1.5        Spillers samlede antal skud | Alessandro Zanoli          2.9000           1.50            NaN        Betinia       2.9000              1.5000                1.933333
#       Girona vs Ca Osasuna          Ivan Martin       Over 1.5              Spillers samlede antal skud | Ivan Martin             NaN           4.00           2.07         Expekt       4.0000              2.0700                1.932367
# Egypten vs Elfenbenskysten        Oumar Diakite       Over 2.5            Spillers samlede antal skud | Oumar Diakite             NaN           2.20           4.25         Betano       4.2500              2.2000                1.931818
#        Algeriet vs Nigeria        Monsef Bakrar       Over 3.5            Spillers samlede antal skud | Monsef Bakrar             NaN           2.05           3.95         Betano       3.9500              2.0500                1.926829
#       Girona vs Ca Osasuna         Thomas Lemar       Over 2.5             Spillers samlede antal skud | Thomas Lemar             NaN           2.05           3.95         Betano       3.9500              2.0500                1.926829
#         Atalanta vs Torino    Marco Brescianini       Over 1.5        Spillers samlede antal skud | Marco Brescianini          1.2308            NaN           2.37         Betano       2.3700              1.2308                1.925577
#        Algeriet vs Nigeria           Alex Iwobi       Over 2.5               Spillers samlede antal skud | Alex Iwobi             NaN           2.38           4.55         Betano       4.5500              2.3800                1.911765
#        Algeriet vs Nigeria       Cyriel Dessers       Over 3.5           Spillers samlede antal skud | Cyriel Dessers             NaN           2.88           5.50         Betano       5.5000              2.8800                1.909722
# Egypten vs Elfenbenskysten Jean-Philippe Krasso       Over 3.5     Spillers samlede antal skud | Jean-Philippe Krasso             NaN           2.40           4.55         Betano       4.5500              2.4000                1.895833
#       Como 1907 vs Bologna     Nicolo Cambiaghi       Over 0.5     Spillers samlede antal assister | Nicolo Cambiaghi             NaN           6.50           3.45         Expekt       6.5000              3.4500                1.884058
#  Real Oviedo vs Real Betis           Omar Falah       Over 0.5                 Antal afslutninger på mål | Omar Falah          3.4000            NaN           6.40         Betano       6.4000              3.4000                1.882353
#  Real Oviedo vs Real Betis       Cedric Bakambu       Over 1.5     Spillers samlede antal tacklinger | Cedric Bakambu          3.6667           1.95            NaN        Betinia       3.6667              1.9500                1.880359
#         Atalanta vs Torino    Marco Brescianini       Over 0.5          Antal afslutninger på mål | Marco Brescianini          1.4546            NaN           2.72         Betano       2.7200              1.4546                1.869930
#          Valencia vs Elche             Rafa Mir       Over 1.5           Spillers samlede antal tacklinger | Rafa Mir          4.2000           2.25            NaN        Betinia       4.2000              2.2500                1.866667
#        Levante vs Espanyol    Goduine Koyalipou       Over 3.5        Spillers samlede antal skud | Goduine Koyalipou             NaN           3.00           5.60         Betano       5.6000              3.0000                1.866667
#  Real Oviedo vs Real Betis                Natan       Over 2.5              Spillers samlede antal tacklinger | Natan          3.5000           6.50            NaN         Expekt       6.5000              3.5000                1.857143
#            Udinese vs Pisa       Matteo Tramoni       Over 1.5             Antal afslutninger på mål | Matteo Tramoni          3.5000           6.50            NaN         Expekt       6.5000              3.5000                1.857143
#  Real Oviedo vs Real Betis        Alberto Reina       Over 1.5            Spillers samlede antal skud | Alberto Reina          1.6800            NaN           3.10         Betano       3.1000              1.6800                1.845238
#       Villarreal vs Alaves       Tani Oluwaseyi       Over 4.5           Spillers samlede antal skud | Tani Oluwaseyi          3.1000           2.88           5.70         Betano       5.7000              3.1000                1.838710

# %%
import pandas as pd
import numpy as np
import unicodedata
import re

# =========================
# CONFIG
# =========================
BETINIA_CSV = "betinia_player_props.csv"
EXPEKT_CSV  = "expekt_player_props.csv"
BETANO_CSV  = "betano_player_props.csv"

OUT_COMBINED = "betinia_expekt_betano_combined.csv"

MERGE_WITH_DEADLINE = False

RATIO_THRESHOLD = 1.5
SECOND_BEST_MAX = 3.5

FINAL_COLUMNS = [
    "event",
    "marketLabel",
    "selectionLabel",
    "payout_betinia",
    "payout_expekt",
    "payout_betano",
    "best_bookmaker",
    "best_payout",
    "second_best_payout",
    "ratio_best_over_second",
]

# =========================
# EVENT NORMALIZATION
# =========================
def strip_accents(s: str) -> str:
    if not isinstance(s, str):
        return s
    s = unicodedata.normalize("NFKD", s)
    return "".join(ch for ch in s if not unicodedata.combining(ch))

DROP_TOKENS = {
    "fc", "cf", "sc", "ac", "afc", "cfc",
    "ud", "cd", "rcd", "sv", "fk", "sk",
    "club", "klub", "calcio", "association",
    "balompie",  # balompié -> balompie efter accent-strip
    "deportivo",
}

# "real" er farlig at droppe generelt, så vi dropper den kun som trailing
DANGEROUS_TOKENS = {"real"}

def clean_team_name(team: str) -> str:
    if not isinstance(team, str):
        return None

    s = strip_accents(team.strip()).lower()
    s = re.sub(r"\([^)]*\)", " ", s)
    s = re.sub(r"[^\w\s]", " ", s)
    s = re.sub(r"\s+", " ", s).strip()
    if not s:
        return None

    words = s.split()

    # drop leading tokens
    while len(words) >= 2 and words[0] in DROP_TOKENS:
        words.pop(0)

    # drop trailing tokens
    while len(words) >= 2 and words[-1] in DROP_TOKENS:
        words.pop()

    # drop trailing "real" kun hvis der stadig er mindst 2 ord bagefter
    while len(words) >= 3 and words[-1] in DANGEROUS_TOKENS:
        words.pop()

    out = " ".join(words).strip()
    out = re.sub(r"\s+", " ", out)
    return out.title() if out else None

def normalize_event(event: str) -> str:
    """
    Gør event-navn til "Hold1 vs Hold2" og normaliserer hvert hold.
    """
    if not isinstance(event, str):
        return None

    s = event.strip()
    s = s.replace(" vs. ", " vs ")
    s = s.replace(" v ", " vs ")
    s = s.replace(" - ", " vs ")

    parts = [p.strip() for p in s.split("vs")]
    if len(parts) != 2:
        s2 = strip_accents(s)
        s2 = re.sub(r"\s+", " ", s2).strip()
        return s2

    home_raw, away_raw = parts
    home = clean_team_name(home_raw)
    away = clean_team_name(away_raw)

    if not home or not away:
        s2 = strip_accents(s)
        s2 = re.sub(r"\s+", " ", s2).strip()
        return s2

    return f"{home} vs {away}"

# =========================
# LOAD
# =========================
df_betinia = pd.read_csv(BETINIA_CSV)
df_expekt  = pd.read_csv(EXPEKT_CSV)
df_betano  = pd.read_csv(BETANO_CSV)

if df_betinia.empty:
    raise ValueError("Betinia CSV er tom.")
if df_expekt.empty:
    raise ValueError("Expekt CSV er tom.")
if df_betano.empty:
    raise ValueError("Betano CSV er tom.")

# =========================
# CLEAN
# =========================
def clean_df(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()

    for c in ["event", "player", "selectionLabel", "marketLabel"]:
        if c in df.columns:
            df[c] = df[c].astype(str).str.strip()

    if "deadline" in df.columns:
        df["deadline"] = df["deadline"].astype(str).str.strip()

    if "odds_decimal" in df.columns:
        df["odds_decimal"] = pd.to_numeric(df["odds_decimal"], errors="coerce")

    if "event" in df.columns:
        df["event"] = df["event"].apply(normalize_event)

    return df

df_betinia = clean_df(df_betinia)
df_expekt  = clean_df(df_expekt)
df_betano  = clean_df(df_betano)

# rename odds/status
df_betinia = df_betinia.rename(columns={
    "odds_decimal": "odds_decimal_betinia",
    "status_selection": "status_selection_betinia",
})
df_expekt = df_expekt.rename(columns={
    "odds_decimal": "odds_decimal_expekt",
    "status_selection": "status_selection_expekt",
})
df_betano = df_betano.rename(columns={
    "odds_decimal": "odds_decimal_betano",
    "status_selection": "status_selection_betano",
})

# =========================
# MERGE
# =========================
if MERGE_WITH_DEADLINE:
    keys = ["event", "player", "selectionLabel", "marketLabel", "deadline"]
else:
    keys = ["event", "player", "selectionLabel", "marketLabel"]

df_merged = df_betinia.merge(df_expekt, on=keys, how="outer")
df_merged = df_merged.merge(df_betano, on=keys, how="outer")

# =========================
# PAYOUT COLS
# =========================
df_merged["payout_betinia"] = pd.to_numeric(df_merged.get("odds_decimal_betinia"), errors="coerce")
df_merged["payout_expekt"]  = pd.to_numeric(df_merged.get("odds_decimal_expekt"), errors="coerce")
df_merged["payout_betano"]  = pd.to_numeric(df_merged.get("odds_decimal_betano"), errors="coerce")

# -------------------------
# NYT KRAV: alle tre skal findes (ingen NaN) + være > 0
# -------------------------
all_three_present = (
    df_merged["payout_betinia"].notna() &
    df_merged["payout_expekt"].notna() &
    df_merged["payout_betano"].notna() &
    (df_merged["payout_betinia"] > 0) &
    (df_merged["payout_expekt"] > 0) &
    (df_merged["payout_betano"] > 0)
)

# =========================
# BEST + SECOND BEST
# =========================
payout_cols = ["payout_betinia", "payout_expekt", "payout_betano"]
payout_matrix = df_merged[payout_cols].copy()
payout_matrix = payout_matrix.where(payout_matrix > 0)

df_merged["best_payout"] = payout_matrix.max(axis=1)
df_merged["best_bookmaker"] = payout_matrix.idxmax(axis=1)

df_merged["best_bookmaker"] = df_merged["best_bookmaker"].map({
    "payout_betinia": "Betinia",
    "payout_expekt": "Expekt",
    "payout_betano": "Betano",
})

arr = payout_matrix.to_numpy(dtype=float)
sorted_vals = np.sort(arr, axis=1)

second_best = np.full(len(df_merged), np.nan, dtype=float)
for i in range(len(df_merged)):
    row = sorted_vals[i]
    row = row[~np.isnan(row)]
    if len(row) >= 2:
        second_best[i] = row[-2]

df_merged["second_best_payout"] = second_best

valid_best = (
    df_merged["best_payout"].notna() &
    df_merged["second_best_payout"].notna() &
    (df_merged["best_payout"] > 0) &
    (df_merged["second_best_payout"] > 0)
)

df_merged["ratio_best_over_second"] = np.nan
df_merged.loc[valid_best, "ratio_best_over_second"] = (
    df_merged.loc[valid_best, "best_payout"] / df_merged.loc[valid_best, "second_best_payout"]
)

# =========================
# FILTERS
# =========================
df_filtered = df_merged[
    all_three_present &               # <-- NYT: kræv alle tre bookmakere
    valid_best &
    (df_merged["ratio_best_over_second"] >= RATIO_THRESHOLD) &
    (df_merged["second_best_payout"] <= SECOND_BEST_MAX)
].copy()

# =========================
# OUTPUT
# =========================
df_out = df_filtered[FINAL_COLUMNS].copy()
df_out = df_out.sort_values("ratio_best_over_second", ascending=False, kind="stable").reset_index(drop=True)

df_out.to_csv(OUT_COMBINED, index=False, encoding="utf-8")

print(f"Rows written to CSV: {len(df_out)}")
print(f"Saved CSV: {OUT_COMBINED}")
print(df_out.head(100).to_string(index=False))
# Out:
# Rows written to CSV: 30
# Saved CSV: betinia_expekt_betano_combined.csv
#                     event                                       marketLabel selectionLabel  payout_betinia  payout_expekt  payout_betano best_bookmaker  best_payout  second_best_payout  ratio_best_over_second
#      Villarreal vs Alaves  Spillers samlede antal skud | Georges Mikautadze       Over 4.5          1.7143           2.30           7.30         Betano         7.30              2.3000                3.173913
#      Villarreal vs Alaves  Spillers samlede antal skud | Georges Mikautadze       Over 3.5          1.3200           1.53           3.80         Betano         3.80              1.5300                2.483660
#       Levante vs Espanyol      Spillers samlede antal skud | Pablo Martinez       Over 2.5          1.7500           2.30           5.00         Betano         5.00              2.3000                2.173913
#      Villarreal vs Alaves        Spillers samlede antal skud | Nicolas Pepe       Over 3.5          1.8500           2.40           4.70         Betano         4.70              2.4000                1.958333
#      Villarreal vs Alaves      Spillers samlede antal skud | Tani Oluwaseyi       Over 4.5          3.1000           2.88           5.70         Betano         5.70              3.1000                1.838710
#       Levante vs Espanyol        Antal afslutninger på mål | Pablo Martinez       Over 0.5          1.7143           1.67           3.00         Betano         3.00              1.7143                1.749985
#       Levante vs Espanyol         Antal afslutninger på mål | Carlos Romero       Over 0.5          2.6000           5.00           2.90         Expekt         5.00              2.9000                1.724138
#      Villarreal vs Alaves      Spillers samlede antal skud | Tajon Buchanan       Over 2.5          2.0000           2.00           3.40         Betano         3.40              2.0000                1.700000
#         Valencia vs Elche                Spiller får kort | Largie Ramazani            Yes          2.8572           3.30           5.60         Betano         5.60              3.3000                1.696970
#        Atalanta vs Torino                   Spiller får kort | Saba Sazonov            Yes          3.0000           2.62           5.00         Betano         5.00              3.0000                1.666667
#         Valencia vs Elche              Spiller får kort | David Affengruber            Yes          3.0000           5.00           2.07         Expekt         5.00              3.0000                1.666667
#       Levante vs Espanyol      Spillers samlede antal skud | Pablo Martinez       Over 1.5          1.2223           1.40           2.27         Betano         2.27              1.4000                1.621429
#       Levante vs Espanyol                  Spiller får kort | Alan Matturro            Yes          3.4000           5.50           3.40         Expekt         5.50              3.4000                1.617647
# Real Oviedo vs Real Betis                      Spiller får kort | Luka Ilic            Yes          3.0000           5.50           3.40         Expekt         5.50              3.4000                1.617647
#      Villarreal vs Alaves Spillers samlede antal assister | Alfonso Pedraza       Over 0.5          3.2000           5.50           3.40         Expekt         5.50              3.4000                1.617647
#      Villarreal vs Alaves     Spillers samlede antal skud | Alberto Moleiro       Over 3.5          1.6471           2.60           4.20         Betano         4.20              2.6000                1.615385
#       Levante vs Espanyol     Spillers samlede antal skud | Leandro Cabrera       Over 1.5          3.1000           5.00           2.67         Expekt         5.00              3.1000                1.612903
#       Levante vs Espanyol        Spillers samlede antal skud | Antoniu Roca       Over 2.5          2.7500           4.50           2.82         Expekt         4.50              2.8200                1.595745
#      Villarreal vs Alaves        Spillers samlede antal skud | Nicolas Pepe       Over 2.5          1.3200           1.53           2.42         Betano         2.42              1.5300                1.581699
#       Levante vs Espanyol                 Spiller får kort | Pablo Martinez            Yes          2.8000           5.50           3.50         Expekt         5.50              3.5000                1.571429
#         Valencia vs Elche          Spillers samlede antal skud | Ali Houary       Over 2.5          3.5000           5.50           2.82         Expekt         5.50              3.5000                1.571429
#      Villarreal vs Alaves      Spillers samlede antal skud | Tani Oluwaseyi       Over 3.5          1.9500           1.80           3.05         Betano         3.05              1.9500                1.564103
#       Levante vs Espanyol       Antal afslutninger på mål | Leandro Cabrera       Over 0.5          3.2000           5.00           2.60         Expekt         5.00              3.2000                1.562500
#        Atalanta vs Torino                Spiller får kort | Gvidas Gineitis            Yes          3.4000           3.00           5.30         Betano         5.30              3.4000                1.558824
#      Villarreal vs Alaves          Antal afslutninger på mål | Nicolas Pepe       Over 1.5          2.1000           2.88           4.45         Betano         4.45              2.8800                1.545139
#      Villarreal vs Alaves  Spillers samlede antal assister | Tani Oluwaseyi       Over 0.5          1.6471           3.50           5.40         Betano         5.40              3.5000                1.542857
#       Levante vs Espanyol        Spillers samlede antal skud | Diego Pampin       Over 0.5          1.4546           1.50           2.30         Betano         2.30              1.5000                1.533333
#         Valencia vs Elche        Spillers samlede antal skud | Alvaro Nunez       Over 0.5          1.5834           1.50           2.42         Betano         2.42              1.5834                1.528357
#       Levante vs Espanyol       Spillers samlede antal skud | Carlos Romero       Over 1.5          2.5000           3.75           2.50         Expekt         3.75              2.5000                1.500000
#       Levante vs Espanyol                       Spiller scorer | Javi Puado            Yes          3.0000           4.50           2.87         Expekt         4.50              3.0000                1.500000
