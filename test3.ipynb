# %%
import requests
import pandas as pd
from datetime import datetime, timedelta, timezone

API_TOKEN = "KuQ4Rt1ypOCvXfcm3cZXdPhOUlbuOrpHBgJkFm1MWTvtRR8TLhgEI02hjDxz"
BASE_URL = "https://api.sportmonks.com/v3/football"
BOOKMAKER_URL = "https://api.sportmonks.com/v3/odds/bookmakers"  # bookmaker lookup is under /v3/odds/...

# -------------------------
# Fixtures (next 12 hours)
# -------------------------
def fetch_fixtures_next_12h() -> pd.DataFrame:
    """Return fixtures starting in the next 12 hours (UTC)."""
    now_utc = datetime.now(timezone.utc)
    end_utc = now_utc + timedelta(hours=12)

    start_date = now_utc.date()
    end_date = (now_utc + timedelta(days=1)).date()
    endpoint = f"/fixtures/between/{start_date:%Y-%m-%d}/{end_date:%Y-%m-%d}"

    session = requests.Session()
    fixtures = []
    page = 1

    while True:
        r = session.get(
            f"{BASE_URL}{endpoint}",
            params={"api_token": API_TOKEN, "page": page},
            timeout=30,
        )
        r.raise_for_status()
        payload = r.json()

        fixtures.extend(payload.get("data") or [])

        # Pagination handling: be defensive across endpoints/plans
        pagination = ((payload.get("meta") or {}).get("pagination")) or {}
        has_more = pagination.get("has_more")
        total_pages = pagination.get("total_pages")
        current_page = pagination.get("current_page")

        if has_more is False:
            break
        if total_pages is not None and current_page is not None and int(current_page) >= int(total_pages):
            break
        if has_more is None and (total_pages is None or current_page is None):
            # If the API didn't return pagination metadata, assume single page.
            break

        page += 1

    df = pd.DataFrame(
        {
            "FixtureID": [f.get("id") for f in fixtures],
            "Fixture": [f.get("name") for f in fixtures],
            "StartingAt": [f.get("starting_at") for f in fixtures],
        }
    )

    if df.empty:
        return df

    df["StartingAt"] = pd.to_datetime(df["StartingAt"], utc=True, errors="coerce")
    df = df[df["StartingAt"].between(now_utc, end_utc)].reset_index(drop=True)
    return df


# -------------------------
# Bookmaker ID -> Name lookup (cached)
# -------------------------
def _get_bookmaker_name(bookmaker_id: int | None, session: requests.Session, cache: dict[int, str]) -> str | None:
    """
    Resolve bookmaker_id to bookmaker name via /v3/odds/bookmakers/{ID}.
    Caches results to avoid repeated calls.
    """
    if bookmaker_id is None:
        return None

    try:
        bookmaker_id_int = int(bookmaker_id)
    except (TypeError, ValueError):
        return None

    if bookmaker_id_int in cache:
        return cache[bookmaker_id_int]

    r = session.get(
        f"{BOOKMAKER_URL}/{bookmaker_id_int}",
        params={"api_token": API_TOKEN},
        timeout=30,
    )
    if r.status_code == 404:
        return None
    r.raise_for_status()

    data = (r.json() or {}).get("data") or {}
    name = data.get("name")
    if isinstance(name, str) and name.strip():
        cache[bookmaker_id_int] = name.strip()
        return cache[bookmaker_id_int]

    return None


# -------------------------
# Odds (keep ONLY the fields used in your first version)
# -------------------------
def fetch_odds_prematch_for_fixture(
    fixture_id: int,
    session: requests.Session,
    bookmaker_cache: dict[int, str],
) -> list[dict]:
    """Pull odds for a single fixture and shape the columns we need (first-code schema)."""
    endpoint = f"/odds/pre-match/fixtures/{fixture_id}"

    r = session.get(
        f"{BASE_URL}{endpoint}",
        params={"api_token": API_TOKEN},
        timeout=30,
    )
    if r.status_code == 404:
        return []

    r.raise_for_status()
    odds = r.json().get("data") or []

    rows = []
    for odd in odds:
        bookmaker_id = odd.get("bookmaker_id")
        bookmaker_name = _get_bookmaker_name(bookmaker_id, session, bookmaker_cache)

        rows.append(
            {
                "OddID": odd.get("id"),
                "FixtureID": odd.get("fixture_id"),
                "MarketID": odd.get("market_id"),
                "Bookmaker": bookmaker_name,  # <-- filled reliably via bookmaker_id lookup
                "Market": odd.get("market_description"),
                "Label": odd.get("label"),
                "Name": odd.get("name"),
                "Value": odd.get("value"),
                "DP3": odd.get("dp3"),
                "Total": odd.get("total"),
                "Handicap": odd.get("handicap"),
                "LatestBookmakerUpdate": odd.get("latest_bookmaker_update"),
            }
        )

    return rows


def fetch_odds_next_12h() -> pd.DataFrame:
    fixtures_df = fetch_fixtures_next_12h()
    if fixtures_df.empty:
        return pd.DataFrame()

    session = requests.Session()
    bookmaker_cache: dict[int, str] = {}
    rows: list[dict] = []

    for fid in fixtures_df["FixtureID"].astype(int):
        rows.extend(fetch_odds_prematch_for_fixture(fid, session, bookmaker_cache))

    df = pd.DataFrame(rows)
    if df.empty:
        return df

    df = df.merge(fixtures_df, on="FixtureID", how="left")

    # Normalize types
    df["Odds"] = pd.to_numeric(df["Value"], errors="coerce")
    df["Total"] = pd.to_numeric(df["Total"], errors="coerce")
    df["Handicap"] = pd.to_numeric(df["Handicap"], errors="coerce")

    # Drop unusable odds (same spirit as your original)
    df = df.dropna(subset=["Odds", "MarketID", "Bookmaker", "Label", "StartingAt"]).reset_index(drop=True)

    return df


# -------------------------
# Example usage
# -------------------------
df = fetch_odds_next_12h()

columns_to_show = [
    "StartingAt",
    "Fixture",
    "Bookmaker",
    "Market",
    "Label",
    "Odds",
    "Name",
    "Total",
    "Handicap",
    "LatestBookmakerUpdate",
]

df[columns_to_show].head(50)
# Out:
#                   StartingAt        Fixture    Bookmaker  \
# 0  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 1  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 2  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 3  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 4  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 5  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 6  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 7  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 8  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 9  2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 10 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 11 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 12 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 13 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 14 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 15 2026-01-06 17:00:00+00:00  Lecce vs Roma  Marathonbet
# 16 2026-01-06 17:00:00+00:00  Lecce vs Roma        1xbet
# 17 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 18 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 19 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 20 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 21 2026-01-06 17:00:00+00:00  Lecce vs Roma        1xbet
# 22 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 23 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 24 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 25 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 26 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 27 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 28 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 29 2026-01-06 17:00:00+00:00  Lecce vs Roma        1xbet
# 30 2026-01-06 17:00:00+00:00  Lecce vs Roma  WilliamHill
# 31 2026-01-06 17:00:00+00:00  Lecce vs Roma  Marathonbet
# 32 2026-01-06 17:00:00+00:00  Lecce vs Roma  WilliamHill
# 33 2026-01-06 17:00:00+00:00  Lecce vs Roma  WilliamHill
# 34 2026-01-06 17:00:00+00:00  Lecce vs Roma  Marathonbet
# 35 2026-01-06 17:00:00+00:00  Lecce vs Roma     Pinnacle
# 36 2026-01-06 17:00:00+00:00  Lecce vs Roma  Interwetten
# 37 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 38 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 39 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 40 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 41 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 42 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 43 2026-01-06 17:00:00+00:00  Lecce vs Roma       bet365
# 44 2026-01-06 17:00:00+00:00  Lecce vs Roma  Marathonbet
# 45 2026-01-06 17:00:00+00:00  Lecce vs Roma       Unibet
# 46 2026-01-06 17:00:00+00:00  Lecce vs Roma  WilliamHill
# 47 2026-01-06 17:00:00+00:00  Lecce vs Roma        1xbet
# 48 2026-01-06 17:00:00+00:00  Lecce vs Roma     888Sport
# 49 2026-01-06 17:00:00+00:00  Lecce vs Roma     888Sport
#
#                                 Market               Label    Odds  \
# 0                           Team Shots                   1    1.83
# 1                           Team Shots                   1    1.83
# 2                   1st Half Goal Line               Under    1.72
# 3       Alternative 1st Half Goal Line               Under    1.67
# 4                         Player Shots                 4.5   11.00
# 5                         Player Shots                 4.5   21.00
# 6                          Goalscorers             Anytime    8.50
# 7                          Goalscorers               First   34.00
# 8                          Goalscorers               First   41.00
# 9                          Goalscorers                Last   29.00
# 10                       Multi Scorers           3 or More  501.00
# 11       Player Headed Shots on Target                 0.5   29.00
# 12  Player Shots on Target Outside Box                 0.5   26.00
# 13                    Last Goal Scorer                Last   15.00
# 14                    Last Goal Scorer                Last   15.00
# 15                        HT/FT Double           Home/Draw   17.75
# 16                Highest Scoring Half                Draw    3.38
# 17                        Multicorners                Over    1.72
# 18             Half Time Correct Score                   1  301.00
# 19                     Team Goalscorer               First   23.00
# 20                 Player to be booked              Booked    3.40
# 21                       Correct Score                 8:9  100.00
# 22                    Half Time Result                Home    5.50
# 23                       Multi Scorers           3 or More  501.00
# 24                   1st Player Booked            1st Card   15.00
# 25                 Player to be booked              Booked    6.50
# 26           Player to Score or Assist  To Score or Assist    2.50
# 27                     1st Goal Scorer               First    4.75
# 28                     1st Goal Scorer               First   13.00
# 29                            Odd/Even                Even    1.79
# 30                   Odd/Even 1st Half                Even    1.65
# 31                   Odd/Even 1st Half                Even    1.60
# 32      Both Teams To Score - 2nd Half                 Yes    4.00
# 33      Both Teams To Score - 2nd Half                  No    1.20
# 34      Both Teams To Score - 2nd Half                  No    1.20
# 35                        Total - Away               Under    1.81
# 36                     Fulltime Result                Away    1.77
# 37                         Goalscorers             Anytime    9.50
# 38                        Corners Race             Neither    1.72
# 39                 Both Teams to Score                 Yes    2.05
# 40                        Player Shots                 0.5    2.25
# 41                        Player Shots                 4.5    8.00
# 42  Player Shots on Target Outside Box                 0.5    4.00
# 43                          Team Shots                   2    1.90
# 44                      Asian Handicap                Away    6.25
# 45                    Goals Over/Under                Over    1.38
# 46           Goals Over/Under 2nd Half                Over   15.00
# 47                        Total - Home                Over   15.50
# 48                     Fulltime Result                Home    5.00
# 49                     Fulltime Result                Draw    3.30
#
#                  Name  Total  Handicap LatestBookmakerUpdate
# 0                None    NaN       NaN   2026-01-04 19:40:37
# 1                None    NaN       NaN   2026-01-04 19:40:37
# 2                 1.0    1.0       NaN   2026-01-06 16:10:37
# 3                 1.0    1.0       NaN   2026-01-06 13:40:44
# 4   Santiago Pierotti    NaN       NaN   2026-01-06 16:10:37
# 5        Tete Morente    NaN       NaN   2026-01-06 16:10:37
# 6        Muhammed Bah    NaN       NaN   2026-01-06 16:10:37
# 7        Corrie Ndaba    NaN       NaN   2026-01-06 16:10:37
# 8        Matias Perez    NaN       NaN   2026-01-06 16:10:37
# 9       Jose Angelino    NaN       NaN   2026-01-06 16:10:37
# 10          Alex Sala    NaN       NaN   2026-01-06 16:10:37
# 11          Alex Sala    NaN       NaN   2026-01-06 16:10:37
# 12        Olaf Gorter    NaN       NaN   2026-01-06 16:10:37
# 13        Olaf Gorter    NaN       NaN   2026-01-06 16:10:37
# 14   Daniele Ghilardi    NaN       NaN   2026-01-06 16:10:37
# 15          Home/Draw    NaN       NaN   2026-01-06 07:49:46
# 16               Draw    NaN       NaN   2026-01-06 07:04:16
# 17               19.5    NaN       NaN   2026-01-06 16:10:37
# 18                3-2    NaN       NaN   2026-01-06 16:10:37
# 19       Matias Perez    NaN       NaN   2026-01-06 16:10:37
# 20          Alex Sala    NaN       NaN   2026-01-06 16:10:37
# 21                8:9    NaN       NaN   2026-01-06 03:28:24
# 22               None    NaN       NaN   2026-01-06 16:10:37
# 23          Gaby Jean    NaN       NaN   2026-01-06 16:10:37
# 24       Danilo Veiga    NaN       NaN   2026-01-06 16:10:37
# 25       Plamen Penev    NaN       NaN   2026-01-06 16:10:37
# 26        Leon Bailey    NaN       NaN   2026-01-06 16:10:37
# 27       Matias Soule    NaN       NaN   2026-01-06 16:10:37
# 28      Devyne Rensch    NaN       NaN   2026-01-06 16:10:37
# 29               Even    NaN       NaN   2026-01-06 07:25:15
# 30               Even    NaN       NaN   2025-12-31 17:19:40
# 31               Even    NaN       NaN   2026-01-06 07:25:35
# 32                Yes    NaN       NaN   2026-01-06 03:09:10
# 33                 No    NaN       NaN   2026-01-06 03:09:10
# 34                 No    NaN       NaN   2026-01-06 07:34:22
# 35              Under    1.5       NaN   2026-01-06 07:25:55
# 36               Away    NaN       NaN   2026-01-06 15:59:55
# 37      Youssef Maleh    NaN       NaN   2026-01-06 16:10:37
# 38                  7    NaN       NaN   2026-01-06 16:10:37
# 39               None    NaN       NaN   2026-01-06 16:10:37
# 40       Corrie Ndaba    NaN       NaN   2026-01-06 16:10:37
# 41      Nikola Stulic    NaN       NaN   2026-01-06 16:10:37
# 42        Leon Bailey    NaN       NaN   2026-01-06 16:10:37
# 43               None    NaN       NaN   2026-01-06 16:10:37
# 44               Away    NaN      2.25   2026-01-06 07:53:56
# 45               Over    1.5       NaN   2026-01-06 03:09:49
# 46               Over    3.5       NaN   2026-01-06 03:09:10
# 47               Over    2.5       NaN   2026-01-06 05:28:19
# 48               Home    NaN       NaN   2026-01-06 15:58:07
# 49               Draw    NaN       NaN   2026-01-06 15:58:07

# %%
import pandas as pd
import numpy as np

def find_valuebets(
    df: pd.DataFrame,
    pct_threshold: float = 0.30,
    min_bookmakers: int = 3,
    group_cols: list[str] | None = None,
    odds_col: str = "Odds",
    bookmaker_col: str = "Bookmaker",
    # normalization so 1.5 vs 1.50 don't split groups:
    line_round: int = 3,
    na_sentinel: str = "__NA__",
    # optional: avoid multiple rows per bookmaker for same selection
    dedupe_per_bookmaker: bool = True,
    dedupe_keep: str = "best",  # "best" (max odds) or "latest"
    latest_col: str = "LatestBookmakerUpdate",
) -> pd.DataFrame:
    """
    Valuebet if Odds >= (1 + pct_threshold) * median(Odds) within the same selection group.

    Grouping default (as you requested):
      FixtureID, MarketID, Label, Name, Total, Handicap

    Adds:
      MedianOdds, ValueThreshold, IsValueBet, ComparedCount, ComparedBookmakers, ComparedOdds
    """
    out = df.copy()

    if group_cols is None:
        group_cols = ["FixtureID", "MarketID", "Label", "Name", "Total", "Handicap"]

    # --- Required columns check ---
    required = [odds_col, bookmaker_col] + group_cols
    missing = [c for c in required if c not in out.columns]
    if missing:
        raise KeyError(f"Missing required columns: {missing}")

    # --- Normalize core types ---
    out[odds_col] = pd.to_numeric(out[odds_col], errors="coerce")
    out[bookmaker_col] = out[bookmaker_col].astype("string")

    # Total/Handicap should be numeric for stable rounding/grouping
    # (we'll later convert to a string key with sentinel)
    out["Total"] = pd.to_numeric(out["Total"], errors="coerce").round(line_round)
    out["Handicap"] = pd.to_numeric(out["Handicap"], errors="coerce").round(line_round)

    # Name can be missing; keep as string
    out["Name"] = out["Name"].astype("string")

    # --- Drop only truly unusable rows ---
    # We DO NOT drop on Total/Handicap/Name; those can be NaN.
    out = out.dropna(subset=[odds_col, bookmaker_col, "FixtureID", "MarketID", "Label"]).copy()

    # --- Build safe grouping keys (so NaNs don't delete rows) ---
    # Create grouping versions of Name/Total/Handicap that are never null.
    out["_NameKey"] = out["Name"].fillna(na_sentinel)
    out["_TotalKey"] = out["Total"].map(lambda x: f"{x:.{line_round}f}" if pd.notna(x) else na_sentinel)
    out["_HandicapKey"] = out["Handicap"].map(lambda x: f"{x:.{line_round}f}" if pd.notna(x) else na_sentinel)

    # Use exactly the grouping you want, but with safe keys for nullable cols
    group_key_cols = ["FixtureID", "MarketID", "Label", "_NameKey", "_TotalKey", "_HandicapKey"]

    # --- Optional: dedupe (group + bookmaker) to avoid duplicates blowing up comparisons ---
    if dedupe_per_bookmaker:
        dedupe_keys = group_key_cols + [bookmaker_col]

        if dedupe_keep.lower() == "latest" and latest_col in out.columns:
            out[latest_col] = pd.to_datetime(out[latest_col], utc=True, errors="coerce")
            out = out.sort_values(by=dedupe_keys + [latest_col], ascending=True, kind="mergesort")
            out = out.drop_duplicates(subset=dedupe_keys, keep="last").copy()
        else:
            # keep "best" odds per bookmaker per group
            out = out.sort_values(by=dedupe_keys + [odds_col], ascending=True, kind="mergesort")
            out = out.drop_duplicates(subset=dedupe_keys, keep="last").copy()

    # --- Core valuebet stats ---
    g = out.groupby(group_key_cols, dropna=False)
    out["MedianOdds"] = g[odds_col].transform("median")
    out["ValueThreshold"] = out["MedianOdds"] * (1.0 + pct_threshold)
    out["_GroupBookmakersN"] = g[bookmaker_col].transform("nunique")
    out["IsValueBet"] = (out[odds_col] >= out["ValueThreshold"]) & (out["_GroupBookmakersN"] >= min_bookmakers)

    # --- Compared vs lists WITHOUT apply(axis=1) ---
    out = out.reset_index(drop=False).rename(columns={"index": "_RowID"})

    left = out[["_RowID"] + group_key_cols + [bookmaker_col, odds_col]]
    right = out[["_RowID"] + group_key_cols + [bookmaker_col, odds_col]].rename(
        columns={"_RowID": "_RowID_other", bookmaker_col: "Bookmaker_other", odds_col: "Odds_other"}
    )

    m = left.merge(right, on=group_key_cols, how="left")
    m = m[(m["_RowID"] != m["_RowID_other"]) & (m[bookmaker_col] != m["Bookmaker_other"])]

    agg = m.groupby("_RowID", sort=False).agg(
        ComparedBookmakers=("Bookmaker_other", lambda s: sorted(pd.unique(s.dropna()))),
        ComparedOdds=("Odds_other", lambda s: list(pd.to_numeric(s, errors="coerce").dropna().astype(float))),
        ComparedCount=("Bookmaker_other", lambda s: int(pd.Series(s.dropna()).nunique())),
    )

    out = out.merge(agg, on="_RowID", how="left")
    out["ComparedBookmakers"] = out["ComparedBookmakers"].apply(lambda x: x if isinstance(x, list) else [])
    out["ComparedOdds"] = out["ComparedOdds"].apply(lambda x: x if isinstance(x, list) else [])
    out["ComparedCount"] = out["ComparedCount"].fillna(0).astype(int)

    # Cleanup temp columns
    out = out.drop(columns=["_GroupBookmakersN", "_NameKey", "_TotalKey", "_HandicapKey"])

    return out

# %%
value_df = find_valuebets(
    df,
    pct_threshold=0.50,
    min_bookmakers=3,
    group_cols=["FixtureID", "MarketID", "Label", "Name", "Total", "Handicap"],
)

cols = [
    "StartingAt","Fixture","Bookmaker","Market","Label","Name","Total","Handicap",
    "Odds","MedianOdds","ValueThreshold","IsValueBet",
    "ComparedCount","ComparedBookmakers",
]
value_df[value_df["IsValueBet"]][cols].head(50)
# Out:
#                      StartingAt                               Fixture  \
# 1186  2026-01-06 17:00:00+00:00                         Lecce vs Roma
# 1193  2026-01-06 17:00:00+00:00                         Lecce vs Roma
# 1199  2026-01-06 17:00:00+00:00                         Lecce vs Roma
# 1211  2026-01-06 17:00:00+00:00                         Lecce vs Roma
# 1216  2026-01-06 17:00:00+00:00                         Lecce vs Roma
# 1222  2026-01-06 17:00:00+00:00                         Lecce vs Roma
# 1226  2026-01-06 17:00:00+00:00                         Lecce vs Roma
# 1260  2026-01-06 17:00:00+00:00                         Lecce vs Roma
# 3908  2026-01-06 19:45:00+00:00                  Sassuolo vs Juventus
# 4996  2026-01-06 19:45:00+00:00                  Sassuolo vs Juventus
# 5002  2026-01-06 19:45:00+00:00                  Sassuolo vs Juventus
# 5011  2026-01-06 19:45:00+00:00                  Sassuolo vs Juventus
# 5016  2026-01-06 19:45:00+00:00                  Sassuolo vs Juventus
# 5023  2026-01-06 19:45:00+00:00                  Sassuolo vs Juventus
# 5027  2026-01-06 19:45:00+00:00                  Sassuolo vs Juventus
# 5030  2026-01-06 19:45:00+00:00                  Sassuolo vs Juventus
# 8576  2026-01-06 20:00:00+00:00  West Ham United vs Nottingham Forest
# 8772  2026-01-06 20:00:00+00:00  West Ham United vs Nottingham Forest
# 8787  2026-01-06 20:00:00+00:00  West Ham United vs Nottingham Forest
# 8802  2026-01-06 20:00:00+00:00  West Ham United vs Nottingham Forest
# 8808  2026-01-06 20:00:00+00:00  West Ham United vs Nottingham Forest
# 8813  2026-01-06 20:00:00+00:00  West Ham United vs Nottingham Forest
# 11320 2026-01-06 19:45:00+00:00              Livingston vs St. Mirren
# 12450 2026-01-06 19:45:00+00:00              Livingston vs St. Mirren
# 12462 2026-01-06 19:45:00+00:00              Livingston vs St. Mirren
# 12469 2026-01-06 19:45:00+00:00              Livingston vs St. Mirren
# 12477 2026-01-06 19:45:00+00:00              Livingston vs St. Mirren
# 12482 2026-01-06 19:45:00+00:00              Livingston vs St. Mirren
# 14858 2026-01-06 20:00:00+00:00                   Rangers vs Aberdeen
# 14861 2026-01-06 20:00:00+00:00                   Rangers vs Aberdeen
# 14862 2026-01-06 20:00:00+00:00                   Rangers vs Aberdeen
# 14866 2026-01-06 20:00:00+00:00                   Rangers vs Aberdeen
# 14867 2026-01-06 20:00:00+00:00                   Rangers vs Aberdeen
# 14870 2026-01-06 20:00:00+00:00                   Rangers vs Aberdeen
# 15740 2026-01-06 20:00:00+00:00                   Rangers vs Aberdeen
# 15809 2026-01-06 20:00:00+00:00                   Rangers vs Aberdeen
# 15815 2026-01-06 20:00:00+00:00                   Rangers vs Aberdeen
# 15890 2026-01-06 20:00:00+00:00                   Rangers vs Aberdeen
# 15896 2026-01-06 20:00:00+00:00                   Rangers vs Aberdeen
# 15954 2026-01-06 20:00:00+00:00                   Rangers vs Aberdeen
# 15995 2026-01-06 20:00:00+00:00                   Rangers vs Aberdeen
# 16028 2026-01-06 20:00:00+00:00                   Rangers vs Aberdeen
# 19457 2026-01-06 18:00:00+00:00             Granada vs Rayo Vallecano
# 19530 2026-01-06 18:00:00+00:00             Granada vs Rayo Vallecano
# 19593 2026-01-06 18:00:00+00:00             Granada vs Rayo Vallecano
# 19624 2026-01-06 18:00:00+00:00             Granada vs Rayo Vallecano
# 19631 2026-01-06 18:00:00+00:00             Granada vs Rayo Vallecano
# 19636 2026-01-06 18:00:00+00:00             Granada vs Rayo Vallecano
# 19647 2026-01-06 18:00:00+00:00             Granada vs Rayo Vallecano
# 19653 2026-01-06 18:00:00+00:00             Granada vs Rayo Vallecano
#
#          Bookmaker           Market Label  Name  Total  Handicap    Odds  \
# 1186           Sbo    Correct Score   3:2   3:2    NaN       NaN   81.64
# 1193           Sbo    Correct Score   3:3   3:3    NaN       NaN  148.84
# 1199           Sbo    Correct Score   3:4   3:4    NaN       NaN  240.04
# 1211           Sbo    Correct Score   4:0   4:0    NaN       NaN  240.04
# 1216           Sbo    Correct Score   4:1   4:1    NaN       NaN  240.04
# 1222           Sbo    Correct Score   4:2   4:2    NaN       NaN  240.04
# 1226           Sbo    Correct Score   4:3   4:3    NaN       NaN  240.04
# 1260      Pinnacle    Correct Score   6:1   6:1    NaN       NaN  251.00
# 3908        MelBet   Asian Handicap  Away  Away    NaN     -1.50    2.86
# 4996           Sbo    Correct Score   3:3   3:3    NaN       NaN  105.64
# 5002           Sbo    Correct Score   3:4   3:4    NaN       NaN  240.04
# 5011           Sbo    Correct Score   4:0   4:0    NaN       NaN  211.24
# 5016           Sbo    Correct Score   4:1   4:1    NaN       NaN  211.24
# 5023           Sbo    Correct Score   4:2   4:2    NaN       NaN  206.44
# 5027           Sbo    Correct Score   4:3   4:3    NaN       NaN  240.04
# 5030           Sbo    Correct Score   4:4   4:4    NaN       NaN  240.04
# 8576           Sbo    Correct Score   0:4   0:4    NaN       NaN   72.04
# 8772           Sbo    Correct Score   3:4   3:4    NaN       NaN  187.24
# 8787           Sbo    Correct Score   4:0   4:0    NaN       NaN  139.24
# 8802           Sbo    Correct Score   4:2   4:2    NaN       NaN  129.64
# 8808           Sbo    Correct Score   4:3   4:3    NaN       NaN  225.64
# 8813           Sbo    Correct Score   4:4   4:4    NaN       NaN  230.44
# 11320   MansionBet   Asian Handicap  Away  Away    NaN     -0.25    2.38
# 12450          Sbo    Correct Score   3:4   3:4    NaN       NaN  211.24
# 12462          Sbo    Correct Score   4:0   4:0    NaN       NaN  163.24
# 12469          Sbo    Correct Score   4:1   4:1    NaN       NaN  105.64
# 12477          Sbo    Correct Score   4:2   4:2    NaN       NaN  144.04
# 12482          Sbo    Correct Score   4:3   4:3    NaN       NaN  216.04
# 14858        1xbet   Asian Handicap  Away  Away    NaN      0.75    8.10
# 14861  Marathonbet   Asian Handicap  Away  Away    NaN      0.75    8.10
# 14862        1xbet   Asian Handicap  Away  Away    NaN      1.00   11.00
# 14866  Marathonbet   Asian Handicap  Away  Away    NaN      1.00    9.00
# 14867        1xbet   Asian Handicap  Away  Away    NaN      1.25    8.20
# 14870  Marathonbet   Asian Handicap  Away  Away    NaN      1.25    8.20
# 15740     Pinnacle  Handicap Result  Away  Away    NaN      1.00   20.13
# 15809          Sbo    Correct Score   0:3   0:3    NaN       NaN  168.04
# 15815          Sbo    Correct Score   0:4   0:4    NaN       NaN  216.04
# 15890          Sbo    Correct Score   1:3   1:3    NaN       NaN   76.84
# 15896          Sbo    Correct Score   1:4   1:4    NaN       NaN  211.24
# 15954          Sbo    Correct Score   2:4   2:4    NaN       NaN  216.04
# 15995          Sbo    Correct Score   3:4   3:4    NaN       NaN  211.24
# 16028          Sbo    Correct Score   4:3   4:3    NaN       NaN  148.84
# 19457          Sbo    Correct Score   0:4   0:4    NaN       NaN   62.44
# 19530          Sbo    Correct Score   1:4   1:4    NaN       NaN   62.44
# 19593          Sbo    Correct Score   2:4   2:4    NaN       NaN  129.64
# 19624          Sbo    Correct Score   3:2   3:2    NaN       NaN   62.44
# 19631          Sbo    Correct Score   3:3   3:3    NaN       NaN  139.24
# 19636          Sbo    Correct Score   3:4   3:4    NaN       NaN  240.04
# 19647          Sbo    Correct Score   4:0   4:0    NaN       NaN  240.04
# 19653          Sbo    Correct Score   4:1   4:1    NaN       NaN  230.44
#
#        MedianOdds  ValueThreshold  IsValueBet  ComparedCount  \
# 1186       51.000         76.5000        True              6
# 1193       71.000        106.5000        True              6
# 1199      101.000        151.5000        True              4
# 1211      113.000        169.5000        True              3
# 1216      101.000        151.5000        True              4
# 1222      126.000        189.0000        True              4
# 1226      138.500        207.7500        True              3
# 1260      151.000        226.5000        True              2
# 3908        1.030          1.5450        True              2
# 4996       67.000        100.5000        True              6
# 5002      106.000        159.0000        True              5
# 5011      126.000        189.0000        True              2
# 5016      106.970        160.4550        True              5
# 5023      114.945        172.4175        True              5
# 5027      126.000        189.0000        True              2
# 5030      151.000        226.5000        True              2
# 8576       46.000         69.0000        True              6
# 8772      101.000        151.5000        True              5
# 8787       81.000        121.5000        True              6
# 8802       71.000        106.5000        True              6
# 8808      111.000        166.5000        True              5
# 8813      138.500        207.7500        True              3
# 11320       1.480          2.2200        True              4
# 12450     101.000        151.5000        True              4
# 12462      76.000        114.0000        True              6
# 12469      61.000         91.5000        True              6
# 12477      71.000        106.5000        True              6
# 12482     101.000        151.5000        True              4
# 14858       5.130          7.6950        True              3
# 14861       5.130          7.6950        True              3
# 14862       2.050          3.0750        True              4
# 14866       2.050          3.0750        True              4
# 14867       5.045          7.5675        True              3
# 14870       5.045          7.5675        True              3
# 15740      12.500         18.7500        True              3
# 15809      81.000        121.5000        True              6
# 15815     125.500        188.2500        True              5
# 15890      50.000         75.0000        True              6
# 15896     101.000        151.5000        True              5
# 15954     101.000        151.5000        True              5
# 15995     126.000        189.0000        True              4
# 16028      85.500        128.2500        True              5
# 19457      37.700         56.5500        True              6
# 19530      39.610         59.4150        True              6
# 19593      71.000        106.5000        True              6
# 19624      41.000         61.5000        True              6
# 19631      71.000        106.5000        True              6
# 19636     101.000        151.5000        True              4
# 19647     111.000        166.5000        True              5
# 19653      95.500        143.2500        True              5
#
#                                       ComparedBookmakers
# 1186   [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 1193   [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 1199               [10Bet, 1xbet, Pinnacle, WilliamHill]
# 1211                      [1xbet, Pinnacle, WilliamHill]
# 1216               [10Bet, 1xbet, Pinnacle, WilliamHill]
# 1222               [10Bet, 1xbet, Pinnacle, WilliamHill]
# 1226                      [1xbet, Pinnacle, WilliamHill]
# 1260                                [1xbet, WilliamHill]
# 3908                                [1xbet, Marathonbet]
# 4996   [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 5002       [10Bet, 1xbet, Pinnacle, Unibet, WilliamHill]
# 5011                                [1xbet, WilliamHill]
# 5016       [10Bet, 1xbet, Pinnacle, Unibet, WilliamHill]
# 5023       [10Bet, 1xbet, Pinnacle, Unibet, WilliamHill]
# 5027                                [1xbet, WilliamHill]
# 5030                                [1xbet, WilliamHill]
# 8576   [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 8772       [10Bet, 1xbet, Pinnacle, Unibet, WilliamHill]
# 8787   [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 8802   [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 8808       [10Bet, 1xbet, Pinnacle, Unibet, WilliamHill]
# 8813                      [1xbet, Pinnacle, WilliamHill]
# 11320           [1xbet, CloudBet, Marathonbet, Pinnacle]
# 12450                [10Bet, 1xbet, Unibet, WilliamHill]
# 12462  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 12469  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 12477  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 12482                [10Bet, 1xbet, Unibet, WilliamHill]
# 14858                [CloudBet, MansionBet, Marathonbet]
# 14861                      [1xbet, CloudBet, MansionBet]
# 14862       [CloudBet, Dafabet, MansionBet, Marathonbet]
# 14866             [1xbet, CloudBet, Dafabet, MansionBet]
# 14867                      [CloudBet, HKJC, Marathonbet]
# 14870                            [1xbet, CloudBet, HKJC]
# 15740                       [10Bet, Marathonbet, Unibet]
# 15809  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 15815   [10Bet, 1xbet, Marathonbet, Unibet, WilliamHill]
# 15890  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 15896   [10Bet, 1xbet, Marathonbet, Unibet, WilliamHill]
# 15954   [10Bet, 1xbet, Marathonbet, Unibet, WilliamHill]
# 15995                [10Bet, 1xbet, Unibet, WilliamHill]
# 16028   [10Bet, 1xbet, Marathonbet, Unibet, WilliamHill]
# 19457  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 19530  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 19593  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 19624  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 19631  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 19636                [10Bet, 1xbet, Unibet, WilliamHill]
# 19647   [10Bet, 1xbet, Marathonbet, Unibet, WilliamHill]
# 19653   [10Bet, 1xbet, Marathonbet, Unibet, WilliamHill]

# %%
# only show valuebets:
value_bets = value_df[value_df["IsValueBet"]]

# remove columns: DP3, OddID, _RowID, MarketID
value_bets = value_bets.drop(columns=["DP3", "OddID", "_RowID", "MarketID"], errors="ignore")
value_bets.head(50)
# Out:
#        FixtureID    Bookmaker           Market Label  Name   Value  Total  \
# 1186    19425064          Sbo    Correct Score   3:2   3:2   81.64    NaN
# 1193    19425064          Sbo    Correct Score   3:3   3:3  148.84    NaN
# 1199    19425064          Sbo    Correct Score   3:4   3:4  240.04    NaN
# 1211    19425064          Sbo    Correct Score   4:0   4:0  240.04    NaN
# 1216    19425064          Sbo    Correct Score   4:1   4:1  240.04    NaN
# 1222    19425064          Sbo    Correct Score   4:2   4:2  240.04    NaN
# 1226    19425064          Sbo    Correct Score   4:3   4:3  240.04    NaN
# 1260    19425064     Pinnacle    Correct Score   6:1   6:1  251.00    NaN
# 3908    19425069       MelBet   Asian Handicap  Away  Away    2.86    NaN
# 4996    19425069          Sbo    Correct Score   3:3   3:3  105.64    NaN
# 5002    19425069          Sbo    Correct Score   3:4   3:4  240.04    NaN
# 5011    19425069          Sbo    Correct Score   4:0   4:0  211.24    NaN
# 5016    19425069          Sbo    Correct Score   4:1   4:1  211.24    NaN
# 5023    19425069          Sbo    Correct Score   4:2   4:2  206.44    NaN
# 5027    19425069          Sbo    Correct Score   4:3   4:3  240.04    NaN
# 5030    19425069          Sbo    Correct Score   4:4   4:4  240.04    NaN
# 8576    19427665          Sbo    Correct Score   0:4   0:4   72.04    NaN
# 8772    19427665          Sbo    Correct Score   3:4   3:4  187.24    NaN
# 8787    19427665          Sbo    Correct Score   4:0   4:0  139.24    NaN
# 8802    19427665          Sbo    Correct Score   4:2   4:2  129.64    NaN
# 8808    19427665          Sbo    Correct Score   4:3   4:3  225.64    NaN
# 8813    19427665          Sbo    Correct Score   4:4   4:4  230.44    NaN
# 11320   19428102   MansionBet   Asian Handicap  Away  Away    2.38    NaN
# 12450   19428102          Sbo    Correct Score   3:4   3:4  211.24    NaN
# 12462   19428102          Sbo    Correct Score   4:0   4:0  163.24    NaN
# 12469   19428102          Sbo    Correct Score   4:1   4:1  105.64    NaN
# 12477   19428102          Sbo    Correct Score   4:2   4:2  144.04    NaN
# 12482   19428102          Sbo    Correct Score   4:3   4:3  216.04    NaN
# 14858   19590624        1xbet   Asian Handicap  Away  Away    8.10    NaN
# 14861   19590624  Marathonbet   Asian Handicap  Away  Away    8.10    NaN
# 14862   19590624        1xbet   Asian Handicap  Away  Away   11.00    NaN
# 14866   19590624  Marathonbet   Asian Handicap  Away  Away    9.00    NaN
# 14867   19590624        1xbet   Asian Handicap  Away  Away    8.20    NaN
# 14870   19590624  Marathonbet   Asian Handicap  Away  Away    8.20    NaN
# 15740   19590624     Pinnacle  Handicap Result  Away  Away   20.13    NaN
# 15809   19590624          Sbo    Correct Score   0:3   0:3  168.04    NaN
# 15815   19590624          Sbo    Correct Score   0:4   0:4  216.04    NaN
# 15890   19590624          Sbo    Correct Score   1:3   1:3   76.84    NaN
# 15896   19590624          Sbo    Correct Score   1:4   1:4  211.24    NaN
# 15954   19590624          Sbo    Correct Score   2:4   2:4  216.04    NaN
# 15995   19590624          Sbo    Correct Score   3:4   3:4  211.24    NaN
# 16028   19590624          Sbo    Correct Score   4:3   4:3  148.84    NaN
# 19457   19612499          Sbo    Correct Score   0:4   0:4   62.44    NaN
# 19530   19612499          Sbo    Correct Score   1:4   1:4   62.44    NaN
# 19593   19612499          Sbo    Correct Score   2:4   2:4  129.64    NaN
# 19624   19612499          Sbo    Correct Score   3:2   3:2   62.44    NaN
# 19631   19612499          Sbo    Correct Score   3:3   3:3  139.24    NaN
# 19636   19612499          Sbo    Correct Score   3:4   3:4  240.04    NaN
# 19647   19612499          Sbo    Correct Score   4:0   4:0  240.04    NaN
# 19653   19612499          Sbo    Correct Score   4:1   4:1  230.44    NaN
#
#        Handicap LatestBookmakerUpdate                               Fixture  \
# 1186        NaN   2026-01-06 06:01:45                         Lecce vs Roma
# 1193        NaN   2026-01-06 06:01:45                         Lecce vs Roma
# 1199        NaN   2026-01-06 06:01:45                         Lecce vs Roma
# 1211        NaN   2026-01-06 06:01:45                         Lecce vs Roma
# 1216        NaN   2026-01-06 06:01:45                         Lecce vs Roma
# 1222        NaN   2026-01-06 06:01:45                         Lecce vs Roma
# 1226        NaN   2026-01-06 06:01:45                         Lecce vs Roma
# 1260        NaN   2026-01-06 07:30:03                         Lecce vs Roma
# 3908      -1.50   2026-01-06 16:00:35                  Sassuolo vs Juventus
# 4996        NaN   2026-01-06 05:12:25                  Sassuolo vs Juventus
# 5002        NaN   2026-01-06 05:12:25                  Sassuolo vs Juventus
# 5011        NaN   2026-01-06 05:12:25                  Sassuolo vs Juventus
# 5016        NaN   2026-01-06 05:12:25                  Sassuolo vs Juventus
# 5023        NaN   2026-01-06 05:12:25                  Sassuolo vs Juventus
# 5027        NaN   2026-01-06 05:12:25                  Sassuolo vs Juventus
# 5030        NaN   2026-01-06 05:12:25                  Sassuolo vs Juventus
# 8576        NaN   2026-01-06 02:41:50  West Ham United vs Nottingham Forest
# 8772        NaN   2026-01-06 02:41:50  West Ham United vs Nottingham Forest
# 8787        NaN   2026-01-06 02:41:50  West Ham United vs Nottingham Forest
# 8802        NaN   2026-01-06 02:41:50  West Ham United vs Nottingham Forest
# 8808        NaN   2026-01-06 02:41:50  West Ham United vs Nottingham Forest
# 8813        NaN   2026-01-06 02:41:50  West Ham United vs Nottingham Forest
# 11320     -0.25   2026-01-04 18:01:08              Livingston vs St. Mirren
# 12450       NaN   2026-01-06 05:28:01              Livingston vs St. Mirren
# 12462       NaN   2026-01-06 05:28:01              Livingston vs St. Mirren
# 12469       NaN   2026-01-06 05:28:01              Livingston vs St. Mirren
# 12477       NaN   2026-01-06 05:28:01              Livingston vs St. Mirren
# 12482       NaN   2026-01-06 05:28:01              Livingston vs St. Mirren
# 14858      0.75   2026-01-06 07:58:13                   Rangers vs Aberdeen
# 14861      0.75   2026-01-06 07:57:38                   Rangers vs Aberdeen
# 14862      1.00   2026-01-06 07:58:13                   Rangers vs Aberdeen
# 14866      1.00   2026-01-06 07:57:38                   Rangers vs Aberdeen
# 14867      1.25   2026-01-06 07:58:13                   Rangers vs Aberdeen
# 14870      1.25   2026-01-06 07:57:38                   Rangers vs Aberdeen
# 15740      1.00   2026-01-06 07:13:50                   Rangers vs Aberdeen
# 15809       NaN   2026-01-06 07:42:02                   Rangers vs Aberdeen
# 15815       NaN   2026-01-06 07:42:02                   Rangers vs Aberdeen
# 15890       NaN   2026-01-06 07:42:02                   Rangers vs Aberdeen
# 15896       NaN   2026-01-06 07:42:02                   Rangers vs Aberdeen
# 15954       NaN   2026-01-06 07:42:02                   Rangers vs Aberdeen
# 15995       NaN   2026-01-06 07:42:02                   Rangers vs Aberdeen
# 16028       NaN   2026-01-06 07:42:02                   Rangers vs Aberdeen
# 19457       NaN   2026-01-06 07:57:29             Granada vs Rayo Vallecano
# 19530       NaN   2026-01-06 07:57:29             Granada vs Rayo Vallecano
# 19593       NaN   2026-01-06 07:57:29             Granada vs Rayo Vallecano
# 19624       NaN   2026-01-06 07:57:29             Granada vs Rayo Vallecano
# 19631       NaN   2026-01-06 07:57:29             Granada vs Rayo Vallecano
# 19636       NaN   2026-01-06 07:57:29             Granada vs Rayo Vallecano
# 19647       NaN   2026-01-06 07:57:29             Granada vs Rayo Vallecano
# 19653       NaN   2026-01-06 07:57:29             Granada vs Rayo Vallecano
#
#                      StartingAt    Odds  MedianOdds  ValueThreshold  \
# 1186  2026-01-06 17:00:00+00:00   81.64      51.000         76.5000
# 1193  2026-01-06 17:00:00+00:00  148.84      71.000        106.5000
# 1199  2026-01-06 17:00:00+00:00  240.04     101.000        151.5000
# 1211  2026-01-06 17:00:00+00:00  240.04     113.000        169.5000
# 1216  2026-01-06 17:00:00+00:00  240.04     101.000        151.5000
# 1222  2026-01-06 17:00:00+00:00  240.04     126.000        189.0000
# 1226  2026-01-06 17:00:00+00:00  240.04     138.500        207.7500
# 1260  2026-01-06 17:00:00+00:00  251.00     151.000        226.5000
# 3908  2026-01-06 19:45:00+00:00    2.86       1.030          1.5450
# 4996  2026-01-06 19:45:00+00:00  105.64      67.000        100.5000
# 5002  2026-01-06 19:45:00+00:00  240.04     106.000        159.0000
# 5011  2026-01-06 19:45:00+00:00  211.24     126.000        189.0000
# 5016  2026-01-06 19:45:00+00:00  211.24     106.970        160.4550
# 5023  2026-01-06 19:45:00+00:00  206.44     114.945        172.4175
# 5027  2026-01-06 19:45:00+00:00  240.04     126.000        189.0000
# 5030  2026-01-06 19:45:00+00:00  240.04     151.000        226.5000
# 8576  2026-01-06 20:00:00+00:00   72.04      46.000         69.0000
# 8772  2026-01-06 20:00:00+00:00  187.24     101.000        151.5000
# 8787  2026-01-06 20:00:00+00:00  139.24      81.000        121.5000
# 8802  2026-01-06 20:00:00+00:00  129.64      71.000        106.5000
# 8808  2026-01-06 20:00:00+00:00  225.64     111.000        166.5000
# 8813  2026-01-06 20:00:00+00:00  230.44     138.500        207.7500
# 11320 2026-01-06 19:45:00+00:00    2.38       1.480          2.2200
# 12450 2026-01-06 19:45:00+00:00  211.24     101.000        151.5000
# 12462 2026-01-06 19:45:00+00:00  163.24      76.000        114.0000
# 12469 2026-01-06 19:45:00+00:00  105.64      61.000         91.5000
# 12477 2026-01-06 19:45:00+00:00  144.04      71.000        106.5000
# 12482 2026-01-06 19:45:00+00:00  216.04     101.000        151.5000
# 14858 2026-01-06 20:00:00+00:00    8.10       5.130          7.6950
# 14861 2026-01-06 20:00:00+00:00    8.10       5.130          7.6950
# 14862 2026-01-06 20:00:00+00:00   11.00       2.050          3.0750
# 14866 2026-01-06 20:00:00+00:00    9.00       2.050          3.0750
# 14867 2026-01-06 20:00:00+00:00    8.20       5.045          7.5675
# 14870 2026-01-06 20:00:00+00:00    8.20       5.045          7.5675
# 15740 2026-01-06 20:00:00+00:00   20.13      12.500         18.7500
# 15809 2026-01-06 20:00:00+00:00  168.04      81.000        121.5000
# 15815 2026-01-06 20:00:00+00:00  216.04     125.500        188.2500
# 15890 2026-01-06 20:00:00+00:00   76.84      50.000         75.0000
# 15896 2026-01-06 20:00:00+00:00  211.24     101.000        151.5000
# 15954 2026-01-06 20:00:00+00:00  216.04     101.000        151.5000
# 15995 2026-01-06 20:00:00+00:00  211.24     126.000        189.0000
# 16028 2026-01-06 20:00:00+00:00  148.84      85.500        128.2500
# 19457 2026-01-06 18:00:00+00:00   62.44      37.700         56.5500
# 19530 2026-01-06 18:00:00+00:00   62.44      39.610         59.4150
# 19593 2026-01-06 18:00:00+00:00  129.64      71.000        106.5000
# 19624 2026-01-06 18:00:00+00:00   62.44      41.000         61.5000
# 19631 2026-01-06 18:00:00+00:00  139.24      71.000        106.5000
# 19636 2026-01-06 18:00:00+00:00  240.04     101.000        151.5000
# 19647 2026-01-06 18:00:00+00:00  240.04     111.000        166.5000
# 19653 2026-01-06 18:00:00+00:00  230.44      95.500        143.2500
#
#        IsValueBet                                 ComparedBookmakers  \
# 1186         True  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 1193         True  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 1199         True              [10Bet, 1xbet, Pinnacle, WilliamHill]
# 1211         True                     [1xbet, Pinnacle, WilliamHill]
# 1216         True              [10Bet, 1xbet, Pinnacle, WilliamHill]
# 1222         True              [10Bet, 1xbet, Pinnacle, WilliamHill]
# 1226         True                     [1xbet, Pinnacle, WilliamHill]
# 1260         True                               [1xbet, WilliamHill]
# 3908         True                               [1xbet, Marathonbet]
# 4996         True  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 5002         True      [10Bet, 1xbet, Pinnacle, Unibet, WilliamHill]
# 5011         True                               [1xbet, WilliamHill]
# 5016         True      [10Bet, 1xbet, Pinnacle, Unibet, WilliamHill]
# 5023         True      [10Bet, 1xbet, Pinnacle, Unibet, WilliamHill]
# 5027         True                               [1xbet, WilliamHill]
# 5030         True                               [1xbet, WilliamHill]
# 8576         True  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 8772         True      [10Bet, 1xbet, Pinnacle, Unibet, WilliamHill]
# 8787         True  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 8802         True  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 8808         True      [10Bet, 1xbet, Pinnacle, Unibet, WilliamHill]
# 8813         True                     [1xbet, Pinnacle, WilliamHill]
# 11320        True           [1xbet, CloudBet, Marathonbet, Pinnacle]
# 12450        True                [10Bet, 1xbet, Unibet, WilliamHill]
# 12462        True  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 12469        True  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 12477        True  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 12482        True                [10Bet, 1xbet, Unibet, WilliamHill]
# 14858        True                [CloudBet, MansionBet, Marathonbet]
# 14861        True                      [1xbet, CloudBet, MansionBet]
# 14862        True       [CloudBet, Dafabet, MansionBet, Marathonbet]
# 14866        True             [1xbet, CloudBet, Dafabet, MansionBet]
# 14867        True                      [CloudBet, HKJC, Marathonbet]
# 14870        True                            [1xbet, CloudBet, HKJC]
# 15740        True                       [10Bet, Marathonbet, Unibet]
# 15809        True  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 15815        True   [10Bet, 1xbet, Marathonbet, Unibet, WilliamHill]
# 15890        True  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 15896        True   [10Bet, 1xbet, Marathonbet, Unibet, WilliamHill]
# 15954        True   [10Bet, 1xbet, Marathonbet, Unibet, WilliamHill]
# 15995        True                [10Bet, 1xbet, Unibet, WilliamHill]
# 16028        True   [10Bet, 1xbet, Marathonbet, Unibet, WilliamHill]
# 19457        True  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 19530        True  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 19593        True  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 19624        True  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 19631        True  [10Bet, 1xbet, Marathonbet, Pinnacle, Unibet, ...
# 19636        True                [10Bet, 1xbet, Unibet, WilliamHill]
# 19647        True   [10Bet, 1xbet, Marathonbet, Unibet, WilliamHill]
# 19653        True   [10Bet, 1xbet, Marathonbet, Unibet, WilliamHill]
#
#                                   ComparedOdds  ComparedCount
# 1186      [46.0, 60.0, 64.0, 51.0, 51.0, 51.0]              6
# 1193      [67.0, 90.0, 96.0, 67.0, 67.0, 71.0]              6
# 1199               [126.0, 100.0, 91.0, 101.0]              4
# 1211                      [100.0, 81.0, 126.0]              3
# 1216               [126.0, 100.0, 71.0, 101.0]              4
# 1222              [126.0, 100.0, 101.0, 126.0]              4
# 1226                     [100.0, 126.0, 151.0]              3
# 1260                            [100.0, 151.0]              2
# 3908                               [1.03, 1.0]              2
# 4996     [56.0, 65.0, 71.0, 74.09, 51.0, 67.0]              6
# 5002       [91.0, 100.0, 119.07, 111.0, 101.0]              5
# 5011                            [100.0, 126.0]              2
# 5016      [101.0, 100.0, 112.94, 126.0, 101.0]              5
# 5023      [101.0, 100.0, 128.89, 141.0, 101.0]              5
# 5027                            [100.0, 126.0]              2
# 5030                            [100.0, 151.0]              2
# 8576      [46.0, 46.0, 56.0, 36.0, 36.0, 46.0]              6
# 8772        [91.0, 100.0, 101.0, 101.0, 101.0]              5
# 8787      [76.0, 90.0, 93.0, 61.0, 61.0, 81.0]              6
# 8802      [61.0, 75.0, 88.0, 61.0, 61.0, 71.0]              6
# 8808       [101.0, 100.0, 121.0, 121.0, 101.0]              5
# 8813                     [100.0, 126.0, 151.0]              3
# 11320                 [1.41, 1.99, 1.41, 1.48]              4
# 12450              [91.0, 100.0, 101.0, 101.0]              4
# 12462  [76.0, 100.0, 106.0, 50.98, 56.0, 71.0]              6
# 12469    [56.0, 75.0, 81.0, 50.77, 46.0, 61.0]              6
# 12477   [67.0, 90.0, 106.0, 50.63, 61.0, 71.0]              6
# 12482             [101.0, 100.0, 121.0, 101.0]              4
# 14858                        [1.99, 2.16, 8.1]              3
# 14861                        [8.1, 1.99, 2.16]              3
# 14862                  [1.97, 2.03, 2.05, 9.0]              4
# 14866                 [11.0, 1.97, 2.03, 2.05]              4
# 14867                        [1.89, 1.89, 8.2]              3
# 14870                        [8.2, 1.89, 1.89]              3
# 15740                        [13.0, 7.5, 12.0]              3
# 15809   [76.0, 90.0, 106.0, 53.37, 51.0, 81.0]              6
# 15815        [91.0, 100.0, 88.0, 151.0, 151.0]              5
# 15890    [41.0, 50.0, 61.0, 47.63, 29.0, 51.0]              6
# 15896      [101.0, 100.0, 101.0, 111.0, 101.0]              5
# 15954       [101.0, 100.0, 106.0, 81.0, 101.0]              5
# 15995             [126.0, 100.0, 101.0, 126.0]              4
# 16028          [71.0, 90.0, 106.0, 67.0, 81.0]              5
# 19457     [34.0, 36.0, 46.0, 37.7, 23.0, 46.0]              6
# 19530    [34.0, 36.0, 46.0, 39.61, 25.0, 46.0]              6
# 19593    [61.0, 75.0, 83.0, 55.67, 46.0, 71.0]              6
# 19624    [34.0, 36.0, 51.0, 44.84, 29.0, 41.0]              6
# 19631    [61.0, 80.0, 83.0, 54.86, 41.0, 71.0]              6
# 19636              [126.0, 100.0, 91.0, 101.0]              4
# 19647      [126.0, 100.0, 111.0, 111.0, 101.0]              5
# 19653         [81.0, 100.0, 111.0, 76.0, 91.0]              5

# %%
# 1) Do you have enough rows after cleaning?
print("Rows:", len(value_df))
print("Valuebets:", value_df["IsValueBet"].sum())

# 2) How many groups have >= 3 bookmakers?
tmp = df.copy()
tmp["Odds"] = pd.to_numeric(tmp["Odds"], errors="coerce")
tmp = tmp.dropna(subset=["Odds", "Bookmaker", "FixtureID", "MarketID", "Label", "Name", "Total", "Handicap"])

grp = tmp.groupby(["FixtureID","MarketID","Label","Name","Total","Handicap"])["Bookmaker"].nunique()
print("Groups total:", len(grp))
print("Groups with >=3 books:", (grp >= 3).sum())

# 3) What's the maximum "value ratio" you even see?
# ratio = Odds / MedianOdds; valuebet at 30% is ratio >= 1.30
mx = (value_df["Odds"] / value_df["MedianOdds"]).max()
print("Max Odds/MedianOdds ratio:", mx)
# Out:
# Rows: 0
# Valuebets: 0
# Groups total: 0
# Groups with >=3 books: 0
# Max Odds/MedianOdds ratio: nan
